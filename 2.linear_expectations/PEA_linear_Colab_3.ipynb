# %% [markdown]
# # I. Theory
#
# ## I.1. Model description
#
# Let us consider a simple forward-looking expectational difference equation
# \begin{equation}
# y_t = a\,\mathbb{E}_t[y_{t+1}] + b\,x_t,
# \end{equation}
#
# where the state $x_t$ follows an AR(1) with mean $\bar x$:
# \begin{equation}
# x_{t+1} = \rho\,x_t + (1-\rho)\,\bar x + \varepsilon_{t+1},
# \quad |\rho|<1.
# \end{equation}
#
# Parameters $a,b,\rho,\bar x$ are given, and $\varepsilon_t \sim \mathcal N(0,\sigma_{\varepsilon}^2)$.
#
# ---
#
# ## I.2. Analytic solution for $y_t$
#
# 1. **Forward-sum representation**
#    Under the no-bubble solution (transversality condition)
#    \begin{equation}
#    y_t = b \sum_{i=0}^\infty a^i\,\mathbb{E}_t[x_{t+i}].
#    \end{equation}
#
# 2. **Compute $\mathbb{E}_t[x_{t+i}]$**
#
#    For the AR(1) with intercept,
#    \begin{equation}
#    \mathbb{E}_t[x_{t+i}]
#    = \rho^i\,x_t + (1-\rho^i)\,\bar x.
#    \end{equation}
#
# 3. **Evaluate the two infinite sums**
#    - Slope term:
#      \begin{equation}
#      \sum_{i=0}^\infty (a\rho)^i = \frac{1}{1 - a\,\rho}.
#      \end{equation}
#    - Intercept term:
#      \begin{equation}
#        \sum_{i=0}^\infty a^i(1-\rho^i)
#        = \frac{1}{1-a} - \frac{1}{1-a\rho}
#        = \frac{a\,(1-\rho)}{(1-a)\,(1-a\rho)}.
#      \end{equation}
#
# 4. **Closed-form**
#    Plugging in,
#    \begin{equation}
#    y_t
#    = b\,x_t\;\frac{1}{1 - a\,\rho}
#      + b\,\bar x\;\frac{a\,(1-\rho)}{(1-a)\,(1-a\rho)},
#    \end{equation}
#    i.e.
#    \begin{equation}
#    \boxed{
#      y_t
#      = \frac{b}{1 - a\,\rho}\,x_t
#      + \frac{a\,b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x
#    }.
#    \end{equation}
#
# ---
#
# ## I.3. Analytic form of $\mathbb{E}_t[y_{t+1}]$
#
# Let's make the parametric assumption for the conditional expectation term:
# \begin{equation}
# \mathbb{E}_t[y_{t+1}] \approx \theta_0 + \theta_1\,x_t.
# \end{equation}
#
# 1. **Use the solution for $y_{t+1}$**
#    \begin{equation}
#    y_{t+1}
#    = \frac{b}{1 - a\,\rho}\,x_{t+1}
#      + \frac{a\,b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x.
#    \end{equation}
#
# 2. **Take conditional expectation**
#    Since $\mathbb{E}_t[x_{t+1}] = \rho\,x_t + (1-\rho)\,\bar x$
#    \begin{equation}
#    \mathbb{E}_t[y_{t+1}]
#    = \frac{b}{1 - a\,\rho}\bigl[\rho\,x_t+(1-\rho)\bar x\bigr]
#      + \frac{a\,b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x.
#    \end{equation}
#
# 3. **Collect terms**
#    \begin{equation}
#    \theta_1 = \frac{b\,\rho}{1 - a\,\rho},
#    \quad
#    \theta_0 = \frac{b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x.
#    \end{equation}
#
# Hence
# \begin{equation}
# \boxed{
#   \mathbb{E}_t[y_{t+1}]
#   = \frac{b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x
#     + \frac{b\,\rho}{1 - a\,\rho}\,x_t
# }.
# \end{equation}
#
# With the **PEA**, we hope to estimate the parameters using OLS:
# \begin{equation}
# \begin{split}
# \hat{\theta_0} & = \frac{b\,(1-\rho)}{(1-a)\,(1-a\rho)}\,\bar x \\
# \hat{\theta_1} & = \frac{b\,\rho}{1 - a\,\rho}
# \end{split}
# \end{equation}
#
# ---
#
# ## I.4. An economic interpretation
#
# Some economic models fit within the simple linear rational expectations model from above.
# One example is the **Cagan model of hyperinflation**.
#
# Consider an economy in which money demand (= money supply in equilibrium), divided by the price level, depends negatively on expected inflation:
#
# \begin{equation}
# \frac{M_t}{P_t} = \exp(- \alpha \pi_{t+1}^e)
# \end{equation}
#
# where $\pi_{t+1}^e = E_t[\frac{P_{t+1} - P_{t}}{P_t}]$.
#
# Let's use non-capitalized letters to denote the logarithm of terms (e.g., $p_t = \log(P_t))$.
#
# Observe that  $\pi_{t+1}^e = E_t[\exp(p_{t+1}^e - p_t) - 1] \approx E_t[p_{t+1}^e - p_t]$, using $\exp(x) \approx 1 + x$ for $x$ small.
#
# Hence, we have:
#
# \begin{equation}
# m_t - p_t \approx - \alpha  ( E_t[p_{t+1}^e ] - p_t)
# \end{equation}
#
# or, equivalently:
#
# \begin{equation}
# p_t \approx \frac{\alpha}{1 + \alpha } E_t[p_{t+1}^e ] + \frac{1}{1 + \alpha} m_t
# \end{equation}
#
# Define $a = \frac{\alpha}{1 + \alpha }$ and $ b = \frac{1}{1 + \alpha}$, then we have (forgetting the approximation):
#
# \begin{equation}
# p_t = a E_t[p_{t+1}^e ] + b m_t
# \end{equation}
#
# For the **law of motion of money supply**, we may assume that the (detrended, removing a constant growth term) log of money supply follows an AR(1) process:
#
# \begin{equation}
# m_{t+1} = \rho\,m_t + (1-\rho)\,\bar m + \varepsilon_{t+1},
# \quad |\rho|<1.
# \end{equation}
#
# with $\varepsilon_t \sim \mathcal N(0,\sigma^2)$.
#
# ---
#
# ## I.5. Convergence Analysis
#
# Let's analyze the convergence of the PEA, for $\bar{x} = 0$, to make our life simpler. With that extra assumption, the law of motion for the state vector simplifies to :
#
# \begin{equation}
# x_{t+1} = \rho\,x_t +  \varepsilon_{t+1},
# \quad |\rho|<1.
# \end{equation}
#
# We start with an initial guess $\theta_0^{(0)} = \theta_0^{0}$ and $\theta_1^{(0)} = \theta_1^{0}$.
#
# At step $k$ of the PEA, our guess for the expectation function is $E_t[y_{t+1}] = \theta_0^{(k)} + \theta_1^{(k)} x_t$. Because $y_t = a E_t[y_{t+1}] + b x_t$, we get:
#
# \begin{equation}
# y_t = a \theta_0^{(k)} + ( a \theta_1^{(k)} + b) x_t
# \end{equation}
#
#
# Forward $y_t$ by one period and use the law of motion for $x_{t+1}$ to get:
#
# \begin{equation}
# y_{t+1} = a \theta_0^{(k)} + \rho ( a \theta_1^{(k)} + b) x_t + \varepsilon_{t+1}
# \end{equation}
#
# OLS is unbiased, so at step $k+1$ and assuming full update ($\tau = 1$), we get:
#
# \begin{equation}
# \begin{split}
# \theta_0^{(k+1)} & =  a \theta_0^{(k)} \\
# \theta_1^{(k+1)} & = \rho ( a \theta_1^{(k)} + b)
# \end{split}
# \end{equation}
#
# It is easy to see that, as long as $|a|<1$ and $|\rho a| < 1$, we have a contraction mapping, leading to the fixed point:
#
# \begin{equation}
# \begin{split}
# \theta_0^{*} & =  0 \\
# \theta_1^{*} & = \frac{b\,\rho}{1 - a\,\rho}
# \end{split}
# \end{equation}
#
# Thus, the PEA converges to the true solution. We can even calculate the expected values for $\theta_0^{(k)}$ and $\theta_1^{(k)}$ after $k$ updates:
#
# \begin{equation}
# \begin{split}
# \theta_0^{(k)} & =  a^{k} \theta_0^{0} \\
# \theta_1^{(k)} & = \frac{b \rho}{1 - a \rho } \big(1 - (a \rho)^{n} \big) +  \theta_1^{0} (a \rho)^{n}
# \end{split}
# \end{equation}

# %% [markdown]
# ---
#
# ## II. Computations
#
#
# ### II. A. Load libraries, functions and types

# %%
on_Colab = True #When on Google Colab, set to true. False to run locally.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import random
import scipy.stats
#import chaospy  ## for quadrature
from itertools import product
import os
import re
import subprocess
import shutil

import time
import pandas as pd
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.ticker as mticker

import seaborn as sns; sns.set()
from tqdm import tqdm as tqdm
import datetime
from typing import Tuple
class Vector: pass
from scipy.stats import norm

import torch
from torch import nn
from torch.utils.data import DataLoader, Subset, Dataset, TensorDataset
from torch.nn.utils import clip_grad_norm_

# To create copies of NN
import copy
import matplotlib.ticker as mtick
# To use sparse kronecker product
from scipy import sparse

import itertools
# Interpolations
from scipy.interpolate import LinearNDInterpolator
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from scipy.interpolate import RegularGridInterpolator

# Regressions
import statsmodels.formula.api as smf
import statsmodels.api as sm
lowess = sm.nonparametric.lowess

#import quantecon as qe
#from interpolation import interp
#from quantecon.optimize import brentq
from numba import njit
#from numba.experimental import jitclass
#import copy # Not used so far

import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator

import platform,socket,re,uuid,json,psutil,logging, cpuinfo, shutil

from scipy.stats import chi2
from scipy.stats import qmc

# %%
# Store parameters
class MyParams():
    """
    N: number of draws for innovation vector
    M: number of draws for the state vector
    lr: learning rate
    nb_epochs: number of gradient descent steps during training
    """
    def __init__(self, N, M, x_bar, rho_x, std_e, a, b, low_discrepancy):
        # Model parameters
        self.x_bar = x_bar
        self.rho_x = rho_x
        self.std_e = std_e
        # We assume the linear expectation model y_t = a E_t[y_{t+1}] + b x_t
        self.a = a
        self.b = b
        # Infer mean and variance for x_t
        self.mean_x = self.x_bar
        self.var_x = (std_e**2)/(1 - self.rho_x**2)
        self.std_x = std_e/np.sqrt(1 - self.rho_x**2)
        # Dependent variable in level or log
        self.formula = ""
        # Options for OLS regression
        self.nb_expl_vars = 2 #including cst
        self.basis = 1 #1: linear. 2: chebychev.
        self.nb_shocks = 1
        # Nb agents:
        self.nb_agents = 1 #One representative household
        # bc-MC hyperparameters
        self.N = N #number of iid shocks used for each value of the state vector
        self.M = M #number of iid realization of the state vector
        self.MN = int(M*N)
        # To keep constant the number of function evaluations
        self.T = int((M*N)/2) #number
        # low-discrepancy draws
        self.low_discrepancy = low_discrepancy

def show_params(params):
    """
    Dynamically display parameter values using getattr.
    """
    list_p = ["M", "N", "x_bar", "rho_x", "std_e", "mean_x", "std_x", "a", "b", "low_discrepancy"]
    for name in list_p:
        value = getattr(params, name)
        print(f"{name}: {value}")

# %%
info_cpu = cpuinfo.get_cpu_info()
for (name) in info_cpu:
  print(f"{name}: ", info_cpu[name])

same_machine = True #ensure same machine
machine_desired = "Intel(R) Xeon(R) CPU @ 2.20GHz"
machine_desired = "AMD EPYC 7B12"

if (on_Colab == True):
    if info_cpu['brand_raw'] != machine_desired:
      print(f"Machine is: {info_cpu['brand_raw']}. RESTARTING VM")
      print("You can ignore the error message [Your session crashed for an unknown reason.]")
      time.sleep(0.5)
      os._exit(0)  # restart
    else:
      print(f"Found desired machine: {machine_desired}")
# Out:
# python_version:  3.11.12.final.0 (64 bit)
# cpuinfo_version:  [9, 0, 0]
# cpuinfo_version_string:  9.0.0
# arch:  X86_64
# bits:  64
# count:  8
# arch_string_raw:  x86_64
# vendor_id_raw:  AuthenticAMD
# brand_raw:  AMD EPYC 7B12
# hz_advertised_friendly:  2.2500 GHz
# hz_actual_friendly:  2.2500 GHz
# hz_advertised:  [2249998000, 0]
# hz_actual:  [2249998000, 0]
# model:  49
# family:  23
# flags:  ['3dnowext', '3dnowprefetch', 'abm', 'adx', 'aes', 'apic', 'arat', 'avx', 'avx2', 'bmi1', 'bmi2', 'clflush', 'clflushopt', 'clwb', 'clzero', 'cmov', 'cmp_legacy', 'constant_tsc', 'cpuid', 'cr8_legacy', 'cx16', 'cx8', 'de', 'extd_apicid', 'f16c', 'fma', 'fpu', 'fsgsbase', 'fxsr', 'fxsr_opt', 'ht', 'hypervisor', 'ibpb', 'ibrs', 'lahf_lm', 'lm', 'mca', 'mce', 'misalignsse', 'mmx', 'mmxext', 'movbe', 'msr', 'mtrr', 'nonstop_tsc', 'nopl', 'npt', 'nrip_save', 'nx', 'osvw', 'osxsave', 'pae', 'pat', 'pclmulqdq', 'pdpe1gb', 'pge', 'pni', 'popcnt', 'pse', 'pse36', 'rdpid', 'rdrand', 'rdrnd', 'rdseed', 'rdtscp', 'rep_good', 'sep', 'sha', 'sha_ni', 'smap', 'smep', 'ssbd', 'sse', 'sse2', 'sse4_1', 'sse4_2', 'sse4a', 'ssse3', 'stibp', 'syscall', 'topoext', 'tsc', 'tsc_adjust', 'tsc_known_freq', 'umip', 'vme', 'vmmcall', 'x2apic', 'xgetbv1', 'xsave', 'xsavec', 'xsaveerptr', 'xsaveopt']
# l3_cache_size:  524288
# l2_cache_size:  2097152
# l1_data_cache_size:  131072
# l1_instruction_cache_size:  131072
# l2_cache_line_size:  512
# l2_cache_associativity:  6
# Found desired machine: AMD EPYC 7B12

# %%
current_wd = os.getcwd()
print(current_wd)
output_extension = "PEA_linear_Colab_3"
output_folder = output_extension + "/"
print(output_folder)

# Create folder if does not exist:
if not os.path.exists(output_folder):
    # If it doesn't exist, create it
    os.makedirs(output_folder)

# Create folder to save models
output_folder_models = output_folder + '/models/'
if not os.path.exists(output_folder_models):
    # If it doesn't exist, create it
    os.makedirs(output_folder_models)

if on_Colab == True:
    # Mount gdrive
    from google.colab import drive
    drive.mount('/gdrive')
    # For final save
    g_drive_path = '/gdrive/My Drive/bc_MC_PEA/4.Linear_Expectations/'
    # Small test
    with open(g_drive_path + 'fooHello.txt', 'w') as f:
        f.write('Hello Google Drive!')

    # Autosave every 60 seconds
    # %autosave 60
# Out:
# /content
# PEA_linear_Colab_3/
# Mounted at /gdrive
# Autosaving every 60 seconds

# %%
# Load functions
plot_scale = 0.75
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)
# Controlling fontsizes
SMALL_SIZE = 12
MEDIUM_SIZE = SMALL_SIZE + 2
BIGGER_SIZE =  SMALL_SIZE + 4
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
dpi_chosen=600 #control the quality of .png
linewidth_chosen = 2

# %%
M_chosen = 200 #200 #200 #100 #Nb draws state vector
N_chosen = 2 #Nb draws innovation vector for each realization of the state vector

x_bar_chosen = 0
rho_x_chosen = 0.8
std_e_chosen = 0.1 #0.025 #0.05

# In Cagan's model, a = alpha/(1+alpha) and b = 1/(1+alpha)
# In An alternate method of estimating the Cagan money demand function in hyperinflation under rational expectations, Marvin S. Goodfriend (1982)
# the author finds value 3 - 8. Let's take 4.
alpha_Cagan = 4
a_chosen = alpha_Cagan/(alpha_Cagan + 1)
b_chosen = 1/(alpha_Cagan + 1)

# Use random sampling, or randomized low discrepancy sequence for integration with respect to the innovation vector?
low_discrepancy_chosen = True #when True, randomized low discrepancy sequence is used.

params = MyParams(N_chosen, M_chosen, x_bar_chosen, rho_x_chosen, std_e_chosen, a_chosen, b_chosen, low_discrepancy_chosen)
show_params(params)
# Out:
# M: 200
# N: 2
# x_bar: 0
# rho_x: 0.8
# std_e: 0.1
# mean_x: 0
# std_x: 0.1666666666666667
# a: 0.8
# b: 0.2
# low_discrepancy: True

# %% [markdown]
# ### II.B. Standard PEA
#
# PEA for $y_t = a E_t[y_{t+1}] + b x_t$
#
# with $x_{t+1} = \rho x_t + (1 - \rho) \bar{x} + \varepsilon_{t+1}$
#
# Approximates $E_t[y_{t+1}] ≈ \theta_0 + \theta_1 * x_t$

# %%
# Analytic solutions:
def analytic_coefs_yt(a, b, rho, xbar):
    """
    Analytic no-bubble solution parameters for y_{t} = theta0_tilde + theta1_tilde * x_t.
    Valid for x_{t+1} = rho * x_t + (1 - rho) * xbar + eps_{t+1}.
    """
    theta1_tilde = b / (1 - a * rho)
    theta0_tilde = (a * b * (1 - rho) * xbar) / ((1 - a) * (1 - a * rho))
    return theta0_tilde, theta1_tilde

def analytic_theta(a, b, rho, xbar):
    """
    Analytic no-bubble solution parameters for E_t[y_{t+1}] = theta0 + theta1 * x_t.
    Valid for x_{t+1} = rho * x_t + (1 - rho) * xbar + eps_{t+1}.
    """
    theta1 = rho * b / (1 - a * rho)
    theta0 = xbar * b * (1 - rho) / ((1 - a)*(1 - a * rho))
    return theta0, theta1

# %%
# Generate draws
def generate_random_innovations(slong, std, sampler = None, random_permutations = False):
    """
    Generate 1-D innovations ~ N(0, std^2) of length slong.
    If `sampler` is None, random draws.
    Otherwise draw using `sampler.random(n_samples)`, where sampler is expected to be a low-discrepancy sampler.
    """
    if sampler is None:
        e = std * np.random.randn(slong)
    else:
        # 1. Draws from QMC
        e = sampler.random(slong).reshape(-1)
        # 2. Break serial correlation by shuffling
        if random_permutations == True:
            perm = np.random.default_rng().permutation(slong)
            e = e[perm]
    return e

def generate_random_arrays(slong, N, std, sampler = None, random_permutations = False):
    """
    Generate:
      • e: a 1-D array of length `slong` with entries ~ N(0, std^2)
      • E: a (slong × N) random matrix. Each ROW is a quasi Monte Carlo sample ~ N(0, std^2)
    """
    # vectorized draws in one go:
    if sampler is None:
        e = std * np.random.randn(slong)
        E = std * np.random.randn(slong, N)
    else:
        e = std * np.random.randn(slong) # Generate random draws, to push forward the simulation
        E = generate_random_innovations(slong * N, std, sampler, random_permutations).reshape(slong, N)

    return e, E

def generate_ld_sampler(params):
    """
    Generate a low-discrepancy sampler if params.low_discrepancy is True.
    Otherwise, returns None

    """
    # If low-discrepancy, build a sampler for innovation vectors
    if params.low_discrepancy == True:
        #sob = qmc.Sobol(d=1, scramble=True) ## Not needed
        ld_sampler = qmc.MultivariateNormalQMC(mean=[0], cov=[[params.std_e**2]])
    else:
        ld_sampler = None

    return ld_sampler


def gamma_k(k, K=50, c=0.5):
    """
    Compute step size γ_k for PEA update:
      γ_k = 1       if k ≤ K
      γ_k = K / k   if k > K

    Parameters:
    - k: iteration number (1-based integer)
    - K: threshold for full-weight updates (default 50)

    Returns:
    - γ_k: float
    """
    #return 1.0 if k <= K else K / k
    #return 1/(k**c)
    return 1.0 if k <= K else K/(k**c)

# %%
# PEA params
T=10000 #number of draws for the state vector. One innovation draw per shock.
burn=500 #burin period
tol=1e-6 #tolerance on two guesses for the parameter vector
max_iter=1000 #maximum number of iterations
gamma = 1.0 #1.0 #convex parameter for the update of guesses
new_shock_every= 1000 #draws new shocks every x iterations
time_varying_gamma = False #True # schedule for updates
seed=123 #seed number

# Initial guess for [theta0, theta1]
theta_init = np.array([0.25, 0.5]) #np.array([0.5, 1.0])

theta = theta_init.copy()
theta_hist = [theta.copy()] #store history for parameter vector
diff_hist = [] #store history of |theta^{n+1} - theta^{n}|

eps = generate_random_innovations(T+1, params.std_e) #rng.standard_normal(T + 1) * sigma_e #innovation draws
x = np.empty(T+1) #state vector

np.random.seed(seed)
check_val = 1000.0

for it in range(1, max_iter + 1):
    # redraw shocks
    if it % new_shock_every == 0:
         eps[:] = generate_random_innovations(T+1, params.std_e)

    # Simulate AR(1) x-path
    x[0] = params.mean_x
    for t in range(T):
        x[t + 1] = params.rho_x * x[t] + (1 - params.rho_x) * params.x_bar + eps[t + 1]

    # Simulate y-path using current theta
    y = np.zeros(T + 1)
    for t in range(T+1):
        Et_y = theta[0] + theta[1] * x[t]
        y[t] = params.a * Et_y + params.b * x[t]

    # OLS regression to update theta: E_{yt+1} = x'theta
    X = np.column_stack([np.ones(T), x[:-1]]) #remove last period
    Y = y[1:] #forward by one
    Xr, Yr = X[burn:], Y[burn:]
    theta_new, _, _, _ = np.linalg.lstsq(Xr, Yr, rcond=None)

    theta_hist.append(theta_new.copy())

    # Convergence check
    check_val = np.max(np.abs(theta_new - theta))
    diff_hist.append(check_val)
    if check_val < tol:
        print(f"PEA converged in {it} iterations. Tolerance: {check_val}")
        theta = theta_new
        break

    # Damped update
    theta = gamma * theta_new + (1 - gamma) * theta

    # Update gamma parameter:
    if time_varying_gamma == True:
      gamma = gamma_k(it)

else:
    print(f"Warning: PEA did not converge within max_iter: {max_iter}. Tolerance {check_val}. Update size: {gamma}")

# residual
Res = Yr - np.dot(Xr, theta)
MSE = np.mean(Res ** 2)

# 1. Plot histogram of residuals
plt.figure()
plt.hist(Res, bins=100)
plt.title('Residuals', fontname='Times', fontsize=12)
plt.show()

# Store values
theta_history = np.array(theta_hist)
theta_est = theta.copy()

# Compute analytic solution
theta0_true, theta1_true = analytic_theta(params.a, params.b, params.rho_x, params.x_bar)

# Print comparison
print(f"Estimated theta0 = {theta_est[0]:.6f}, analytic = {theta0_true:.6f}, error = {theta_est[0] - theta0_true:.2e}")
print(f"Estimated theta1 = {theta_est[1]:.6f}, analytic = {theta1_true:.6f}, error = {theta_est[1] - theta1_true:.2e}")

# Plot convergence of theta estimates
iterations = np.arange(len(theta_history))
plt.figure(figsize=(8, 4))
plt.plot(iterations, theta_history[:, 0], label=r'$\theta_0$ est')
plt.axhline(theta0_true, color='k', linestyle='--', label=r'$\theta_0$ true')
plt.plot(iterations, theta_history[:, 1], label=r'$\theta_1$ est')
plt.axhline(theta1_true, color='gray', linestyle='--', label=r'$\theta_1$ true')
plt.xlabel('Iteration')
plt.ylabel('Theta values')
plt.title('PEA Convergence: Estimated vs. True Theta')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(8, 4))
plt.plot(diff_hist)
plt.xlabel('Iteration')
plt.ylabel('Difference thetas')
plt.yscale('log')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times' not found.
# PEA converged in 50 iterations. Tolerance: 8.923105987626833e-07
# Estimated theta0 = -0.000085, analytic = 0.000000, error = -8.51e-05
# Estimated theta1 = 0.436904, analytic = 0.444444, error = -7.54e-03

# %% [markdown]
# ## II.C. bc-MC-PEA
#
# Use multiple innovation draws per realization of the state vector.

# %%
@njit
def simulate_path_N_inplace(
    M: int, #number of draws in the state space
    N: int, #number of innovation draws, per state vector draw
    init: int, #number of draws discarded
    mean_x: float, #value value for x
    std_x: float, # std dev. for x
    rho_x: float, #persistence parameter for x
    x_bar: float, #mean for x
    a: float,
    b: float,
    e: np.ndarray, #i.i.d. draws for innovation
    E: np.ndarray, #extra draws for innovation
    b0: np.ndarray, #parameter vector
    nb_expl_vars: int,
    basis: int,
    x: np.ndarray,
    y: np.ndarray,
    X: np.ndarray,
    y_temp: np.ndarray
) -> None:
    """
    Simulates one path using a Parameterized Expectations Algorithm (PEA)
    with in-place mutation of pre-allocated arrays. JIT-compiled with numba for maximum performance.

    All outputs are written directly into the provided arrays; no value is returned.
    """
    slong = M + init

    # Set value for constant vector
    X[:, 0] = 1.0

    # Unpack coefficients for inlined dot-products
    b0_0 = b0[0]; b0_1 = b0[1]

    # Initialize state
    x[0] = mean_x
    # Simulate AR(1) x-path
    for t in range(1, slong):
        x[t] = rho_x * x[t-1] + (1 - rho_x) * x_bar + e[t]

    for i in range(0, slong):
        # Fill in X[i] for OLS regression y = X*b
        X[i, 1] = x[i]

        # Only do multi-innovation MC for i >= init. No need for burnin phase.
        if i >= init:
            # Monte Carlo expectation
            for j in range(N):
                # forward the state by one period, using different innovations
                x_next = rho_x * x[i] + (1 - rho_x) * x_bar + E[i, j]

                # Linear model for conditional expectation
                ## E_t[y_{t+1}], for several realization of the innovation vector
                #
                # E_t[y_{t+1}] = b0_0 + b0_1 * x_t, and y_t = a E_t[y_{t+1}] + b * x_t
                # gives: y_t = a (b0_0 + b0_1 * x_t) + b * x_t
                y_temp[j] = a * b0_0 + (a*b0_1 + b)* x_next

            # Final aggregation, to calculate Et_{yt+1} as an average
            s = 0.0
            for j in range(N):
                s += y_temp[j]

            y[i] = (s / N)

#@njit
def calculate_MSIE(
    slong: int, #number of draws in the state space
    init: int, #number of draws discarded
    mean_x: float, #value value for x
    std_x: float, # std dev. for x
    rho_x: float, #persistence parameter for x
    x_bar: float, #mean for x
    e: np.ndarray, #i.i.d. draws for innovation
    b0_true: np.ndarray, #True parameter vector
    b0: np.ndarray, #Estimate parameter vector
):
    """
    Calculate mean squared integration error using Monte Carlo integration.
    """
    MSIE_array = np.zeros(slong)
    x = np.zeros(slong+1)

    # Unpack coefficients for inlined dot-products
    b0_0_diff = b0_true[0] - b0[0]
    b0_1_diff = b0_true[1] - b0[1]

    # Initialize state
    x[0] = mean_x
    # Simulate AR(1) x-path
    for t in range(1, slong):
        x[t] = rho_x * x[t-1] + (1 - rho_x) * x_bar + e[t]

    # Calculate squared integration error:
    for t in range(0, slong):
        MSIE_array[t] = (b0_0_diff + b0_1_diff * x[t])**2

    MSIE = np.mean(MSIE_array[init:-1]) #remove last observation
    return MSIE

def calculate_MSIE_analytic(
    mean_x: float, #value value for x
    std_x: float, # std dev. for x
    rho_x: float, #persistence parameter for x
    x_bar: float, #mean for x
    b0_true: np.ndarray, #True parameter vector
    b0: np.ndarray, #Estimate parameter vector
):
    """
    Calculate mean squared integration error using analytic formula
    """
    # Unpack coefficients for inlined dot-products
    Δ0  = b0_true[0] - b0[0]
    Δ1  = b0_true[1] - b0[1]

    # Obtained by expanding the square and using the fact that x_t is AR(1)
    MSIE = (Δ0**2 + 2*Δ0*Δ1*x_bar + Δ1**2*(x_bar**2 + std_x**2))

    return MSIE

# %% [markdown]
# ### Change $N$, while keeping $M$ fixed

# %%
# %%time

# --------------------------------------------------------------------------
# Main code (outside numba) to run the PEA iterations.
# --------------------------------------------------------------------------
list_N = [1, 2, 5, 10, 25, 50, 100, 250, 500]
MSE_N = np.zeros(len(list_N)) #In-sample
MSIE_N = np.zeros(len(list_N)) #Mean square integration error, out-sample
MSIE_N_analytic = np.zeros(len(list_N)) #Mean square integration error, out-sample
Time_N = np.zeros(len(list_N))

M = 10000
init = 100
slong = init + M

# Compute analytic solution
theta0_true, theta1_true = analytic_theta(params.a, params.b, params.rho_x, params.x_bar)
b0_true = np.array([theta0_true, theta1_true])

# To store errors on parameter vector
list_err_theta0 = []
list_err_theta1 = []

tol = 1e-8
gam = 1.0  # smoothing parameter
max_iter = 100 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

slong_test = 100000
init_test = 100
e_test =  generate_random_innovations(slong_test, params.std_e)

np.random.seed(1)
#for N in range(1, max_N+1):
for (index_N, N) in enumerate(list_N):
    print("Running simulation with N =", N)

    b0_current = theta_init.copy()  # initial guess (shape (6,))

    # Generate a ld sampler. If random draws, ld_sampler is None
    ld_sampler = generate_ld_sampler(params)

    # innovation for state vector
    e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

    # Preallocate arrays
    x = np.zeros(slong+1)
    y_out      = np.zeros(slong)        # simulated y
    X_data      = np.zeros((slong, params.nb_expl_vars))   # regressor matrix
    y_temp = np.zeros(N)            # temporary array for innovations

    # Warmup (compilation) first go
    simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                        params.a, params.b, e, E, b0_current,
                        params.nb_expl_vars, params.basis,
                        x, y_out, X_data,y_temp)

    start_time = time.perf_counter()
    iter_num = 1
    crit = 1.0
    # Run a fixed number of iterations (or use while crit > tol)
    while iter_num < max_iter:
        if iter_num % redraw_shocks_every == 0:
            e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

        # Call the numba-compiled simulation to get regression data.
        simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                        params.a, params.b, e, E, b0_current,
                        params.nb_expl_vars, params.basis,
                        x, y_out, X_data, y_temp)

        # Remove burnin
        X_reg = X_data[init:, :]
        y_reg = y_out[init:]

        # OLS
        bt, _, _, _ = np.linalg.lstsq(X_reg, y_reg, rcond=None)

        # Parameter update
        b_new = gam * bt + (1 - gam) * b0_current
        crit = np.max(np.abs(b_new - b0_current))
        b0_current = b_new.copy()
        if iter_num % 10 == 0:
            print("Iteration:", iter_num, "Conv. crit.:", crit)
        iter_num += 1

    end_time = time.perf_counter()
    elapsed = end_time - start_time
    print("Elapsed time for N =", N, ":", elapsed, "seconds")

    # Compute residuals and In-sample MSE.
    Res = y_reg - np.dot(X_reg, b0_current)
    MSE = np.mean(Res ** 2)
    MSE_N[index_N] = MSE

    # Error on parameter values:
    err_theta0 = b0_current[0] - theta0_true
    err_theta1 = b0_current[1] - theta1_true
    list_err_theta0.append(err_theta0)
    list_err_theta1.append(err_theta1)

    MSIE_N[index_N] = calculate_MSIE(slong_test, init_test, params.mean_x,
               params.std_x, params.rho_x, params.x_bar,
               e_test, b0_true, b0_current)

    MSIE_N_analytic[index_N] = calculate_MSIE_analytic(params.mean_x,
               params.std_x, params.rho_x, params.x_bar,
               b0_true, b0_current)

    Time_N[index_N] = elapsed
    print("Final iteration N:", N, "Iterations:", iter_num, "OLS MSE:", MSE)
    print("Final b0:", b0_current)
# Out:
# Running simulation with N = 1
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_qmc.py:993: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# Iteration: 10 Conv. crit.: 0.006709375195826529
# Iteration: 20 Conv. crit.: 0.0007204178970995163
# Iteration: 30 Conv. crit.: 7.735432763783485e-05
# Iteration: 40 Conv. crit.: 8.305858163893458e-06
# Iteration: 50 Conv. crit.: 8.918347345814937e-07
# Iteration: 60 Conv. crit.: 9.576002551343595e-08
# Iteration: 70 Conv. crit.: 1.028215444558167e-08
# Iteration: 80 Conv. crit.: 1.1040379254123036e-09
# Iteration: 90 Conv. crit.: 1.1854516779557893e-10
# Elapsed time for N = 1 : 0.030019048999974984 seconds
# Final iteration N: 1 Iterations: 100 OLS MSE: 0.002998147170644293
# Final b0: [6.17984855e-05 4.34815788e-01]
# Running simulation with N = 2
# Iteration: 10 Conv. crit.: 0.006710514096542077
# Iteration: 20 Conv. crit.: 0.0007205368607824387
# Iteration: 30 Conv. crit.: 7.736706690080305e-05
# Iteration: 40 Conv. crit.: 8.307225678182448e-06
# Iteration: 50 Conv. crit.: 8.919815666821677e-07
# Iteration: 60 Conv. crit.: 9.57757914607808e-08
# Iteration: 70 Conv. crit.: 1.0283847304381384e-08
# Iteration: 80 Conv. crit.: 1.1042196939766693e-09
# Iteration: 90 Conv. crit.: 1.1856468889974024e-10
# Elapsed time for N = 2 : 0.029835389000027135 seconds
# Final iteration N: 2 Iterations: 100 OLS MSE: 0.0008567574349784856
# Final b0: [1.49411310e-05 4.47446906e-01]
# Running simulation with N = 5
# Iteration: 10 Conv. crit.: 0.0067101228165885145
# Iteration: 20 Conv. crit.: 0.0007204958034370203
# Iteration: 30 Conv. crit.: 7.736266959657739e-05
# Iteration: 40 Conv. crit.: 8.30675365231731e-06
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_qmc.py:993: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# Iteration: 50 Conv. crit.: 8.919308848294203e-07
# Iteration: 60 Conv. crit.: 9.577034954852658e-08
# Iteration: 70 Conv. crit.: 1.0283262981262455e-08
# Iteration: 80 Conv. crit.: 1.1041569554422767e-09
# Iteration: 90 Conv. crit.: 1.1855794505041903e-10
# Elapsed time for N = 5 : 0.03360339899995779 seconds
# Final iteration N: 5 Iterations: 100 OLS MSE: 0.00040956387784186836
# Final b0: [3.06689184e-05 4.46890941e-01]
# Running simulation with N = 10
# Iteration: 10 Conv. crit.: 0.006710862289492341
# Iteration: 20 Conv. crit.: 0.0007205734118775585
# Iteration: 30 Conv. crit.: 7.737098165573592e-05
# Iteration: 40 Conv. crit.: 8.30764590480314e-06
# Iteration: 50 Conv. crit.: 8.920266867927226e-07
# Iteration: 60 Conv. crit.: 9.578063617307451e-08
# Iteration: 70 Conv. crit.: 1.028436749860602e-08
# Iteration: 80 Conv. crit.: 1.1042755507023083e-09
# Iteration: 90 Conv. crit.: 1.1857068195155074e-10
# Elapsed time for N = 10 : 0.03760821900004885 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 4.332536233151526e-05
# Final b0: [9.71836581e-07 4.44529719e-01]
# Running simulation with N = 25
# Iteration: 10 Conv. crit.: 0.0067109535825355705
# Iteration: 20 Conv. crit.: 0.00072058298520862
# Iteration: 30 Conv. crit.: 7.737200694527029e-05
# Iteration: 40 Conv. crit.: 8.307755964036006e-06
# Iteration: 50 Conv. crit.: 8.920385039609892e-07
# Iteration: 60 Conv. crit.: 9.578190502907896e-08
# Iteration: 70 Conv. crit.: 1.0284503744865884e-08
# Iteration: 80 Conv. crit.: 1.1042901833474557e-09
# Iteration: 90 Conv. crit.: 1.1857225336516866e-10
# Elapsed time for N = 25 : 0.048620279000033406 seconds
# Final iteration N: 25 Iterations: 100 OLS MSE: 7.401215551283483e-06
# Final b0: [-2.70902045e-06  4.44207196e-01]
# Running simulation with N = 50
# Iteration: 10 Conv. crit.: 0.00671091077326328
# Iteration: 20 Conv. crit.: 0.0007205784964450564
# Iteration: 30 Conv. crit.: 7.73715262070583e-05
# Iteration: 40 Conv. crit.: 8.307704359400463e-06
# Iteration: 50 Conv. crit.: 8.920329631197645e-07
# Iteration: 60 Conv. crit.: 9.578131008763537e-08
# Iteration: 70 Conv. crit.: 1.0284439859366401e-08
# Iteration: 80 Conv. crit.: 1.1042833236581204e-09
# Iteration: 90 Conv. crit.: 1.1857151548406337e-10
# Elapsed time for N = 50 : 0.06825853700001971 seconds
# Final iteration N: 50 Iterations: 100 OLS MSE: 3.146793729551634e-06
# Final b0: [-9.82283780e-07  4.44540597e-01]
# Running simulation with N = 100
# Iteration: 10 Conv. crit.: 0.006710888018462764
# Iteration: 20 Conv. crit.: 0.000720576110105457
# Iteration: 30 Conv. crit.: 7.737127063279256e-05
# Iteration: 40 Conv. crit.: 8.307676924906693e-06
# Iteration: 50 Conv. crit.: 8.920300174462864e-07
# Iteration: 60 Conv. crit.: 9.578099379835976e-08
# Iteration: 70 Conv. crit.: 1.028440589920277e-08
# Iteration: 80 Conv. crit.: 1.10427967473701e-09
# Iteration: 90 Conv. crit.: 1.1857112595669257e-10
# Elapsed time for N = 100 : 0.11905325499992614 seconds
# Final iteration N: 100 Iterations: 100 OLS MSE: 4.3676404107886506e-07
# Final b0: [-6.51762552e-08  4.44448600e-01]
# Running simulation with N = 250
# Iteration: 10 Conv. crit.: 0.006710885200788875
# Iteration: 20 Conv. crit.: 0.0007205758146191683
# Iteration: 30 Conv. crit.: 7.737123898658537e-05
# Iteration: 40 Conv. crit.: 8.307673527862437e-06
# Iteration: 50 Conv. crit.: 8.920296527035482e-07
# Iteration: 60 Conv. crit.: 9.578095463760886e-08
# Iteration: 70 Conv. crit.: 1.028440169326571e-08
# Iteration: 80 Conv. crit.: 1.1042792245521938e-09
# Iteration: 90 Conv. crit.: 1.185710768929179e-10
# Elapsed time for N = 250 : 0.31253078800000367 seconds
# Final iteration N: 250 Iterations: 100 OLS MSE: 1.0942749980473059e-08
# Final b0: [4.84030002e-08 4.44457251e-01]
# Running simulation with N = 500
# Iteration: 10 Conv. crit.: 0.0067108801998882125
# Iteration: 20 Conv. crit.: 0.0007205752901851287
# Iteration: 30 Conv. crit.: 7.737118282038927e-05
# Iteration: 40 Conv. crit.: 8.307667498725428e-06
# Iteration: 50 Conv. crit.: 8.920290053560784e-07
# Iteration: 60 Conv. crit.: 9.578088512471153e-08
# Iteration: 70 Conv. crit.: 1.0284394231527524e-08
# Iteration: 80 Conv. crit.: 1.1042784191466675e-09
# Iteration: 90 Conv. crit.: 1.1857099127935393e-10
# Elapsed time for N = 500 : 0.6996385630000077 seconds
# Final iteration N: 500 Iterations: 100 OLS MSE: 1.2838952259745849e-08
# Final b0: [2.49996105e-07 4.44429241e-01]
# CPU times: user 3.15 s, sys: 141 ms, total: 3.29 s
# Wall time: 3.49 s

# %%
ref_index = 0
plt.scatter(list_N, np.sqrt(MSE_N), label="data")
plt.plot(list_N, np.sqrt(MSE_N))
plt.plot(list_N, np.sqrt(MSE_N[ref_index]*(list_N[ref_index]/np.array(list_N))), label="O(1/sqrt(N))")
plt.plot(list_N, np.sqrt(MSE_N[ref_index])*(list_N[ref_index]/np.array(list_N)), label="O(1/N)")
plt.title("Squares root mean squared error")
plt.legend()
plt.savefig(output_folder + "MSE_N.pdf", dpi=300)
plt.show()

# %%
plt.scatter(list_N, np.sqrt(MSIE_N), label="data")
plt.plot(list_N, np.sqrt(MSIE_N_analytic), label="data (analytic)", linestyle="--")
plt.plot(list_N, np.sqrt(MSIE_N))
plt.plot(list_N, np.sqrt(MSIE_N[0]*(list_N[0]/np.array(list_N))), label="O(1/sqrt(N))")
plt.plot(list_N, np.sqrt(MSIE_N[ref_index])*(list_N[ref_index]/np.array(list_N)), label="O(1/N)")
plt.title("Square root mean square integration error")
plt.legend()
plt.savefig(output_folder + "MSIE_N.pdf", dpi=300)
plt.show()

# %%
ref_index = 0
plt.plot(list_N, np.abs(list_err_theta0), label="error theta_0")
plt.plot(list_N, np.abs(list_err_theta1), label="error theta_1")
#plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# ### Change $M$, while keeping $N$ fixed

# %%
# %%time

# --------------------------------------------------------------------------
# Main code (outside numba) to run the PEA iterations.
# --------------------------------------------------------------------------
list_M = [100, 200, 500, 1000, 2000, 2500, 5000, 10000, 20000, 100000]
MSE_M = np.zeros(len(list_M)) #In-sample
MSIE_M = np.zeros(len(list_M)) #Mean square integration error, out-sample
Time_M = np.zeros(len(list_M))

N = 10 #fix number of innovation draws
init = 100 #burnin

# Compute analytic solution
theta0_true, theta1_true = analytic_theta(params.a, params.b, params.rho_x, params.x_bar)
b0_true = np.array([theta0_true, theta1_true])

# To store errors on parameter vector
list_err_theta0 = []
list_err_theta1 = []

tol = 1e-8
gam = 1.0  # smoothing parameter
max_iter = 100 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

slong_test = 100000
init_test = 100
e_test =  generate_random_innovations(slong_test, params.std_e)

np.random.seed(1)
#for N in range(1, max_N+1):
for (index_M, M) in enumerate(list_M):
    print("Running simulation with M =", M)

    slong = init + M

    b0_current = theta_init.copy()  # initial guess

    # Generate a ld sampler. If random draws, ld_sampler is None
    ld_sampler = generate_ld_sampler(params)

    # innovation for state vector
    e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

    # Preallocate arrays
    x = np.zeros(slong+1)
    y_out      = np.zeros(slong)        # simulated y
    X_data      = np.zeros((slong, params.nb_expl_vars))   # regressor matrix
    y_temp = np.zeros(N)            # temporary array for innovations

    # Warmup (compilation) first go
    simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                        params.a, params.b, e, E, b0_current,
                        params.nb_expl_vars, params.basis,
                        x, y_out, X_data,y_temp)

    start_time = time.perf_counter()
    iter_num = 1
    crit = 1.0
    # Run a fixed number of iterations (or use while crit > tol)
    while iter_num < max_iter:
        if iter_num % redraw_shocks_every == 0:
            e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

        # Call the numba-compiled simulation to get regression data.
        simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                        params.a, params.b, e, E, b0_current,
                        params.nb_expl_vars, params.basis,
                        x, y_out, X_data,y_temp)

        # Remove burnin
        X_reg = X_data[init:, :]
        y_reg = y_out[init:]

        # OLS
        bt, _, _, _ = np.linalg.lstsq(X_reg, y_reg, rcond=None)

        # Parameter update
        b_new = gam * bt + (1 - gam) * b0_current
        crit = np.max(np.abs(b_new - b0_current))
        b0_current = b_new.copy()
        if iter_num % 10 == 0:
            print("Iteration:", iter_num, "Conv. crit.:", crit)
        iter_num += 1

    end_time = time.perf_counter()
    elapsed = end_time - start_time
    print("Elapsed time for N =", N, ":", elapsed, "seconds")
    # Compute residuals and In-sample MSE.
    Res = y_reg - np.dot(X_reg, b0_current)
    MSE = np.mean(Res ** 2)
    MSE_M[index_M] = MSE

    # Error on parameter values:
    err_theta0 = b0_current[0] - theta0_true
    err_theta1 = b0_current[1] - theta1_true
    list_err_theta0.append(err_theta0)
    list_err_theta1.append(err_theta1)

    MSIE_M[index_M] = calculate_MSIE_analytic(params.mean_x,
               params.std_x, params.rho_x, params.x_bar,
               b0_true, b0_current)


    Time_M[index_M] = elapsed
    print("Final iteration N:", N, "Iterations:", iter_num, "OLS MSE:", MSE)
    print("Final b0:", b0_current)
# Out:
# Running simulation with M = 100
# Iteration: 10 Conv. crit.: 0.006701752242870153
# Iteration: 20 Conv. crit.: 0.0007196196102703528
# Iteration: 30 Conv. crit.: 7.726883662624801e-05
# Iteration: 40 Conv. crit.: 8.296681125561961e-06
# Iteration: 50 Conv. crit.: 8.908493851933919e-07
# Iteration: 60 Conv. crit.: 9.565422473767566e-08
# Iteration: 70 Conv. crit.: 1.0270794177983083e-08
# Iteration: 80 Conv. crit.: 1.1028181273460384e-09
# Iteration: 90 Conv. crit.: 1.1841420557859653e-10
# Elapsed time for N = 10 : 0.0036339699997824937 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 4.587466376537314e-05
# Final b0: [3.71241110e-04 4.38914356e-01]
# Running simulation with M = 200
# Iteration: 10 Conv. crit.: 0.006714106556560823
# Iteration: 20 Conv. crit.: 0.0007209141539751681
# Iteration: 30 Conv. crit.: 7.740747737512235e-05
# Iteration: 40 Conv. crit.: 8.311563510000092e-06
# Iteration: 50 Conv. crit.: 8.924473233453886e-07
# Iteration: 60 Conv. crit.: 9.582580152631397e-08
# Iteration: 70 Conv. crit.: 1.028921708246108e-08
# Iteration: 80 Conv. crit.: 1.1047962749722098e-09
# Iteration: 90 Conv. crit.: 1.18626593574242e-10
# Elapsed time for N = 10 : 0.0037538990000030026 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 4.4289583609958275e-05
# Final b0: [-1.28875358e-04  4.49308138e-01]
# Running simulation with M = 500
# Iteration: 10 Conv. crit.: 0.006707747812281773
# Iteration: 20 Conv. crit.: 0.0007202469051213723
# Iteration: 30 Conv. crit.: 7.733601365543204e-05
# Iteration: 40 Conv. crit.: 8.303892277705964e-06
# Iteration: 50 Conv. crit.: 8.916236559619313e-07
# Iteration: 60 Conv. crit.: 9.573736120793144e-08
# Iteration: 70 Conv. crit.: 1.0279720883793171e-08
# Iteration: 80 Conv. crit.: 1.1037766303983575e-09
# Iteration: 90 Conv. crit.: 1.185171155280388e-10
# Elapsed time for N = 10 : 0.004888319999963642 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 7.173171316150551e-06
# Final b0: [1.26712329e-04 4.43402871e-01]
# Running simulation with M = 1000
# Iteration: 10 Conv. crit.: 0.006710294882838037
# Iteration: 20 Conv. crit.: 0.000720513899856768
# Iteration: 30 Conv. crit.: 7.736460795380325e-05
# Iteration: 40 Conv. crit.: 8.306961723035645e-06
# Iteration: 50 Conv. crit.: 8.919532255232734e-07
# Iteration: 60 Conv. crit.: 9.577274835692934e-08
# Iteration: 70 Conv. crit.: 1.0283520555558819e-08
# Iteration: 80 Conv. crit.: 1.1041846217270672e-09
# Iteration: 90 Conv. crit.: 1.1856091849520587e-10
# Elapsed time for N = 10 : 0.0072533099998963735 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 3.5936136716234526e-06
# Final b0: [2.38275822e-05 4.44913495e-01]
# Running simulation with M = 2000
# Iteration: 10 Conv. crit.: 0.006710034838594482
# Iteration: 20 Conv. crit.: 0.000720486671932404
# Iteration: 30 Conv. crit.: 7.736169206506728e-05
# Iteration: 40 Conv. crit.: 8.306648716897418e-06
# Iteration: 50 Conv. crit.: 8.919196176836278e-07
# Iteration: 60 Conv. crit.: 9.576913975274713e-08
# Iteration: 70 Conv. crit.: 1.028313307882599e-08
# Iteration: 80 Conv. crit.: 1.1041430069238297e-09
# Iteration: 90 Conv. crit.: 1.1855645474677032e-10
# Elapsed time for N = 10 : 0.010121429999799147 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 3.393757954644587e-05
# Final b0: [3.43898411e-05 4.43202805e-01]
# Running simulation with M = 2500
# Iteration: 10 Conv. crit.: 0.006711243837456096
# Iteration: 20 Conv. crit.: 0.0007206133972282262
# Iteration: 30 Conv. crit.: 7.737526392207568e-05
# Iteration: 40 Conv. crit.: 8.30810558367264e-06
# Iteration: 50 Conv. crit.: 8.920760430083491e-07
# Iteration: 60 Conv. crit.: 9.578593573882736e-08
# Iteration: 70 Conv. crit.: 1.0284936530338467e-08
# Iteration: 80 Conv. crit.: 1.1043366523165194e-09
# Iteration: 90 Conv. crit.: 1.185772446774875e-10
# Elapsed time for N = 10 : 0.01184901900001023 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 8.440410432662174e-05
# Final b0: [-1.4459841e-05  4.4203779e-01]
# Running simulation with M = 5000
# Iteration: 10 Conv. crit.: 0.006710437906954428
# Iteration: 20 Conv. crit.: 0.0007205289140330196
# Iteration: 30 Conv. crit.: 7.736621602270709e-05
# Iteration: 40 Conv. crit.: 8.307134339958401e-06
# Iteration: 50 Conv. crit.: 8.919717595525211e-07
# Iteration: 60 Conv. crit.: 9.5774738429126e-08
# Iteration: 70 Conv. crit.: 1.0283734233975278e-08
# Iteration: 80 Conv. crit.: 1.1042075541073458e-09
# Iteration: 90 Conv. crit.: 1.185633842148916e-10
# Elapsed time for N = 10 : 0.02004955899997185 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 4.5965104760024296e-05
# Final b0: [1.80909952e-05 4.43991209e-01]
# Running simulation with M = 10000
# Iteration: 10 Conv. crit.: 0.006710899131419416
# Iteration: 20 Conv. crit.: 0.0007205772756821581
# Iteration: 30 Conv. crit.: 7.737139546537276e-05
# Iteration: 40 Conv. crit.: 8.307690324999096e-06
# Iteration: 50 Conv. crit.: 8.920314562284654e-07
# Iteration: 60 Conv. crit.: 9.57811482868467e-08
# Iteration: 70 Conv. crit.: 1.0284422482959244e-08
# Iteration: 80 Conv. crit.: 1.1042814562613328e-09
# Iteration: 90 Conv. crit.: 1.185713177494099e-10
# Elapsed time for N = 10 : 0.037869718000138164 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 8.11920167874814e-05
# Final b0: [-5.12813095e-07  4.44875068e-01]
# Running simulation with M = 20000
# Iteration: 10 Conv. crit.: 0.006710851271606692
# Iteration: 20 Conv. crit.: 0.000720572256335815
# Iteration: 30 Conv. crit.: 7.73708578981856e-05
# Iteration: 40 Conv. crit.: 8.307632620110777e-06
# Iteration: 50 Conv. crit.: 8.920252604016535e-07
# Iteration: 60 Conv. crit.: 9.578048301824533e-08
# Iteration: 70 Conv. crit.: 1.028435105597873e-08
# Iteration: 80 Conv. crit.: 1.1042737852162897e-09
# Iteration: 90 Conv. crit.: 1.185704966368355e-10
# Elapsed time for N = 10 : 0.07026952699993672 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 4.58710802709991e-06
# Final b0: [1.41576127e-06 4.44601536e-01]
# Running simulation with M = 100000
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_qmc.py:993: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# Iteration: 10 Conv. crit.: 0.006710870072346019
# Iteration: 20 Conv. crit.: 0.0007205742281784886
# Iteration: 30 Conv. crit.: 7.73710690810773e-05
# Iteration: 40 Conv. crit.: 8.307655289430357e-06
# Iteration: 50 Conv. crit.: 8.920276944251936e-07
# Iteration: 60 Conv. crit.: 9.578074436473368e-08
# Iteration: 70 Conv. crit.: 1.028437911524054e-08
# Iteration: 80 Conv. crit.: 1.1042767983690282e-09
# Iteration: 90 Conv. crit.: 1.1857081669437562e-10
# Elapsed time for N = 10 : 0.3631015749999733 seconds
# Final iteration N: 10 Iterations: 100 OLS MSE: 7.51842613210991e-05
# Final b0: [6.58339902e-07 4.44334076e-01]
# CPU times: user 610 ms, sys: 10.2 ms, total: 620 ms
# Wall time: 617 ms

# %%
ref_index = 0
plt.scatter(list_M, np.sqrt(MSE_M), label="data")
plt.plot(list_M, np.sqrt(MSE_M))
plt.plot(list_M, np.sqrt(MSE_M[ref_index]*(list_M[ref_index]/np.array(list_M))), label="O(1/sqrt(M))")
plt.plot(list_M, np.sqrt(MSE_M[ref_index])*(list_M[ref_index]/np.array(list_M)), label="O(1/M)")
plt.title("Square root mean squared error")
plt.legend()
plt.savefig(output_folder + "MSE_M.pdf", dpi=300)
plt.show()

# %%
plt.scatter(list_M, np.sqrt(MSIE_M), label="data")
plt.plot(list_M, np.sqrt(MSIE_M))
plt.plot(list_M, np.sqrt(MSIE_M[0]*(list_M[0]/np.array(list_M))), label="O(1/sqrt(M))")
plt.plot(list_M, np.sqrt(MSIE_M[0])*(list_M[0]/np.array(list_M)), label="O(1/M)")
plt.title("Square root mean square integration error")
plt.legend()
plt.savefig(output_folder + "MSIE_M.pdf", dpi=300)
plt.show()

# %%
plt.scatter(list_M, np.abs(list_err_theta0), label="error theta_0")
plt.scatter(list_M, np.abs(list_err_theta1), label="error theta_0")
plt.title("Abs error coefficients")
plt.legend()
plt.yscale("log")
plt.xscale("log")
plt.show()

# %% [markdown]
# ### Change $M$ an $N$

# %%
# %%time

list_N = [1, 2, 5, 10, 25, 50, 100, 250, 500] #number of innovation draws, per state vector
list_M = [500, 1000, 5000, 10000, 20000, 50000] #number of state vector draws

# Create a dataframe, with all the combinations of list_N and list_M
idx = pd.MultiIndex.from_product([list_N, list_M], names=['N','M'])
df_MN_values = idx.to_frame(index=False)

# Add new specific values
new_rows = [
    {'N': 10000, 'M': 1000},
    {'N': 5000, 'M': 1000},
    {'N': 5000, 'M': 100},
    {'N': 100000, 'M': 10},
    {'N': 1000000, 'M': 10},
    {'N': 1, 'M': 100000},
    {'N': 1, 'M': 1000000},
    {'N': 100, 'M': 100000},
    {'N': 100, 'M': 200000}
]
extra_df = pd.DataFrame(new_rows)

# concat and reset the integer index
df_MN_values = pd.concat([df_MN_values, extra_df], ignore_index=True)


# Compute analytic solution
theta0_true, theta1_true = analytic_theta(params.a, params.b, params.rho_x, params.x_bar)
b0_true = np.array([theta0_true, theta1_true])

init = 100 #100 #burnin, train data

tol = 1e-8 # tolerance on parameter vector
gam = 1.0  # smoothing parameter between two iterations
max_iter = 100 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

slong_test = 100000
init_test = 100
nb_tot_reps = 5 #nb of repetitions, to smooth out randomness and potential issues with measuring timing

# to store restults
results = []
np.random.seed(42)

for idx, row in df_MN_values.iterrows():
    N = row['N']
    M = row['M']

    for nb_rep in range(nb_tot_reps):
        # Innovations for the out-sample test
        e_test = generate_random_innovations(slong_test, params.std_e)

        slong = init + M

        b0_current = theta_init.copy()

        # Generate a ld sampler. If random draws, ld_sampler is None
        ld_sampler = generate_ld_sampler(params)

        # innovation for state vector
        e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

        # Preallocate arrays
        x = np.zeros(slong+1)
        y_out      = np.zeros(slong)        # simulated y
        X_data      = np.zeros((slong, params.nb_expl_vars))   # regressor matrix
        y_temp = np.zeros(N)            # temporary array for innovations

        # Warmup (compilation) first go
        simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                            params.a, params.b, e, E, b0_current,
                            params.nb_expl_vars, params.basis,
                            x, y_out, X_data, y_temp)

        start_time = time.perf_counter()
        iter_num = 1
        crit = 1.0
        # Run a fixed number of iterations (or use while crit > tol)
        while iter_num < max_iter:
            if iter_num % redraw_shocks_every == 0:
                e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

            # Call the numba-compiled simulation to get regression data.
            simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                            params.a, params.b, e, E, b0_current,
                            params.nb_expl_vars, params.basis,
                            x, y_out, X_data, y_temp)

            # Remove burnin
            X_reg = X_data[init:, :]
            y_reg = y_out[init:]

            # OLS
            bt, _, _, _ = np.linalg.lstsq(X_reg, y_reg, rcond=None)

            # Parameter update
            b_new = gam * bt + (1 - gam) * b0_current
            crit = np.max(np.abs(b_new - b0_current))
            b0_current = b_new.copy()

            #print("Iteration:", iter_num, "Conv. crit.:", crit)
            iter_num += 1

        end_time = time.perf_counter()
        elapsed = end_time - start_time
        #print("Elapsed time for N =", N, ":", elapsed, "seconds")

        # Compute residuals and In-sample MSE.
        Res = y_reg - np.dot(X_reg, b0_current)
        MSE = np.mean(Res ** 2)

        # Error on parameter values:
        err_theta0 = np.abs(b0_current[0] - theta0_true)
        err_theta1 = np.abs(b0_current[1] - theta1_true)

        MSIE = calculate_MSIE_analytic(params.mean_x,
               params.std_x, params.rho_x, params.x_bar,
               b0_true, b0_current)

        if nb_rep == (nb_tot_reps-1):
            print(f"Final iteration (M, N): ({M}, {N}). Iterations: {iter_num} OLS MSE: {MSE} , MISE: {MSIE}")
            print("Final b0:", b0_current)

        # Store the results in a dictionary
        results.append({
            "repetition": nb_rep,
            "k": params.nb_expl_vars,
            "M": M,
            "N": N,
            "Time": elapsed,
            "MSE": MSE,
            "MSIE": MSIE,
            "err_theta0": err_theta0,
            "err_theta1": err_theta1,
            })

# Create a Pandas DataFrame from the results
df_results = pd.DataFrame(results)
df_results.to_csv(output_folder + "df_results.csv")
print(df_results.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_qmc.py:993: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# Final iteration (M, N): (500, 1). Iterations: 100 OLS MSE: 0.0030294519727762474 , MISE: 1.5987640754479276e-06
# Final b0: [8.66717572e-05 4.36875754e-01]
# Final iteration (M, N): (1000, 1). Iterations: 100 OLS MSE: 0.0031081204416004145 , MISE: 6.560838674522072e-07
# Final b0: [2.95801216e-04 4.48968721e-01]
# Final iteration (M, N): (5000, 1). Iterations: 100 OLS MSE: 0.0030574359324306386 , MISE: 2.9489461588431725e-07
# Final b0: [2.47741578e-05 4.41189585e-01]
# Final iteration (M, N): (10000, 1). Iterations: 100 OLS MSE: 0.003125987284537023 , MISE: 5.476842317335362e-07
# Final b0: [-1.52112000e-05  4.48883848e-01]
# Final iteration (M, N): (20000, 1). Iterations: 100 OLS MSE: 0.003095571368180839 , MISE: 2.9023612584116562e-08
# Final b0: [-1.06928904e-05  4.45464608e-01]
# Final iteration (M, N): (50000, 1). Iterations: 100 OLS MSE: 0.003063372158627514 , MISE: 1.831220671132693e-07
# Final b0: [1.42110590e-05 4.41878295e-01]
# Final iteration (M, N): (500, 2). Iterations: 100 OLS MSE: 0.0003622039993689115 , MISE: 1.7245128886454865e-06
# Final b0: [4.74138859e-05 4.36570339e-01]
# Final iteration (M, N): (1000, 2). Iterations: 100 OLS MSE: 0.000949132260157657 , MISE: 1.205554602697209e-06
# Final b0: [2.14481454e-04 4.37983494e-01]
# Final iteration (M, N): (5000, 2). Iterations: 100 OLS MSE: 0.00012793615582792605 , MISE: 5.6305890314844345e-09
# Final b0: [1.95204434e-05 4.44009722e-01]
# Final iteration (M, N): (10000, 2). Iterations: 100 OLS MSE: 5.835595933899075e-05 , MISE: 4.318973874351436e-08
# Final b0: [4.75286475e-06 4.43197842e-01]
# Final iteration (M, N): (20000, 2). Iterations: 100 OLS MSE: 0.0007707775710183279 , MISE: 1.1624702237409132e-08
# Final b0: [4.45931678e-06 4.45090798e-01]
# Final iteration (M, N): (50000, 2). Iterations: 100 OLS MSE: 0.0010279469761812598 , MISE: 4.216496607162346e-08
# Final b0: [6.52639498e-06 4.45675869e-01]
# Final iteration (M, N): (500, 5). Iterations: 100 OLS MSE: 0.0002640902954805676 , MISE: 1.3410107220903673e-06
# Final b0: [-9.06479606e-05  4.51371245e-01]
# Final iteration (M, N): (1000, 5). Iterations: 100 OLS MSE: 0.00026610154559076065 , MISE: 3.082509559056597e-08
# Final b0: [4.44101420e-05 4.43425277e-01]
# Final iteration (M, N): (5000, 5). Iterations: 100 OLS MSE: 0.00036581548714426836 , MISE: 7.571486108827538e-08
# Final b0: [2.25362174e-05 4.46089878e-01]
# Final iteration (M, N): (10000, 5). Iterations: 100 OLS MSE: 0.0002712077574871163 , MISE: 4.2249532330197367e-10
# Final b0: [-5.47825146e-06  4.44563312e-01]
# Final iteration (M, N): (20000, 5). Iterations: 100 OLS MSE: 0.0003055151475609382 , MISE: 2.562915485960778e-08
# Final b0: [7.15782197e-06 4.43484859e-01]
# Final iteration (M, N): (50000, 5). Iterations: 100 OLS MSE: 0.0002901001352122277 , MISE: 4.032244517849991e-08
# Final b0: [-1.44239399e-06  4.43239649e-01]
# Final iteration (M, N): (500, 10). Iterations: 100 OLS MSE: 8.824757566667355e-05 , MISE: 3.177110102822643e-07
# Final b0: [4.73722254e-05 4.41074458e-01]
# Final iteration (M, N): (1000, 10). Iterations: 100 OLS MSE: 2.0772830997705127e-05 , MISE: 1.4325040327299704e-09
# Final b0: [-1.06788292e-05  4.44226580e-01]
# Final iteration (M, N): (5000, 10). Iterations: 100 OLS MSE: 4.7369865117283265e-05 , MISE: 1.4658375888036117e-08
# Final b0: [-1.66481169e-05  4.45163975e-01]
# Final iteration (M, N): (10000, 10). Iterations: 100 OLS MSE: 1.787724437926856e-05 , MISE: 2.200040984483458e-10
# Final b0: [2.52375801e-07 4.44533427e-01]
# Final iteration (M, N): (20000, 10). Iterations: 100 OLS MSE: 4.7619171502068514e-05 , MISE: 6.581764562531375e-10
# Final b0: [5.05278942e-06 4.44293530e-01]
# Final iteration (M, N): (50000, 10). Iterations: 100 OLS MSE: 4.429633162931564e-05 , MISE: 2.6849624492747996e-10
# Final b0: [-1.53058872e-07  4.44542755e-01]
# Final iteration (M, N): (500, 25). Iterations: 100 OLS MSE: 1.2199808662120701e-05 , MISE: 1.0150282767338542e-07
# Final b0: [4.82952169e-05 4.46333924e-01]
# Final iteration (M, N): (1000, 25). Iterations: 100 OLS MSE: 5.947884416173484e-06 , MISE: 6.657087950784773e-09
# Final b0: [2.03671452e-05 4.43970396e-01]
# Final iteration (M, N): (5000, 25). Iterations: 100 OLS MSE: 8.991580200382073e-06 , MISE: 2.1945152544201775e-09
# Final b0: [-7.04480661e-06  4.44722322e-01]
# Final iteration (M, N): (10000, 25). Iterations: 100 OLS MSE: 1.0374443027588518e-05 , MISE: 5.733635869189579e-10
# Final b0: [-1.94306043e-06  4.44301248e-01]
# Final iteration (M, N): (20000, 25). Iterations: 100 OLS MSE: 6.357984218120566e-06 , MISE: 5.333509554033414e-09
# Final b0: [-1.86564887e-06  4.44006402e-01]
# Final iteration (M, N): (50000, 25). Iterations: 100 OLS MSE: 8.81860177347461e-06 , MISE: 6.390511978861812e-13
# Final b0: [-4.15199790e-08  4.44439654e-01]
# Final iteration (M, N): (500, 50). Iterations: 100 OLS MSE: 1.4894514338512082e-06 , MISE: 2.499563247816228e-08
# Final b0: [5.00205376e-07 4.43495849e-01]
# Final iteration (M, N): (1000, 50). Iterations: 100 OLS MSE: 1.8102483894364063e-06 , MISE: 3.639525778660747e-10
# Final b0: [3.58321849e-06 4.44332016e-01]
# Final iteration (M, N): (5000, 50). Iterations: 100 OLS MSE: 2.173595240398108e-06 , MISE: 1.5429036643326494e-10
# Final b0: [1.42816804e-06 4.44518478e-01]
# Final iteration (M, N): (10000, 50). Iterations: 100 OLS MSE: 6.382172382704323e-07 , MISE: 2.314291984974493e-13
# Final b0: [-5.40871275e-08  4.44447313e-01]
# Final iteration (M, N): (20000, 50). Iterations: 100 OLS MSE: 2.40930057638531e-06 , MISE: 4.0131134300660875e-10
# Final b0: [-2.62939794e-07  4.44564631e-01]
# Final iteration (M, N): (50000, 50). Iterations: 100 OLS MSE: 2.0605487453307033e-07 , MISE: 1.7169991465896134e-11
# Final b0: [-2.57096701e-07  4.44469259e-01]
# Final iteration (M, N): (500, 100). Iterations: 100 OLS MSE: 3.16592846849822e-07 , MISE: 3.977766402508368e-09
# Final b0: [4.15041357e-06 4.44822041e-01]
# Final iteration (M, N): (1000, 100). Iterations: 100 OLS MSE: 4.122792171090882e-07 , MISE: 6.199717131512184e-10
# Final b0: [1.16248247e-05 4.44312331e-01]
# Final iteration (M, N): (5000, 100). Iterations: 100 OLS MSE: 4.1685714041807904e-07 , MISE: 5.388424464257486e-12
# Final b0: [-7.47560627e-07  4.44457630e-01]
# Final iteration (M, N): (10000, 100). Iterations: 100 OLS MSE: 8.889555476823409e-07 , MISE: 3.4758564113075e-10
# Final b0: [2.80415197e-07 4.44332595e-01]
# Final iteration (M, N): (20000, 100). Iterations: 100 OLS MSE: 2.6399440708868665e-07 , MISE: 8.950526051066812e-11
# Final b0: [-2.43885793e-07  4.44387699e-01]
# Final iteration (M, N): (50000, 100). Iterations: 100 OLS MSE: 7.928283502916338e-08 , MISE: 2.554063990191844e-12
# Final b0: [4.28526784e-08 4.44454030e-01]
# Final iteration (M, N): (500, 250). Iterations: 100 OLS MSE: 7.122170173136118e-08 , MISE: 7.324683330708901e-10
# Final b0: [-8.22224668e-07  4.44606754e-01]
# Final iteration (M, N): (1000, 250). Iterations: 100 OLS MSE: 8.011198019350349e-08 , MISE: 8.286749813894843e-12
# Final b0: [-1.69016607e-06  4.44430463e-01]
# Final iteration (M, N): (5000, 250). Iterations: 100 OLS MSE: 7.988134612667634e-08 , MISE: 4.592101286733525e-11
# Final b0: [-2.38441343e-07  4.44403811e-01]
# Final iteration (M, N): (10000, 250). Iterations: 100 OLS MSE: 1.6271815474494667e-08 , MISE: 1.1831290930466967e-12
# Final b0: [-1.42369158e-07  4.44437974e-01]
# Final iteration (M, N): (20000, 250). Iterations: 100 OLS MSE: 1.341916034407284e-07 , MISE: 6.522492848273951e-14
# Final b0: [-1.06360534e-07  4.44443051e-01]
# Final iteration (M, N): (50000, 250). Iterations: 100 OLS MSE: 1.9690744983148163e-08 , MISE: 4.69293825378448e-13
# Final b0: [3.31039638e-08 4.44440339e-01]
# Final iteration (M, N): (500, 500). Iterations: 100 OLS MSE: 1.3717564334016852e-08 , MISE: 3.097801647299242e-11
# Final b0: [1.26345738e-07 4.44411058e-01]
# Final iteration (M, N): (1000, 500). Iterations: 100 OLS MSE: 1.7172600226175693e-08 , MISE: 2.1548286944992278e-11
# Final b0: [1.49100590e-06 4.44470821e-01]
# Final iteration (M, N): (5000, 500). Iterations: 100 OLS MSE: 6.289280558337393e-09 , MISE: 1.0179908052229377e-11
# Final b0: [-2.82557140e-07  4.44463513e-01]
# Final iteration (M, N): (10000, 500). Iterations: 100 OLS MSE: 8.002325308685741e-09 , MISE: 2.860891076215734e-14
# Final b0: [1.30925166e-07 4.44443802e-01]
# Final iteration (M, N): (20000, 500). Iterations: 100 OLS MSE: 1.7546735237989242e-08 , MISE: 3.6921697085864316e-13
# Final b0: [-5.05062482e-08  4.44448078e-01]
# Final iteration (M, N): (50000, 500). Iterations: 100 OLS MSE: 1.9480128896545495e-08 , MISE: 2.4972184101819766e-12
# Final b0: [3.03698803e-09 4.44434963e-01]
# Final iteration (M, N): (1000, 10000). Iterations: 100 OLS MSE: 3.1092178026910347e-11 , MISE: 4.3058836383815065e-15
# Final b0: [8.60189174e-09 4.44444054e-01]
# Final iteration (M, N): (1000, 5000). Iterations: 100 OLS MSE: 2.4685731048522774e-10 , MISE: 1.318075802788247e-13
# Final b0: [-1.95858042e-09  4.44446623e-01]
# Final iteration (M, N): (100, 5000). Iterations: 100 OLS MSE: 1.6384307571161541e-10 , MISE: 1.7916401109287223e-12
# Final b0: [-9.20182085e-07  4.44450277e-01]
# Final iteration (M, N): (10, 100000). Iterations: 100 OLS MSE: 4.587198959289724e-13 , MISE: 1.4127644161088362e-15
# Final b0: [-9.64835104e-09  4.44444226e-01]
# Final iteration (M, N): (10, 1000000). Iterations: 100 OLS MSE: 1.94135539306443e-15 , MISE: 6.066870696345819e-14
# Final b0: [1.76648531e-07 4.44443415e-01]
# Final iteration (M, N): (100000, 1). Iterations: 100 OLS MSE: 0.003069843662093823 , MISE: 9.450520151518484e-08
# Final b0: [3.02254619e-06 4.42600032e-01]
# Final iteration (M, N): (1000000, 1). Iterations: 100 OLS MSE: 0.0030770921095346292 , MISE: 3.042072937057107e-08
# Final b0: [1.16348514e-06 4.43397975e-01]
# Final iteration (M, N): (100000, 100). Iterations: 100 OLS MSE: 6.378957715499403e-07 , MISE: 1.390884467929506e-12
# Final b0: [3.46780315e-09 4.44451521e-01]
# Final iteration (M, N): (200000, 100). Iterations: 100 OLS MSE: 5.048549460405788e-07 , MISE: 4.9631248390907615e-12
# Final b0: [-4.74826588e-09  4.44457811e-01]
#    repetition  k    M  N      Time       MSE          MSIE  err_theta0  \
# 0           0  2  500  1  0.004351  0.002833  9.259814e-06    0.000239
# 1           1  2  500  1  0.004240  0.003039  8.295648e-07    0.000069
# 2           2  2  500  1  0.004533  0.003225  1.324105e-05    0.001426
# 3           3  2  500  1  0.004272  0.002968  5.930250e-06    0.000407
# 4           4  2  500  1  0.004297  0.003029  1.598764e-06    0.000087
#
#    err_theta1
# 0    0.018201
# 1    0.005449
# 2    0.020086
# 3    0.014406
# 4    0.007569
# CPU times: user 2min 42s, sys: 11.2 s, total: 2min 54s
# Wall time: 2min 49s

# %%
df_results["M_init"]    = df_results["M"] + init #add burnin
df_results["log_N"]    = np.log(df_results["N"])
df_results["log_M"]    = np.log(df_results["M"])
df_results["log_MN"]   = np.log(df_results["M"] * df_results["N"])

df_results["MN_label"] = df_results["M"].astype("str") + "-" + df_results["N"].astype("str")

# Remove outliers (non-convergence)
df_results = df_results[df_results["MSIE"] < 10.0]

df_results_average = df_results.groupby("MN_label").mean().reset_index()
print(df_results_average.head())

# sigma_e**2 * k / (N**alpha * (M - k - 1))
m = smf.ols("np.log(MSIE) ~ np.log(N) + np.log(M - k - 1)", data=df_results_average).fit()
coef_alpha = -m.params["np.log(N)"]
print(coef_alpha)
print(m.summary())


## Simulation + OLS time
# 1. Time moddel
m = smf.ols("Time ~ I(M*N) + M ", data=df_results_average).fit()
print(m.summary())

# 2. Extract point estimates
c_st = m.params["Intercept"]
alpha_MN = m.params["I(M * N)"]      # coeff on M*N
alpha_M  = m.params["M"]             # coeff on M

# 3. Extract standard errors
se_c_st = m.bse["Intercept"]
se_alpha_MN = m.bse["I(M * N)"]      # SE of alpha_MN
se_alpha_M  = m.bse["M"]             # SE of alpha_M

# 4. Extract covariance between the two slopes
cov_M_MN = m.cov_params().loc["M", "I(M * N)"]  # covariance between alpha_M and alpha_MN

# 5. Extra full covariance matrix
print(m.cov_params()) # full var-cov matrix
# Reorder
cov_mat = m.cov_params().loc[['Intercept','M','I(M * N)'], ['Intercept','M','I(M * N)']].values

print("alpha_MN =", alpha_MN, "±", se_alpha_MN)
print("alpha_M  =", alpha_M,  "±", se_alpha_M)
print("Cov(alpha_M, alpha_MN) =", cov_M_MN)

## Simulation + OLS time
## Checking the burnin does not change timing model
## Should only change constant
m = smf.ols("Time ~ I(M_init*N) + M_init ", data=df_results_average).fit()
print(m.summary())
# Out:
#      MN_label  repetition    k       M          N      Time           MSE  \
# 0   10-100000         2.0  2.0    10.0   100000.0  0.134183  3.498265e-13
# 1  10-1000000         2.0  2.0    10.0  1000000.0  1.397545  2.524039e-15
# 2    100-5000         2.0  2.0   100.0     5000.0  0.063091  2.167830e-10
# 3      1000-1         2.0  2.0  1000.0        1.0  0.005504  3.115712e-03
# 4     1000-10         2.0  2.0  1000.0       10.0  0.006320  2.939384e-05
#
#            MSIE    err_theta0    err_theta1  M_init      log_N     log_M  \
# 0  7.410559e-12  1.293209e-06  4.851446e-06   110.0  11.512925  2.302585
# 1  2.636129e-14  7.942314e-08  5.042915e-07   110.0  13.815511  2.302585
# 2  5.647116e-12  1.529427e-06  7.914348e-06   200.0   8.517193  4.605170
# 3  3.910243e-06  2.903741e-04  7.622521e-03  1100.0   0.000000  6.907755
# 4  4.933862e-08  2.888560e-05  9.330189e-04  1100.0   2.302585  6.907755
#
#       log_MN
# 0  13.815511
# 1  16.118096
# 2  13.122363
# 3   6.907755
# 4   9.210340
# 1.8987145727625934
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(MSIE)   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     781.8
# Date:                Mon, 26 May 2025   Prob (F-statistic):           1.07e-43
# Time:                        12:12:55   Log-Likelihood:                -85.442
# No. Observations:                  63   AIC:                             176.9
# Df Residuals:                      60   BIC:                             183.3
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -4.5155      0.636     -7.103      0.000      -5.787      -3.244
# np.log(N)            -1.8987      0.048    -39.537      0.000      -1.995      -1.803
# np.log(M - k - 1)    -1.0755      0.062    -17.427      0.000      -1.199      -0.952
# ==============================================================================
# Omnibus:                       10.033   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               16.897
# Skew:                          -0.462   Prob(JB):                     0.000214
# Kurtosis:                       5.363   Cond. No.                         49.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     1290.
# Date:                Mon, 26 May 2025   Prob (F-statistic):           4.95e-50
# Time:                        12:12:55   Log-Likelihood:                 54.643
# No. Observations:                  63   AIC:                            -103.3
# Df Residuals:                      60   BIC:                            -96.86
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0011      0.015      0.072      0.943      -0.029       0.031
# I(M * N)    1.152e-07   2.79e-09     41.219      0.000     1.1e-07    1.21e-07
# M           2.612e-06   1.04e-07     25.076      0.000     2.4e-06    2.82e-06
# ==============================================================================
# Omnibus:                       44.927   Durbin-Watson:                   2.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              407.014
# Skew:                          -1.573   Prob(JB):                     4.15e-89
# Kurtosis:                      15.048   Cond. No.                     5.87e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#               Intercept      I(M * N)             M
# Intercept  2.184940e-04 -1.616317e-11 -3.062264e-10
# I(M * N)  -1.616317e-11  7.807990e-18 -3.134614e-17
# M         -3.062264e-10 -3.134614e-17  1.084769e-14
# alpha_MN = 1.1517749369976151e-07 ± 2.794277998703484e-09
# alpha_M  = 2.6117055916374655e-06 ± 1.0415223930644556e-07
# Cov(alpha_M, alpha_MN) = -3.1346141796101594e-17
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.541
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     35.36
# Date:                Mon, 26 May 2025   Prob (F-statistic):           7.15e-11
# Time:                        12:12:55   Log-Likelihood:                -40.035
# No. Observations:                  63   AIC:                             86.07
# Df Residuals:                      60   BIC:                             92.50
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.1535      0.063      2.423      0.018       0.027       0.280
# I(M_init * N)  2.148e-08   4.13e-09      5.204      0.000    1.32e-08    2.97e-08
# M_init          3.07e-06   4.65e-07      6.598      0.000    2.14e-06       4e-06
# ==============================================================================
# Omnibus:                       66.891   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              534.138
# Skew:                           2.970   Prob(JB):                    1.03e-116
# Kurtosis:                      15.969   Cond. No.                     1.59e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.scatter(df_results_average["log_MN"], np.log(df_results_average["err_theta0"]), label="error theta_0")
plt.scatter(df_results_average["log_MN"], np.log(df_results_average["err_theta1"]), label="error theta_1")
plt.scatter(df_results_average["log_MN"], np.log(df_results_average["MSIE"]), label="log(MSIE)")
plt.xlabel("log(MN)")
plt.legend()

# %%
df_results_average["log_Time"] = np.log(df_results_average["Time"])

fig, axs = plt.subplots(3, 2, figsize=(12, 12))

# 1) Time vs N, colored by M
axs[0, 0].scatter(df_results_average["N"], df_results_average["Time"], c=df_results_average["M"], alpha=0.7)
axs[0, 0].set_xlabel("N")
axs[0, 0].set_ylabel("Time")
axs[0, 0].set_title("Time vs N (color=M)")

# 2) Time vs M, colored by N
axs[0, 1].scatter(df_results_average["M"], df_results_average["Time"], c=df_results_average["N"], alpha=0.7)
axs[0, 1].set_xlabel("M")
axs[0, 1].set_ylabel("Time")
axs[0, 1].set_title("Time vs M (color=N)")

# 3) log_Time vs log_N, colored by M
axs[1, 0].scatter(df_results_average["log_N"], df_results_average["log_Time"], c=df_results_average["M"], alpha=0.7)
axs[1, 0].set_xlabel("log(N)")
axs[1, 0].set_ylabel("log(Time)")
axs[1, 0].set_title("log(Time) vs log(N) (color=M)")

# 4) log_Time vs log_M, colored by N
axs[1, 1].scatter(df_results_average["log_M"], df_results_average["log_Time"], c=df_results_average["N"], alpha=0.7)
axs[1, 1].set_xlabel("log(M)")
axs[1, 1].set_ylabel("log(Time)")
axs[1, 1].set_title("log(Time) vs log(M) (color=N)")

# 5) log_Time vs log_MN, colored by N
axs[2, 0].scatter(df_results_average["log_MN"], df_results_average["log_Time"], c=df_results_average["N"], alpha=0.7)
axs[2, 0].set_xlabel("log(M*N)")
axs[2, 0].set_ylabel("log(Time)")
axs[2, 0].set_title("log(Time) vs log(M*N) (color=N)")

# Remove the unused subplot
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.savefig(output_folder + "plot_Time_MN.pdf", dpi=300)
plt.show()

# %%
df = df_results_average.copy()

# Fit the log-log regression
m = smf.ols("np.log(MSIE) ~ np.log(N) + np.log(M - k - 1)", data=df[df["Time"] < 0.5]).fit()
print(m.summary())

# Prepare a grid over N and M for prediction
k_val = df["k"].iloc[0]
N_vals = np.linspace(df["N"].min(), df["N"].max(), 100)
M_vals = np.linspace(df["M"].min(), df["M"].max(), 100)
NN, MM = np.meshgrid(N_vals, M_vals)

# Create a DataFrame for the grid
grid_df = pd.DataFrame({
    "N": NN.ravel(),
    "M": MM.ravel(),
    "k": k_val
})

# Predict log(MSIE) on the grid
log_msie_pred = m.predict(grid_df)
# Recover MSIE
msie_pred = np.exp(log_msie_pred).values.reshape(NN.shape)

# Plot the surface in log-log space
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(
    np.log(NN),
    np.log(MM - k_val - 1),
    np.log(msie_pred),
    alpha=0.5
)

# Extract data
Y_vals = np.log(df['M'] - params.nb_expl_vars - 1)
X_vals = np.log(df['N'])
Z_vals = np.log(df['MSIE'])
# Scatter plot
ax.scatter(X_vals, Y_vals, Z_vals, color='b')

ax.set_xlabel('log(N)')
ax.set_ylabel('log(M - k - 1)')
ax.set_zlabel('Predicted log(MSIE)')
ax.set_title('Predicted log(MSIE) surface from log-log regression')
plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(MSIE)   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     499.8
# Date:                Mon, 26 May 2025   Prob (F-statistic):           7.33e-33
# Time:                        12:12:56   Log-Likelihood:                -62.714
# No. Observations:                  51   AIC:                             131.4
# Df Residuals:                      48   BIC:                             137.2
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -5.1178      0.707     -7.235      0.000      -6.540      -3.695
# np.log(N)            -1.8255      0.058    -31.580      0.000      -1.942      -1.709
# np.log(M - k - 1)    -1.0218      0.072    -14.173      0.000      -1.167      -0.877
# ==============================================================================
# Omnibus:                        1.502   Durbin-Watson:                   1.503
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                0.723
# Skew:                           0.111   Prob(JB):                        0.697
# Kurtosis:                       3.540   Cond. No.                         53.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Pareto frontier

# %%
def compute_pareto_front(df, time_col='Time', mse_col='MSIE'):
    # Sort by Time ascending
    df_sorted = df.sort_values(by=time_col, ascending=True)

    # List to store the Pareto front
    pareto_points = []

    # Keep track of the lowest MSE encountered so far
    best_mse_so_far = float('inf')

    for idx, row in df_sorted.iterrows():
        mse_val = row[mse_col]
        if mse_val < best_mse_so_far:
            pareto_points.append(row)
            best_mse_so_far = mse_val

    return pd.DataFrame(pareto_points)

pareto_df = compute_pareto_front(df_results_average)

plt.figure(figsize=(8,6))
sns.scatterplot(data=df_results_average, x='Time', y='MSIE', hue='M', palette='viridis', alpha=0.7)
plt.plot(pareto_df['Time'], pareto_df['MSIE'], 'r-o', label='Pareto Frontier')

# Now highlight the optimal points
optimal_df = df_results_average[df_results_average['N'] == 1]
plt.scatter(optimal_df['Time'], optimal_df['MSIE'],
            marker='+', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='N = 1')

plt.xlabel('Time (seconds)')
plt.ylabel('MSIE')
plt.yscale('log')
plt.xscale('log')
plt.title('Time vs. MSIE, Colored by M')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(8,6))
sns.scatterplot(data=df_results_average, x='Time', y='MSIE', hue='N', palette='viridis', alpha=0.7)
plt.plot(pareto_df['Time'], pareto_df['MSIE'], 'r-o', label='Pareto Frontier')

# Now highlight the optimal points
optimal_df = df_results_average[df_results_average['N'] == 1]
plt.scatter(optimal_df['Time'], optimal_df['MSIE'],
            marker='+', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='N = 1')

plt.xlabel('Time (seconds)')
plt.ylabel('MSIE')
plt.yscale('log')
plt.xscale('log')
plt.title('Time vs. MSIE, Colored by N')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-25-47ca7da1608a>:27: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(optimal_df['Time'], optimal_df['MSIE'],
# <ipython-input-25-47ca7da1608a>:48: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(optimal_df['Time'], optimal_df['MSIE'],

# %%
pareto_df
# Out:
#       MN_label  repetition    k        M        N      Time           MSE  \
# 39       500-2         2.0  2.0    500.0      2.0  0.004324  5.144955e-04
# 42       500-5         2.0  2.0    500.0      5.0  0.004530  2.531904e-04
# 37      500-10         2.0  2.0    500.0     10.0  0.004739  4.870475e-05
# 40      500-25         2.0  2.0    500.0     25.0  0.005224  1.338629e-05
# 43      500-50         2.0  2.0    500.0     50.0  0.006120  1.529854e-06
# 8      1000-25         2.0  2.0   1000.0     25.0  0.007737  1.039686e-05
# 38     500-100         2.0  2.0    500.0    100.0  0.009045  3.432740e-07
# 41     500-250         2.0  2.0    500.0    250.0  0.018307  5.772072e-08
# 44     500-500         2.0  2.0    500.0    500.0  0.031764  1.691377e-08
# 12    1000-500         2.0  2.0   1000.0    500.0  0.059508  1.384865e-08
# 2     100-5000         2.0  2.0    100.0   5000.0  0.063091  2.167830e-10
# 31   20000-250         2.0  2.0  20000.0    250.0  0.606126  7.973257e-08
# 13   1000-5000         2.0  2.0   1000.0   5000.0  0.705867  1.580747e-10
# 6   1000-10000         2.0  2.0   1000.0  10000.0  1.359506  3.488134e-11
#
#             MSIE    err_theta0    err_theta1   M_init     log_N     log_M  \
# 39  1.790359e-06  1.803520e-04  6.775543e-03    600.0  0.693147  6.214608
# 42  6.992787e-07  1.067362e-04  4.461727e-03    600.0  1.609438  6.214608
# 37  3.063315e-07  5.311756e-05  2.733378e-03    600.0  2.302585  6.214608
# 40  5.691107e-08  5.308361e-05  1.194927e-03    600.0  3.218876  6.214608
# 43  7.890263e-09  1.333759e-05  4.373383e-04    600.0  3.912023  6.214608
# 8   5.476744e-09  1.040473e-05  4.268854e-04   1100.0  3.218876  6.907755
# 38  2.019835e-09  6.423558e-06  2.101716e-04    600.0  4.605170  6.214608
# 41  4.382704e-10  4.578338e-06  1.167350e-04    600.0  5.521461  6.214608
# 44  3.150875e-11  9.055710e-07  2.691841e-05    600.0  6.214608  6.214608
# 12  9.648421e-12  6.627997e-07  1.571975e-05   1100.0  6.214608  6.907755
# 2   5.647116e-12  1.529427e-06  7.914348e-06    200.0  8.517193  4.605170
# 31  1.913835e-12  6.810810e-08  6.941141e-06  20100.0  5.521461  9.903488
# 13  4.546658e-13  1.225944e-07  3.375128e-06   1100.0  8.517193  6.907755
# 6   5.002724e-15  2.422432e-08  3.444900e-07   1100.0  9.210340  6.907755
#
#        log_MN  log_Time
# 39   6.907755 -5.443470
# 42   7.824046 -5.396974
# 37   8.517193 -5.351955
# 40   9.433484 -5.254532
# 43  10.126631 -5.096127
# 8   10.126631 -4.861783
# 38  10.819778 -4.705569
# 41  11.736069 -4.000455
# 44  12.429216 -3.449434
# 12  13.122363 -2.821650
# 2   13.122363 -2.763185
# 31  15.424948 -0.500668
# 13  15.424948 -0.348328
# 6   16.118096  0.307122

# %% [markdown]
# #### Uncertainty quantification

# %%
def optimal_M_N(T, k, alpha, alpha0, alpha_MN, alpha_M, eps=1e-12, round_nearest = 1):
  """
  Compute the pair (M*, N*) that minimizes MSIE
    E[(…)^2] ∼ σ^2 k / [N^α (M−k−1)]
  subject to the time budget
    T = α0 + α_{MN}⋅M⋅N + α_M⋅M.

  Parameters
  ----------
  T : float
      Total time budget (must exceed α0).
  k : int
      Number of regressors, including constant
  alpha : float
      Exponent in the integration error ( >1 for well‑posed optimum).
  alpha0 : float
      Intercept term (c_st).
  alpha_MN : float
      Coefficient on M⋅N.
  alpha_M : float
      Coefficient on M.
  eps : float, optional
      Threshold below which we treat alpha2 as zero.
  round_nearest : int, optional
      rount to nearest multiple of round_nearest. By default, one

  Returns
  -------
  M_star, N_star : tuple of floats
      Optimal M and N.
  """
  C0 = T - alpha0
  A = (alpha - 1) * C0
  B = alpha * C0 * (k + 1)

  if C0 <= 0:
      raise ValueError("T must exceed alpha0")
  # α2 → 0 limit
  if abs(alpha_M) < eps:
      #print(f"corner case, alpha_M: {alpha_M}")
      N_star = 1
      M_star = C0 / (alpha_MN * N_star)
  else:
      # positive root of α2 M^2 + (α-1)C0 M - α C0 (k+1) = 0
      M_star = (-A + np.sqrt(A**2 + 4 * alpha_M * B)) / (2 * alpha_M)
      # back out N from the time constraint
      N_star = (C0 - alpha_M * M_star) / (alpha_MN * M_star)

  # round to nearest value
  M_star = int(np.round(M_star/round_nearest) * round_nearest)
  N_star = int(np.round(N_star/round_nearest) * round_nearest)

  return M_star, N_star

# Take also into account uncertainty regarding the intercept
def se_MN_star_full(
    M_star, N_star, T, k, alpha,
    alpha_0, alpha_M, alpha_MN,
    se_alpha_0, se_alpha_M, se_alpha_MN,
    cov_mat          # 3×3 numpy array from m.cov_params().values
):
    """
    cov_mat should match the order of grad_M = np.array([dM_dalpha0, dM_dalphaM, dM_dalphaMN])
    """
    # Precompute
    C0 = T - alpha_0
    b  = (alpha - 1)*C0
    D  = np.sqrt(b*b + 4*alpha_M*alpha*C0*(k+1))

    # 1) partials for M*
    dM_d0 = -1/(2*alpha_M)*((alpha-1)
             - ((alpha-1)**2 *C0 + 2*alpha*alpha_M*(k+1))/D)
    dM_dM = (alpha*C0*(k+1)/D - M_star)/alpha_M
    dM_dMN= 0.0

    grad_M = np.array([dM_d0, dM_dM, dM_dMN])
    var_M  = grad_M @ cov_mat @ grad_M
    se_M   = np.sqrt(var_M)

    # 2) partials for N*
    dN_d0 = (1/(alpha_MN*M_star)
             - (C0 - alpha_M*M_star)/(alpha_MN*(M_star**2))*dM_d0)
    dN_dM = (-1/alpha_MN
             - (C0 - alpha_M*M_star)/(alpha_MN*(M_star**2))*dM_dM)
    dN_dMN= -N_star/alpha_MN

    grad_N = np.array([dN_d0, dN_dM, dN_dMN])
    var_N  = grad_N @ cov_mat @ grad_N
    se_N   = np.sqrt(var_N)

    return se_M, se_N

target_time = 1
for alpha_selected in [coef_alpha, 1.0]:
    M_opt, N_opt = optimal_M_N(target_time, params.nb_expl_vars, alpha_selected, c_st, alpha_MN, alpha_M)

    se_M_opt, se_N_opt = se_MN_star_full(M_opt, N_opt, target_time, params.nb_expl_vars, alpha_selected,
                                        c_st, alpha_M, alpha_MN,
                                        se_c_st, se_alpha_M, se_alpha_MN, cov_mat)
    print(f"alpha: {alpha_selected}")
    print(f"M*: {M_opt} +/- 2 * {se_M_opt}. || 2 * std dev.(M*) / M* : {2 * se_M_opt/M_opt}")
    print(f"N*: {N_opt} +/- 2 * {se_N_opt}. || 2 * std dev.(N*) / N* : {2 * se_N_opt/N_opt}")
# Out:
# alpha: 1.8987145727625934
# M*: 6 +/- 2 * 0.01347346912205292. || 2 * std dev.(M*) / M* : 0.00449115637401764
# N*: 1368400 +/- 2 * 46155.2929287875. || 2 * std dev.(N*) / N* : 0.06745877364628398
# alpha: 1.0
# M*: 1071 +/- 2 * 24.207615409510133. || 2 * std dev.(M*) / M* : 0.04520563101682565
# N*: 8074 +/- 2 * 282.38947968041225. || 2 * std dev.(N*) / N* : 0.06995032937339912

# %%
# 1) Pivot MSIE into a matrix with rows=M and columns=N
df_sel = df_results_average[df_results_average["MSIE"] < 1.0].copy()

df_sel["log_MSIE"] = np.log10(df_sel["MSIE"])
df_sel["log_MSIE_Time"] = np.log10(df_sel["MSIE"]/df_sel["Time"])
df_sel["log_MSIE_x_Time"] = np.log10(df_sel["MSIE"]*df_sel["Time"]/10)


# TIME
pivot = df_sel.pivot_table(
    index='M',
    columns='N',
    values='Time',
    aggfunc='mean'        # ensures proper aggregation if duplicates exist
).sort_index().sort_index(axis=1)

# 2) Create a mask of the NaN cells
mask = pivot.isnull()

# 3) Plot with seaborn, masking NaNs
plt.figure(figsize=(8, 6))
sns.heatmap(
    pivot,
    mask=mask,           # hide cells where pivot is NaN
    cmap='viridis',
    cbar_kws={'label': 'Time'},
    linewidths=0.5,
    linecolor='white'
)

plt.xlabel('N (innovation draws)')
plt.ylabel('M (state draws)')
plt.title('Heatmap of Time over (M, N)')
plt.show()

# Accuracy
pivot = df_sel.pivot_table(
    index='M',
    columns='N',
    values='log_MSIE',
    aggfunc='mean'        # ensures proper aggregation if duplicates exist
).sort_index().sort_index(axis=1)

# 2) Create a mask of the NaN cells
mask = pivot.isnull()

# 3) Plot with seaborn, masking NaNs
plt.figure(figsize=(8, 6))
sns.heatmap(
    pivot,
    mask=mask,           # hide cells where pivot is NaN
    cmap='viridis',
    cbar_kws={'label': 'log_MSIE'},
    linewidths=0.5,
    linecolor='white'
)

plt.xlabel('N (innovation draws)')
plt.ylabel('M (state draws)')
plt.title('Heatmap of MSIE over (M, N)')
plt.show()


# Accuracy-Time
pivot = df_sel.pivot_table(
    index='M',
    columns='N',
    values='log_MSIE_x_Time',
    aggfunc='mean'        # ensures proper aggregation if duplicates exist
).sort_index().sort_index(axis=1)

# 2) Create a mask of the NaN cells
mask = pivot.isnull()

# 3) Plot with seaborn, masking NaNs
plt.figure(figsize=(8, 6))
sns.heatmap(
    pivot,
    mask=mask,           # hide cells where pivot is NaN
    cmap='viridis',
    cbar_kws={'label': 'log_MSIE_x_Time'},
    linewidths=0.5,
    linecolor='white'
)

plt.xlabel('N (innovation draws)')
plt.ylabel('M (state draws)')
plt.title('Heatmap of (MSIExTime)/10 over (M, N)')
plt.show()

# %% [markdown]
# ### Change $M$ and $N$, around specific target times

# %%
# Redo regression, but with data close to target times
threshold_reg = 10.0 #in seconds
min_M = 5 #Minimumm value for M. Otherwise blows up

df_selected = df_results_average[df_results_average["Time"] < threshold_reg]

# Accuracy regression
m = smf.ols("np.log(MSIE) ~ np.log(N) + np.log(M - k - 1)", data=df_selected).fit()

use_theoretical_value_alpha = True
if use_theoretical_value_alpha == True:
    if params.low_discrepancy == True:
        coef_alpha = 2.0 #Use theoretical value
    else:
        coef_alpha = 1.0
else:
    coef_alpha = -m.params["np.log(N)"] #Use estimated value

print(coef_alpha)
print(m.summary())

# Time regression
# O(MN) + O(M)
# 1. OLS
m = smf.ols("Time ~ I(M*N) + M ", data=df_selected).fit()
print(m.summary())

# 2. Extract point estimates
c_st = m.params["Intercept"]
alpha_MN = m.params["I(M * N)"]      # coeff on M*N
alpha_M  = m.params["M"]             # coeff on M

# 3. Extract standard errors
se_c_st = m.bse["Intercept"]
se_alpha_MN = m.bse["I(M * N)"]      # SE of alpha_MN
se_alpha_M  = m.bse["M"]             # SE of alpha_M

# 4. Extract covariance between the two slopes
cov_M_MN = m.cov_params().loc["M", "I(M * N)"]  # covariance between alpha_M and alpha_MN

# 5. Extra full covariance matrix
print(m.cov_params()) # full var-cov matrix
# Reorder
cov_mat = m.cov_params().loc[['Intercept','M','I(M * N)'], ['Intercept','M','I(M * N)']].values

print("alpha_MN =", alpha_MN, "±", se_alpha_MN)
print("alpha_M  =", alpha_M,  "±", se_alpha_M)

print("Cov-Mat", cov_mat)


list_N        = []
list_se_N     = []
list_M        = []
list_se_M     = []
list_optimal  = []
list_Time     = []

list_target_times = [0.25, 0.5, 1.0, 1.5, 2.0]

for target_time in list_target_times:
    # 1) build candidate grid
    list_N_temp = [1, 10, 100, 1000, 10000]
    N_array     = np.array(list_N_temp)

    # recover M from your linear timing law (without burn-in)
    vals = (target_time - c_st) / (alpha_M + alpha_MN * N_array)

    # 2) correct rounding: apply *10 before comprehension
    M_vals = np.round(vals/10) * 10
    list_M_temp = [int(max(m, min_M)) for m in M_vals]  # ensure M ≥ min_M

    # 3) append the non‐optimal candidates
    list_N       += list_N_temp
    list_M       += list_M_temp
    list_optimal += [0] * len(list_N_temp)
    list_Time    += [target_time] * len(list_N_temp)  # align one‐to‐one
    list_se_N += [0] * len(list_N_temp)
    list_se_M += [0] * len(list_M_temp)

    # 4) compute the theoretical optimum with burn-in
    M_opt, N_opt = optimal_M_N(target_time, params.nb_expl_vars, coef_alpha, c_st, alpha_MN, alpha_M, round_nearest=True)
    se_M_opt, se_N_opt = se_MN_star_full(M_opt, N_opt, target_time, params.nb_expl_vars, coef_alpha,
                                        c_st, alpha_M, alpha_MN,
                                        se_c_st, se_alpha_M, se_alpha_MN, cov_mat)

    ci_lower_M = M_opt - 2*se_M_opt
    ci_higher_M = M_opt + 2*se_M_opt

    ci_lower_N = N_opt - 2*se_N_opt
    ci_higher_N = N_opt + 2*se_N_opt

    print(f"alpha: {coef_alpha}")
    print(f"M*: {M_opt}. stdev. {se_M_opt}; ({ci_lower_M} - {ci_higher_M})")
    print(f"N*: {N_opt}. stdev. {se_N_opt}; ({ci_lower_N} - {ci_higher_N})")

    # 5) append the optimal point
    list_N.append(int(N_opt))
    list_M.append(int(M_opt))
    list_optimal.append(1)
    list_Time.append(target_time)
    list_se_N.append(se_N_opt)
    list_se_M.append(se_M_opt)

# 6) build DataFrame
df_MN = pd.DataFrame({
    "M":           list_M,
    "N":           list_N,
    "is_optimal":  list_optimal,
    "target_time": list_Time,
    "se_M":        list_se_M,
    "se_N":        list_se_N
})


#----------------------------------
tol = 1e-8 # tolerance on parameter vector
gam = 1.0  # smoothing parameter between two iterations
max_iter = 100 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

slong_test = 1000000
init_test = 100
nb_tot_reps = 100 #100 #nb of repetitions, to smooth out randomness and potential issues with measuring timing

# to store restults
results = []
np.random.seed(42)

for (N, M, is_optimal) in zip(list_N, list_M, list_optimal):
    for nb_rep in range(nb_tot_reps):
        #
        #np.random.seed(nb_rep)
        # Innovations for the out-sample test
        e_test = generate_random_innovations(slong_test, params.std_e)

        slong = init + M

        b0_current = theta_init.copy()

        # Generate a ld sampler. If random draws, ld_sampler is None
        ld_sampler = generate_ld_sampler(params)

        # innovation for state vector
        e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

        # Preallocate arrays
        x = np.zeros(slong+1)
        y_out      = np.zeros(slong)        # simulated y
        X_data      = np.zeros((slong, params.nb_expl_vars))   # regressor matrix
        y_temp = np.zeros(N)            # temporary array for innovations

        # Warmup (compilation) first go
        simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                            params.a, params.b, e, E, b0_current,
                            params.nb_expl_vars, params.basis,
                            x, y_out, X_data, y_temp)

        start_time = time.perf_counter()
        iter_num = 1
        crit = 1.0
        # Run a fixed number of iterations (or use while crit > tol)
        while iter_num < max_iter:
            if iter_num % redraw_shocks_every == 0:
                e, E = generate_random_arrays(slong, N, params.std_e, ld_sampler)

            # Call the numba-compiled simulation to get regression data.
            simulate_path_N_inplace(M, N, init, params.mean_x, params.std_x, params.rho_x, params.x_bar,
                            params.a, params.b, e, E, b0_current,
                            params.nb_expl_vars, params.basis,
                            x, y_out, X_data, y_temp)

            # Remove burnin
            X_reg = X_data[init:, :]
            y_reg = y_out[init:]

            # OLS
            bt, _, _, _ = np.linalg.lstsq(X_reg, y_reg, rcond=None)

            # Parameter update
            b_new = gam * bt + (1 - gam) * b0_current
            crit = np.max(np.abs(b_new - b0_current))
            b0_current = b_new.copy()

            #print("Iteration:", iter_num, "Conv. crit.:", crit)
            iter_num += 1

        end_time = time.perf_counter()
        elapsed = end_time - start_time
        #print("Elapsed time for N =", N, ":", elapsed, "seconds")

        # Compute residuals and In-sample MSE.
        Res = y_reg - np.dot(X_reg, b0_current)
        MSE = np.mean(Res ** 2)

        # Error on parameter values:
        err_theta0 = np.abs(b0_current[0] - theta0_true)
        err_theta1 = np.abs(b0_current[1] - theta1_true)

        #MSIE = calculate_MSIE(slong_test, init_test, params.mean_x,
        #          params.std_x, params.rho_x, params.x_bar,
        #           e_test, b0_true, b0_current)

        MSIE = calculate_MSIE_analytic(params.mean_x,
               params.std_x, params.rho_x, params.x_bar,
               b0_true, b0_current)

        if nb_rep == (nb_tot_reps-1):
            print(f"Final iteration (M, N): ({M}, {N}). Iterations: {iter_num}. Time (s): {elapsed}. OLS MSE: {MSE} , MISE: {MSIE}")
            print("Final b0:", b0_current)

        # Store the results in a dictionary
        results.append({
            "repetition": nb_rep,
            "k": params.nb_expl_vars,
            "M": M,
            "N": N,
            "Time": elapsed,
            "MSE": MSE,
            "MSIE": MSIE,
            "err_theta0": err_theta0,
            "err_theta1": err_theta1,
            "err_theta": 0.5*err_theta0 + 0.5*err_theta1,
            "is_optimal": is_optimal
            })

# Create a Pandas DataFrame from the results
df_results_2 = pd.DataFrame(results)
print(df_results_2.head())
# Out:
# 2.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(MSIE)   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     781.8
# Date:                Mon, 26 May 2025   Prob (F-statistic):           1.07e-43
# Time:                        12:12:58   Log-Likelihood:                -85.442
# No. Observations:                  63   AIC:                             176.9
# Df Residuals:                      60   BIC:                             183.3
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -4.5155      0.636     -7.103      0.000      -5.787      -3.244
# np.log(N)            -1.8987      0.048    -39.537      0.000      -1.995      -1.803
# np.log(M - k - 1)    -1.0755      0.062    -17.427      0.000      -1.199      -0.952
# ==============================================================================
# Omnibus:                       10.033   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               16.897
# Skew:                          -0.462   Prob(JB):                     0.000214
# Kurtosis:                       5.363   Cond. No.                         49.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     1290.
# Date:                Mon, 26 May 2025   Prob (F-statistic):           4.95e-50
# Time:                        12:12:58   Log-Likelihood:                 54.643
# No. Observations:                  63   AIC:                            -103.3
# Df Residuals:                      60   BIC:                            -96.86
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0011      0.015      0.072      0.943      -0.029       0.031
# I(M * N)    1.152e-07   2.79e-09     41.219      0.000     1.1e-07    1.21e-07
# M           2.612e-06   1.04e-07     25.076      0.000     2.4e-06    2.82e-06
# ==============================================================================
# Omnibus:                       44.927   Durbin-Watson:                   2.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              407.014
# Skew:                          -1.573   Prob(JB):                     4.15e-89
# Kurtosis:                      15.048   Cond. No.                     5.87e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#               Intercept      I(M * N)             M
# Intercept  2.184940e-04 -1.616317e-11 -3.062264e-10
# I(M * N)  -1.616317e-11  7.807990e-18 -3.134614e-17
# M         -3.062264e-10 -3.134614e-17  1.084769e-14
# alpha_MN = 1.1517749369976151e-07 ± 2.794277998703484e-09
# alpha_M  = 2.6117055916374655e-06 ± 1.0415223930644556e-07
# Cov-Mat [[ 2.18494026e-04 -3.06226359e-10 -1.61631742e-11]
#  [-3.06226359e-10  1.08476890e-14 -3.13461418e-17]
#  [-1.61631742e-11 -3.13461418e-17  7.80798953e-18]]
# alpha: 2.0
# M*: 6. stdev. 4.0968422967089025e-05; (5.999918063154066 - 6.000081936845934)
# N*: 360226. stdev. 26079.001524396197; (308067.99695120763 - 412384.00304879237)
# alpha: 2.0
# M*: 6. stdev. 1.704067982350926e-05; (5.999965918640353 - 6.000034081359647)
# N*: 721986. stdev. 32519.17951492668; (656947.6409701466 - 787024.3590298534)
# alpha: 2.0
# M*: 6. stdev. 7.902330446988794e-06; (5.999984195339106 - 6.000015804660894)
# N*: 1445507. stdev. 47690.51776998153; (1350125.964460037 - 1540888.035539963)
# alpha: 2.0
# M*: 6. stdev. 5.161437016427466e-06; (5.999989677125967 - 6.000010322874033)
# N*: 2169028. stdev. 64089.663739431984; (2040848.672521136 - 2297207.3274788638)
# alpha: 2.0
# M*: 6. stdev. 3.835737314308521e-06; (5.999992328525371 - 6.000007671474629)
# N*: 2892549. stdev. 80974.08704714647; (2730600.825905707 - 3054497.174094293)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_qmc.py:993: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# Final iteration (M, N): (91290, 1). Iterations: 100. Time (s): 0.23740424000015992. OLS MSE: 0.0030844813660622027 , MISE: 1.453395134417425e-09
# Final b0: [3.09656872e-06 4.44216460e-01]
# Final iteration (M, N): (66150, 10). Iterations: 100. Time (s): 0.2250127810000322. OLS MSE: 8.069890003606706e-05 , MISE: 6.414507539518365e-11
# Final b0: [2.74732959e-07 4.44492471e-01]
# Final iteration (M, N): (17620, 100). Iterations: 100. Time (s): 0.2044740820001607. OLS MSE: 4.5942315059126077e-07 , MISE: 2.3251094754878198e-10
# Final b0: [-5.61541114e-07  4.44353017e-01]
# Final iteration (M, N): (2110, 1000). Iterations: 100. Time (s): 0.2914600580002116. OLS MSE: 2.438076530088105e-09 , MISE: 2.1549315558042448e-11
# Final b0: [-6.39067041e-07  4.44472032e-01]
# Final iteration (M, N): (220, 10000). Iterations: 100. Time (s): 0.30876491799995165. OLS MSE: 7.746642148364465e-11 , MISE: 5.410422015393121e-13
# Final b0: [2.97454221e-07 4.44440408e-01]
# Final iteration (M, N): (6, 360226). Iterations: 100. Time (s): 0.33332904799999596. OLS MSE: 2.7377831900759514e-14 , MISE: 8.62832103174295e-12
# Final b0: [-2.51978211e-06  4.44453502e-01]
# Final iteration (M, N): (182970, 1). Iterations: 100. Time (s): 0.5129551909999464. OLS MSE: 0.003089755201969097 , MISE: 3.823359015576989e-09
# Final b0: [3.55320376e-06 4.44814831e-01]
# Final iteration (M, N): (132570, 10). Iterations: 100. Time (s): 0.49210740199987413. OLS MSE: 4.524121515776199e-05 , MISE: 1.3028723826028814e-10
# Final b0: [4.57332656e-07 4.44376013e-01]
# Final iteration (M, N): (35310, 100). Iterations: 100. Time (s): 0.4272794840003371. OLS MSE: 3.303448254399956e-07 , MISE: 3.701204784401998e-11
# Final b0: [-8.03681360e-08  4.44480944e-01]
# Final iteration (M, N): (4240, 1000). Iterations: 100. Time (s): 0.6189145719999942. OLS MSE: 1.706510708484453e-09 , MISE: 3.103830107447967e-13
# Final b0: [-7.48764370e-08  4.44441132e-01]
# Final iteration (M, N): (430, 10000). Iterations: 100. Time (s): 0.6240642119996664. OLS MSE: 3.269107737194261e-11 , MISE: 1.5789077348415974e-13
# Final b0: [2.40618729e-07 4.44442547e-01]
# Final iteration (M, N): (6, 721986). Iterations: 100. Time (s): 0.63657952199992. OLS MSE: 1.4947616170458916e-15 , MISE: 1.117662561270264e-13
# Final b0: [-2.74519811e-07  4.44443300e-01]
# Final iteration (M, N): (366330, 1). Iterations: 100. Time (s): 1.0663712400000804. OLS MSE: 0.003093659906424474 , MISE: 1.9000466333663226e-08
# Final b0: [1.94950155e-06 4.45271415e-01]
# Final iteration (M, N): (265430, 10). Iterations: 100. Time (s): 1.02609706200019. OLS MSE: 8.28446904470058e-05 , MISE: 1.0891593729814078e-09
# Final b0: [-4.73265823e-08  4.44246430e-01]
# Final iteration (M, N): (70700, 100). Iterations: 100. Time (s): 0.8427261460001318. OLS MSE: 2.79700014816004e-07 , MISE: 6.0099630201617036e-12
# Final b0: [-3.65537642e-08  4.44459152e-01]
# Final iteration (M, N): (8480, 1000). Iterations: 100. Time (s): 1.2133515669997905. OLS MSE: 1.526996116509565e-09 , MISE: 1.8576532335784585e-13
# Final b0: [6.71482018e-08 4.44441890e-01]
# Final iteration (M, N): (870, 10000). Iterations: 100. Time (s): 1.2138066170000457. OLS MSE: 2.7809458437640256e-11 , MISE: 4.479949426755924e-14
# Final b0: [-8.87014380e-09  4.44445713e-01]
# Final iteration (M, N): (6, 1445507). Iterations: 100. Time (s): 1.3077854869998191. OLS MSE: 1.6230957451551864e-15 , MISE: 1.4245460095397643e-13
# Final b0: [5.17626191e-10 4.44442180e-01]
# Final iteration (M, N): (549690, 1). Iterations: 100. Time (s): 1.5817669440002646. OLS MSE: 0.003082437225614834 , MISE: 5.583334401445136e-09
# Final b0: [1.17116453e-06 4.43996169e-01]
# Final iteration (M, N): (398290, 10). Iterations: 100. Time (s): 1.5159262890001628. OLS MSE: 3.222237344988318e-05 , MISE: 1.347377752103959e-10
# Final b0: [3.8228111e-09 4.4451409e-01]
# Final iteration (M, N): (106090, 100). Iterations: 100. Time (s): 1.2831432360007966. OLS MSE: 8.581987070468931e-08 , MISE: 1.4535418572966692e-12
# Final b0: [2.79739575e-08 4.44437213e-01]
# Final iteration (M, N): (12730, 1000). Iterations: 100. Time (s): 1.7433363760001157. OLS MSE: 6.786914333923697e-10 , MISE: 1.091768730684626e-13
# Final b0: [7.43378356e-09 4.44446426e-01]
# Final iteration (M, N): (1300, 10000). Iterations: 100. Time (s): 1.804755266999564. OLS MSE: 3.5885537479401514e-11 , MISE: 1.121091764962862e-15
# Final b0: [2.14280277e-09 4.44444645e-01]
# Final iteration (M, N): (6, 2169028). Iterations: 100. Time (s): 2.1697885590001533. OLS MSE: 7.416814193129941e-16 , MISE: 1.0351046174045603e-13
# Final b0: [7.44734887e-08 4.44442566e-01]
# Final iteration (M, N): (733050, 1). Iterations: 100. Time (s): 2.084449883000161. OLS MSE: 0.003098400804073413 , MISE: 5.012892638113142e-08
# Final b0: [1.90908141e-06 4.45787765e-01]
# Final iteration (M, N): (531140, 10). Iterations: 100. Time (s): 2.0791311989996757. OLS MSE: 1.5071107645652656e-05 , MISE: 3.214796475706086e-14
# Final b0: [1.38993758e-08 4.44445517e-01]
# Final iteration (M, N): (141470, 100). Iterations: 100. Time (s): 1.7049329869996654. OLS MSE: 1.0791313338385006e-06 , MISE: 1.096287895548895e-11
# Final b0: [1.95068562e-08 4.44424579e-01]
# Final iteration (M, N): (16970, 1000). Iterations: 100. Time (s): 2.271622834000482. OLS MSE: 3.029040723737098e-10 , MISE: 4.6447898229136044e-15
# Final b0: [1.14808319e-08 4.44444848e-01]
# Final iteration (M, N): (1730, 10000). Iterations: 100. Time (s): 2.3083310520014493. OLS MSE: 2.7699230747184286e-11 , MISE: 4.845646354296749e-15
# Final b0: [2.42749780e-08 4.44444053e-01]
# Final iteration (M, N): (6, 2892549). Iterations: 100. Time (s): 2.668362901000364. OLS MSE: 1.5005260904447531e-15 , MISE: 3.0582274407034624e-17
# Final b0: [-1.94366948e-09  4.44444476e-01]
#    repetition  k      M  N      Time       MSE          MSIE    err_theta0  \
# 0           0  2  91290  1  0.245068  0.003095  2.427189e-08  2.075672e-06
# 1           1  2  91290  1  0.227593  0.003073  6.876182e-08  2.127049e-07
# 2           2  2  91290  1  0.243411  0.003088  8.984586e-10  3.882686e-06
# 3           3  2  91290  1  0.247776  0.003096  3.073585e-08  8.392500e-06
# 4           4  2  91290  1  0.243214  0.003097  3.650177e-08  3.018235e-07
#
#    err_theta1  err_theta  is_optimal
# 0    0.000935   0.000468           0
# 1    0.001573   0.000787           0
# 2    0.000178   0.000091           0
# 3    0.001051   0.000530           0
# 4    0.001146   0.000573           0

# %%
df_results_2["log_N"]    = np.log(df_results_2["N"])
df_results_2["log_M"]    = np.log(df_results_2["M"])
df_results_2["log_MN"]   = np.log(df_results_2["M"] * df_results_2["N"])

df_results_2["MN_label"] = df_results_2["M"].astype("str") + "-" + df_results_2["N"].astype("str")
df_results_average_2 = df_results_2.groupby("MN_label").mean().reset_index()
print(df_results_average_2.head())

print(df_results_average_2[df_results_average_2['N'] == 1])

pareto_df = compute_pareto_front(df_results_average_2)

plt.figure(figsize=(8,6))
sns.scatterplot(data=df_results_average_2, x='Time', y='MSIE', alpha=0.7)
plt.plot(pareto_df['Time'], pareto_df['MSIE'], 'r-o', label='Pareto Frontier')

# Now highlight the optimal points
optimal_df = df_results_average_2[df_results_average_2['is_optimal'] == 1]

plt.scatter(optimal_df['Time'], optimal_df['MSIE'],
            marker='*', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='Optimal (M, N)')


df_one = df_results_average_2[df_results_average_2['N'] == 1]
plt.scatter(df_one['Time'], df_one['MSIE'],
            marker='+', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='N = 1')

df_hundred = df_results_average_2[df_results_average_2['N'] == 100]
plt.scatter(df_hundred['Time'], df_hundred['MSIE'],
            marker='x', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='N = 100')



for T in list_target_times:
    plt.axvline(x = T, color = 'b')

plt.xlabel('Time (seconds)')
plt.ylabel('MSIE')
plt.yscale('log')
#plt.xscale('log')
plt.title('Time vs. MSIE, Colored by N')
plt.legend(loc= "upper right")
plt.grid(True)
plt.show()
# Out:
#      MN_label  repetition    k         M        N      Time           MSE  \
# 0  106090-100        49.5  2.0  106090.0    100.0  1.281769  3.970007e-07
# 1  12730-1000        49.5  2.0   12730.0   1000.0  1.767550  3.995582e-09
# 2  1300-10000        49.5  2.0    1300.0  10000.0  1.813103  3.439338e-11
# 3   132570-10        49.5  2.0  132570.0     10.0  0.492262  5.450219e-05
# 4  141470-100        49.5  2.0  141470.0    100.0  1.728285  4.259501e-07
#
#            MSIE    err_theta0    err_theta1     err_theta  is_optimal  \
# 0  5.734072e-12  3.838706e-08  1.100595e-05  5.522170e-06         0.0
# 1  4.784564e-13  3.211324e-08  3.302728e-06  1.667421e-06         0.0
# 2  4.172573e-14  2.866548e-08  9.535381e-07  4.911018e-07         0.0
# 3  6.976569e-10  3.394432e-07  1.222555e-04  6.129746e-05         0.0
# 4  6.797977e-12  3.242880e-08  1.180695e-05  5.919687e-06         0.0
#
#       log_N      log_M     log_MN
# 0  4.605170  11.572043  16.177213
# 1  6.907755   9.451717  16.359472
# 2  9.210340   7.170120  16.380460
# 3  2.302585  11.794866  14.097451
# 4  4.605170  11.859843  16.465013
#     MN_label  repetition    k         M    N      Time       MSE  \
# 8   182970-1        49.5  2.0  182970.0  1.0  0.502633  0.003086
# 13  366330-1        49.5  2.0  366330.0  1.0  1.077551  0.003088
# 18  549690-1        49.5  2.0  549690.0  1.0  1.599741  0.003086
# 26  733050-1        49.5  2.0  733050.0  1.0  2.153839  0.003088
# 29   91290-1        49.5  2.0   91290.0  1.0  0.241067  0.003086
#
#             MSIE    err_theta0  err_theta1  err_theta  is_optimal  log_N  \
# 8   3.981467e-08  2.791736e-06    0.000986   0.000494         0.0    0.0
# 13  2.307317e-08  1.534148e-06    0.000733   0.000367         0.0    0.0
# 18  1.366762e-08  1.048906e-06    0.000567   0.000284         0.0    0.0
# 26  1.264859e-08  7.553787e-07    0.000547   0.000274         0.0    0.0
# 29  8.308567e-08  5.057957e-06    0.001376   0.000691         0.0    0.0
#
#         log_M     log_MN
# 8   12.117077  12.117077
# 13  12.811290  12.811290
# 18  13.217110  13.217110
# 26  13.504969  13.504969
# 29  11.421797  11.421797
# <ipython-input-30-a1adeeedc1d3>:27: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(df_one['Time'], df_one['MSIE'],
# <ipython-input-30-a1adeeedc1d3>:33: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(df_hundred['Time'], df_hundred['MSIE'],

# %%
# Select df for non-optimal
df = df_results_average_2.copy()
df = df[df["is_optimal"] == 0]
df['N_cat'] = df['N'].astype(int).astype(str).astype('category')

# Now plot:
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df[df["MSIE"] < 1],
    x='Time',
    y='MSIE',
    style='N_cat',
    legend='full',
    hue="N_cat",
    alpha=0.7,
    s=200
)

plt.scatter(optimal_df['Time'], optimal_df['MSIE'],
            marker='*', s=250, c='red',
            edgecolors='black', linewidths=1,
            label='N*')

plt.legend(title='N', loc='best')
plt.yscale('log')
plt.xlabel('Time (s)')
plt.ylabel('MSIE')
plt.title('Time vs MSIE by N')
plt.savefig(output_folder + f"Time_vs_MSIE_1.pdf", dpi=300)
plt.show()

# %%
pareto_df
# Out:
#       MN_label  repetition    k        M          N      Time           MSE  \
# 7    17620-100        49.5  2.0  17620.0      100.0  0.207496  3.887426e-07
# 9    2110-1000        49.5  2.0   2110.0     1000.0  0.296960  3.920014e-09
# 10   220-10000        49.5  2.0    220.0    10000.0  0.313324  3.524614e-11
# 16   430-10000        49.5  2.0    430.0    10000.0  0.644256  3.919142e-11
# 28   870-10000        49.5  2.0    870.0    10000.0  1.236011  3.482064e-11
# 19   6-1445507        49.5  2.0      6.0  1445507.0  1.347397  3.895493e-15
# 2   1300-10000        49.5  2.0   1300.0    10000.0  1.813103  3.439338e-11
# 20   6-2169028        49.5  2.0      6.0  2169028.0  2.160438  1.248058e-15
# 21   6-2892549        49.5  2.0      6.0  2892549.0  2.663116  8.189104e-16
#
#             MSIE    err_theta0    err_theta1     err_theta  is_optimal  \
# 7   2.996578e-11  2.054980e-07  2.518739e-05  1.269644e-05         0.0
# 9   3.845500e-12  2.283076e-07  8.907488e-06  4.567898e-06         0.0
# 10  4.286822e-13  2.150803e-07  2.635437e-06  1.425258e-06         0.0
# 16  2.297488e-13  9.955400e-08  1.891906e-06  9.957300e-07         0.0
# 28  6.755454e-14  4.605465e-08  1.202154e-06  6.241045e-07         0.0
# 19  6.102372e-14  1.307815e-07  7.063124e-07  4.185469e-07         1.0
# 2   4.172573e-14  2.866548e-08  9.535381e-07  4.911018e-07         0.0
# 20  3.903732e-14  8.225688e-08  4.564537e-07  2.693553e-07         1.0
# 21  3.070945e-14  8.734569e-08  4.049339e-07  2.461398e-07         1.0
#
#         log_N     log_M     log_MN
# 7    4.605170  9.776790  14.381960
# 9    6.907755  7.654443  14.562199
# 10   9.210340  5.393628  14.603968
# 16   9.210340  6.063785  15.274126
# 28   9.210340  6.768493  15.978834
# 19  14.183971  1.791759  15.975730
# 2    9.210340  7.170120  16.380460
# 20  14.589790  1.791759  16.381549
# 21  14.877649  1.791759  16.669408

# %%
df_MN_sel = df_MN[df_MN["is_optimal"] == 1]
df = df_results_average_2[df_results_average_2["is_optimal"] == True].copy()
df.sort_values("Time", inplace=True)
plt.scatter(df["Time"], df["N"], label="N* (theory)")
plt.fill_between(df["Time"], df_MN_sel['N'] -1.96*df_MN_sel['se_N'], df_MN_sel['N']+ 1.96*df_MN_sel['se_N'], alpha=0.5)

plt.scatter(pareto_df["Time"], pareto_df["N"], label="N* (actual)")
plt.legend()
plt.show()

df = df_results_average_2[df_results_average_2["is_optimal"] == True].copy()
df.sort_values("Time", inplace=True)
plt.scatter(df["Time"], df["M"], label="M* (theory)")
plt.fill_between(df["Time"], df_MN_sel['M'] -1.96*df_MN_sel['se_M'], df_MN_sel['M']+ 1.96*df_MN_sel['se_M'], alpha=0.5)
plt.scatter(pareto_df["Time"], pareto_df["M"], label="M* (actual)")
plt.legend()
plt.show()

# %%
# !python3 --version
# Out:
# Python 3.11.12

# %%
cpuinfo.get_cpu_info()
# Out:
# {'python_version': '3.11.12.final.0 (64 bit)',
#  'cpuinfo_version': [9, 0, 0],
#  'cpuinfo_version_string': '9.0.0',
#  'arch': 'X86_64',
#  'bits': 64,
#  'count': 8,
#  'arch_string_raw': 'x86_64',
#  'vendor_id_raw': 'AuthenticAMD',
#  'brand_raw': 'AMD EPYC 7B12',
#  'hz_advertised_friendly': '2.2500 GHz',
#  'hz_actual_friendly': '2.2500 GHz',
#  'hz_advertised': [2249998000, 0],
#  'hz_actual': [2249998000, 0],
#  'model': 49,
#  'family': 23,
#  'flags': ['3dnowext',
#   '3dnowprefetch',
#   'abm',
#   'adx',
#   'aes',
#   'apic',
#   'arat',
#   'avx',
#   'avx2',
#   'bmi1',
#   'bmi2',
#   'clflush',
#   'clflushopt',
#   'clwb',
#   'clzero',
#   'cmov',
#   'cmp_legacy',
#   'constant_tsc',
#   'cpuid',
#   'cr8_legacy',
#   'cx16',
#   'cx8',
#   'de',
#   'extd_apicid',
#   'f16c',
#   'fma',
#   'fpu',
#   'fsgsbase',
#   'fxsr',
#   'fxsr_opt',
#   'ht',
#   'hypervisor',
#   'ibpb',
#   'ibrs',
#   'lahf_lm',
#   'lm',
#   'mca',
#   'mce',
#   'misalignsse',
#   'mmx',
#   'mmxext',
#   'movbe',
#   'msr',
#   'mtrr',
#   'nonstop_tsc',
#   'nopl',
#   'npt',
#   'nrip_save',
#   'nx',
#   'osvw',
#   'osxsave',
#   'pae',
#   'pat',
#   'pclmulqdq',
#   'pdpe1gb',
#   'pge',
#   'pni',
#   'popcnt',
#   'pse',
#   'pse36',
#   'rdpid',
#   'rdrand',
#   'rdrnd',
#   'rdseed',
#   'rdtscp',
#   'rep_good',
#   'sep',
#   'sha',
#   'sha_ni',
#   'smap',
#   'smep',
#   'ssbd',
#   'sse',
#   'sse2',
#   'sse4_1',
#   'sse4_2',
#   'sse4a',
#   'ssse3',
#   'stibp',
#   'syscall',
#   'topoext',
#   'tsc',
#   'tsc_adjust',
#   'tsc_known_freq',
#   'umip',
#   'vme',
#   'vmmcall',
#   'x2apic',
#   'xgetbv1',
#   'xsave',
#   'xsavec',
#   'xsaveerptr',
#   'xsaveopt'],
#  'l3_cache_size': 524288,
#  'l2_cache_size': 2097152,
#  'l1_data_cache_size': 131072,
#  'l1_instruction_cache_size': 131072,
#  'l2_cache_line_size': 512,
#  'l2_cache_associativity': 6}

# %%
# Copy to drive
if on_Colab==True:
    drive.mount('/gdrive', force_remount=True)

    zip_filename = f"{output_extension}"  # No '.zip' extension here yet (shutil adds it)
    output_zip_full_path = g_drive_path + zip_filename

    # Compress the folder into the named zip file
    shutil.make_archive(output_zip_full_path, 'zip', output_extension)

    # Unmount Drive safely
    drive.flush_and_unmount()
    print(f'Backup {zip_filename}.zip completed and saved to Google Drive at {g_drive_path}.')
# Out:
# Mounted at /gdrive
# Backup PEA_linear_Colab_3.zip completed and saved to Google Drive at /gdrive/My Drive/bc_MC_PEA/4.Linear_Expectations/.

# %%
disconnect_when_done = False

if on_Colab==True:
    # Wait 2 minutes
    time.sleep(120)

    ## Close session
    from google.colab import runtime
    if disconnect_when_done==True:
      print("Closing runtime")
      runtime.unassign()

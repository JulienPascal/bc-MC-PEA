# %% [markdown]
# # Solving the stochastic growth model with the bc-MC-PEA
#
# This notebook solves a simple optimal growth model.
#
#
# ## This version
#
# *
#
# ---
# ---
#
# ## I. Model: Optimal Growth Model with Irreversible Investment
#
# The planner’s problem is to choose consumption $\{c_t\}$ and next period’s capital $\{k_{t+1}\}$ to maximize expected utility,
#
# \begin{equation}
# \max_{\{c_t,k_{t+1}\}_{t=0}^\infty} \; E_0 \sum_{t=0}^\infty \beta^t \frac{c_t^{1-\sigma}-1}{1-\sigma}
# \end{equation}
#
# subject to the resource constraint:
# \begin{equation}
# k_{t+1} = z_t k_t^\alpha - c_t + (1-\delta)k_t,
# \end{equation}
# the law of motion for TFP:
# \begin{equation}
# \log(z_{t+1}) = \rho \log(z_t) + \varepsilon_{t+1},
# \end{equation}
#
# The associated FOC is:
# \begin{equation}
# \begin{split}
# c_t^{-\sigma} &= \beta E_t \left\{ c_{t+1}^{-\sigma} \left[\alpha z_{t+1} k_{t+1}^{\alpha-1} + 1-\delta \right] \right\}, \\
# \end{split}
# \end{equation}
#
#
# #### Expectation Function $E_t[\phi_{t+1}]$:
# $$
# \phi_{t+1} \equiv \beta\left[ c_{t+1}^{-\sigma} \left(\alpha z_{t+1} k_{t+1}^{\alpha-1} + 1-\delta\right) \right].
# $$
# As in the standard case, a parametric approximation is used. For example, one may posit
# \begin{equation}
# \log\phi_{t+1}(\theta) = \theta_0 + \theta_1 \log k_t + \theta_2 \log z_t + \theta_3 \left(\log k_t\right)^2 + \theta_4 \left(\log z_t\right)^2 + \theta_5 \log k_t \cdot \log z_t.
# \end{equation}

# %% [markdown]
# ---
#
# ## II. Computations
#
#
# ### Roadmap
#
# <div style="background-color: #f0f0f0; padding: 10px;">
#
# #### Subsection 1
#
#
# #### Subsection 2
#
# </div>
#
# ### II. A. Load libraries, functions and types

# %%
on_Colab = True #True
import time, os

def is_chaospy_installed():
    try:
        import chaospy
        return True
    except ModuleNotFoundError:
        return False

# Usage
if is_chaospy_installed():
    print("chaospy is installed.")
else:
    print("chaospy is not installed.")

# Install deps on Colab
if (on_Colab == True) & (is_chaospy_installed() == False):
    print("Installing packages...")
    # %shell pip install -v quantecon interpolation chaospy --user
    #Restart runtime
    print("Runtime is now restarting...")
    print("You can ignore the error message [Your session crashed for an unknown reason.]")
    time.sleep(0.5)
    os._exit(0)  # restart
    # torch torchcontrib torch-optimizer 
else:
    print("Packages already installed")
# Out:
# chaospy is installed.
# Packages already installed

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import random
import scipy.stats
import chaospy  ## for quadrature
from itertools import product
import os
import re
import subprocess
import shutil

import time
import pandas as pd
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.ticker as mticker

import seaborn as sns; sns.set()
from tqdm import tqdm as tqdm
import datetime
from typing import Tuple
class Vector: pass
from scipy.stats import norm

import torch
from torch import nn
from torch.utils.data import DataLoader, Subset, Dataset, TensorDataset
from torch.nn.utils import clip_grad_norm_

# To create copies of NN
import copy
import matplotlib.ticker as mtick
# To use sparse kronecker product
from scipy import sparse

import itertools
# Interpolations
from scipy.interpolate import LinearNDInterpolator
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from scipy.interpolate import RegularGridInterpolator

# Regressions
import statsmodels.formula.api as smf
import statsmodels.api as sm
lowess = sm.nonparametric.lowess

import quantecon as qe
from interpolation import interp
from quantecon.optimize import brentq
from numba import njit
#from numba.experimental import jitclass
#import copy # Not used so far

import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator

import platform,socket,re,uuid,json,psutil,logging, cpuinfo, shutil

from scipy.stats import chi2
# Out:
# /home/julien/.local/lib/python3.8/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)

# %%
# Store parameters
class MyParams():
    """
    N: number of draws for innovation vector
    M: number of draws for the state vector
    lr: learning rate
    nb_epochs: number of gradient descent steps during training
    """
    def __init__(self, N, M, lr, optimizer, nb_epochs, order_gauss,
                 beta, alpha, gamma, delta, std_tfp, rho_tfp):
        # Model parameters
        self.beta = beta # Discount factor (patience)
        self.alpha = alpha # Capital share in production
        self.gamma = gamma # CRRA coefficient
        self.one_min_gamma = 1 - gamma #pre-compute
        # depreciation rate capital
        self.delta = delta
        # Standard deviation exo random variables
        self.std_tfp = std_tfp #0.01
        # Mean value exo random variables
        self.mean_tfp = 1.0
        # Persistence params
        self.rho_tfp = rho_tfp # Persistence log TFP values
        # Dependent variable in level or log
        self.formula = ""
        self.nb_shocks = 1
        ## State: Distribution of wealth + TFP (no persistence depreciation shocks)
        self.dim_state = 2
        ## Input for neural net
        self.dim_input = 2
        self.dim_output = 1
        # Nb agents:
        self.nb_agents = 1 #One representative household
        # Functions
        ## Utility
        if self.gamma != 1:
            self.u = lambda c: (1/self.one_min_gamma)*(c**(self.one_min_gamma) - 1)
        else:
            self.u = lambda c: torch.log(c)
        self.u_prime =  lambda c: c**(-self.gamma)
        self.u_prime_inv =  lambda c: c**(-(1/self.gamma))
        # bc-MC hyperparameters
        self.N = N #number of iid shocks used for each value of the state vector
        self.M = M #number of iid realization of the state vector
        self.MN = int(M*N)
        # To keep constant the number of function evaluations
        self.T = int((M*N)/2) #number
        self.distribution_shocks = "Normal" #"Normal" #Lognormal
        # Vectorized bc-MC
        # W used using the 2/M*N*(N-1) Sum f(i)*f(j) formula
        self.W_single_age_group = create_W_expanded_matrix(self.M, self.N, 1).to_sparse()
        # Expand W to vectorize calculations for all age groups:
        self.W_expanded = create_W_expanded_matrix(self.M, self.N, self.nb_agents-1).to_sparse()
        # Calculate W + W^T
        self.W_WT = (self.W_expanded + self.W_expanded.t()).to_sparse()
        # Learning parameters
        self.lr = lr
        self.momentum = 0.9 #momentum for SGD with momentum
        self.optimizer = optimizer #"Adam" #default: #Adam or SGD or SWA
        self.freq_gamma = 0.95 #When using a scheduler for the learning rate, lr_{t} = freq_gamma*lr_{t-1}
        self.use_scheduler = False #If true, use a scheduler for the learning rate
        self.nb_epochs = nb_epochs
        self.freq_scheduler = 1000
        # GAUSSIAN QUADRATURE
        ## INNOVATION VECTOR
        strr = "chaospy.Normal(0, self.std_tfp)"
        self.distrib = eval('chaospy.J({})'.format(strr))
        self.order_gauss = order_gauss
        nodes, weights = dist(self.order_gauss, self.distrib, rule = "gaussian", sp=True)
        self.nodes = nodes
        self.nodes_flat =  self.nodes.flatten() #make 1d array
        self.weights = weights
        self.weights_torch = torch.tensor(weights)
        self.nodes_torch = torch.tensor(np.transpose(self.nodes)) #column=dim. Row=observation
        # Save the number of points for the guassian quadrature:
        self.N_gaussian = len(self.weights_torch)
        # Implied number of points for the current space (T=MN/2 <-> M = 2T/N)
        self.M_gaussian = int((2*self.T)/self.N_gaussian)
        self.MN_gaussian = self.N_gaussian*self.M_gaussian
        # Repeat nodes to match the number of function evaluations for the expectation
        self.nodes_torch_repeated = self.nodes_torch.repeat(self.M_gaussian, 1)
        # Check bad combination
        if (self.optimizer == "SWA") & (self.use_scheduler == True):
            raise('opt SWA and use_schedule = True')

# %%
info_cpu = cpuinfo.get_cpu_info()
for (name) in info_cpu:
  print(f"{name}: ", info_cpu[name])

same_machine = True #ensure same machine
machine_desired = "Intel(R) Xeon(R) CPU @ 2.20GHz"
machine_desired = "AMD EPYC 7B12"


if (on_Colab == True):
    if info_cpu['brand_raw'] != machine_desired:
      print(f"Machine is: {info_cpu['brand_raw']}. RESTARTING VM")
      print("You can ignore the error message [Your session crashed for an unknown reason.]")
      time.sleep(0.5)
      os._exit(0)  # restart
    else:
      print(f"Found desired machine: {machine_desired}")
# Out:
# python_version:  3.8.10.final.0 (64 bit)
# cpuinfo_version:  [9, 0, 0]
# cpuinfo_version_string:  9.0.0
# arch:  X86_64
# bits:  64
# count:  12
# arch_string_raw:  x86_64
# vendor_id_raw:  GenuineIntel
# brand_raw:  Intel(R) Core(TM) i7-8850H CPU @ 2.60GHz
# hz_advertised_friendly:  2.6000 GHz
# hz_actual_friendly:  3.1093 GHz
# hz_advertised:  [2600000000, 0]
# hz_actual:  [3109323000, 0]
# stepping:  10
# model:  158
# family:  6
# flags:  ['3dnowprefetch', 'abm', 'acpi', 'adx', 'aes', 'aperfmperf', 'apic', 'arat', 'arch_capabilities', 'arch_perfmon', 'art', 'avx', 'avx2', 'bmi1', 'bmi2', 'bts', 'clflush', 'clflushopt', 'cmov', 'constant_tsc', 'cpuid', 'cpuid_fault', 'cx16', 'cx8', 'de', 'ds_cpl', 'dtes64', 'dtherm', 'dts', 'epb', 'ept', 'ept_ad', 'erms', 'est', 'f16c', 'flexpriority', 'flush_l1d', 'fma', 'fpu', 'fsgsbase', 'fxsr', 'hle', 'ht', 'hwp', 'hwp_act_window', 'hwp_epp', 'hwp_notify', 'ibpb', 'ibrs', 'ida', 'intel_pt', 'invpcid', 'invpcid_single', 'lahf_lm', 'lm', 'mca', 'mce', 'md_clear', 'mmx', 'monitor', 'movbe', 'mpx', 'msr', 'mtrr', 'nonstop_tsc', 'nopl', 'nx', 'osxsave', 'pae', 'pat', 'pbe', 'pcid', 'pclmulqdq', 'pdcm', 'pdpe1gb', 'pebs', 'pge', 'pln', 'pni', 'popcnt', 'pse', 'pse36', 'pti', 'pts', 'rdrand', 'rdrnd', 'rdseed', 'rdtscp', 'rep_good', 'rtm', 'sdbg', 'sep', 'sgx', 'sgx_lc', 'smap', 'smep', 'smx', 'ss', 'ssbd', 'sse', 'sse2', 'sse4_1', 'sse4_2', 'ssse3', 'stibp', 'syscall', 'tm', 'tm2', 'tpr_shadow', 'tsc', 'tsc_adjust', 'tsc_deadline_timer', 'tscdeadline', 'vme', 'vmx', 'vnmi', 'vpid', 'x2apic', 'xgetbv1', 'xsave', 'xsavec', 'xsaveopt', 'xsaves', 'xtopology', 'xtpr']
# l3_cache_size:  9437184
# l2_cache_size:  1,5 MiB
# l1_data_cache_size:  196608
# l1_instruction_cache_size:  196608
# l2_cache_line_size:  256
# l2_cache_associativity:  6

# %%
current_wd = os.getcwd()
output_extension = "stochastic_growth_2"
output_folder = current_wd  + "/output/" + output_extension + "/"
# Create folder if does not exist:
if not os.path.exists(output_folder):
    # If it doesn't exist, create it
    os.makedirs(output_folder)

# Create folder to save models
output_folder_models = output_folder + '/models/'
if not os.path.exists(output_folder_models):
    # If it doesn't exist, create it
    os.makedirs(output_folder_models)

if on_Colab == True:
    # Mount gdrive
    from google.colab import drive
    drive.mount('/gdrive')
    g_drive_path = '/gdrive/My Drive/bc_MC_PEA/3.stochastic_growth/'
    # Small test
    with open(g_drive_path + 'foo.txt', 'w') as f:
        f.write('Hello Google Drive!')

    # Create directory
    path = f"/gdrive/My Drive/{output_extension}"
    # Create folder if does not exist:
    if not os.path.exists(path):
    # If it doesn't exist, create it
        os.mkdir(path)
    # Autosave every 60 seconds
    # %autosave 60

# Import functions from notebook
if on_Colab == False:
    # %run functions_OLG.ipynb
    # %run functions_GF_bcMC.ipynb
else:
    # Where functions are stored
    # %run "/gdrive/My Drive/bc_MC_PEA/3.stochastic_growth/functions_OLG.ipynb"
    # %run "/gdrive/My Drive/bc_MC_PEA/3.stochastic_growth/functions_GF_bcMC.ipynb"

# If on Colab, install Octave and Matlab
if on_Colab == True:
    # Step 1: Install Octave
    # !apt-get install -y octave
    # !octave --version

    # Step 2: Install Dynare (this might take a bit of time)
    # !apt-get install -y dynare
# Out:
# Using cpu device

# %%
# Load functions
plot_scale = 0.75
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)
# Controlling fontsizes
SMALL_SIZE = 12
MEDIUM_SIZE = SMALL_SIZE + 2
BIGGER_SIZE =  SMALL_SIZE + 4
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
dpi_chosen=600 #control the quality of .png
linewidth_chosen = 2

# %%
M_chosen = 200 #200 #200 #100 #Nb draws state vector
N_chosen = 2 #Nb draws innovation vector for each realization of the state vector
lr_chosen = 1e-5 #1e-4 #4 #1e-4 #3 #5 #1e-3 #default: 1e-4 #3 #Learning rate
nb_epochs_chosen = 2000 #2000
order_gauss_chosen = 5
optimizer_chosen = "Adam" #"Adam" #"NAdam" # default: "Adam"

beta_chosen = 0.9 #0.95 #discount factor
alpha_chosen = 0.33 #production params
std_tfp_chosen = 0.02 #10 #125 #0.125 #0.01 #0.125 #std tfp. High value for constraint to bind
gamma_chosen = 1.0 #CRRA parameter
rho_chosen = 0.9 #persistence TFP
delta_chosen = 0.1 #0.1 #depreciation rate

mu_chosen = 1e-5 #e-6 #1e-5 #1e-6 #1e-6 #parameter gradient free bc-MC
mu_threshold = 1e-10 #min value for mu
mu_decay_chosen = 1.0 #0.999
use_Lookahead_chosen = False #Lookahead optimizer

params = MyParams(N_chosen, M_chosen, lr_chosen, optimizer_chosen,
                  nb_epochs_chosen, order_gauss_chosen,
                  beta_chosen, alpha_chosen, gamma_chosen, delta_chosen,
                  std_tfp_chosen, rho_chosen)

show_params(params)
# Out:
# learning rate: 1e-05
# nb epochs: 2000
# W_expanded.shape: torch.Size([0, 0])
# M: 200
# N: 2
# MN: 400
# T: 200
# optimizer_chosen: Adam
# use_scheduler: False
# nb agents: 1
# /tmp/ipykernel_52833/4059954804.py:8: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:605.)
#   return torch.sparse.FloatTensor(indices, values, shape)

# %%
# Function to calculate interest rate and wage
def interest_rate(K, L, delta, tfp, params):
    output = tfp*params.alpha*(K**(params.alpha-1))*(L**(1-params.alpha)) + (1 - delta)
    return output

def wage(K, L, tfp, params):
    output = (1 - params.alpha)*tfp*(K**(params.alpha))*(L**(-params.alpha))
    return output

def Production(K, L, tfp, params):
    """
    Production
    """
    output = tfp*(K**(params.alpha))*(L**(1-params.alpha))
    return output

# %% [markdown]
# ### II.B. 1st order solution using Dynare.

# %%
fname = "neogrowth.mod"
dirpath = os.getcwd()  # Get the current working directory
fpath = os.path.join(dirpath, fname)

file_content_1 = """
% optimal_growth.mod
% Dynare file for the standard optimal growth model (first-order approximation)

var k c z;
varexo eps;

parameters beta gamma alpha delta rho sigma_eps;

% Parameter values
beta      = {beta};
gamma     = {gamma};      % CRRA coefficient
alpha     = {alpha};
delta     = {delta};
rho       = {rho_tfp};
sigma_eps = {std_tfp};

model;
% Euler equation (after substituting the marginal utility condition)
c^(-gamma) = beta * c(+1)^(-gamma) * ( alpha * z(+1) * k^(alpha-1) + 1 - delta );

% Resource constraint (law of motion for capital)
k = z * k(-1)^alpha - c + (1-delta)*k(-1);

% Technology process (AR(1) in logs)
log(z) = rho*log(z(-1)) + eps;

end;

initval;
% Initial guesses for the steady state
k   = ((alpha*beta)/(1 - beta*(1-delta)))^(1/(1-alpha));
c   = ((alpha*beta)/(1 - beta*(1-delta)))^(alpha/(1-alpha)) - delta*(((alpha*beta)/(1 - beta*(1-delta)))^(alpha/(1-alpha)));
z   = 1;
eps = 0;
end;

steady;
check;

shocks;
var eps = sigma_eps^2;
end;

% IRF
stoch_simul(order=1, irf=100);

% SIMULATED SERIES
stoch_simul(periods=50000);
""".format(beta = params.beta, alpha = params.alpha,  gamma = params.gamma, 
           delta = params.delta, std_tfp = params.std_tfp, rho_tfp = params.rho_tfp)

file_content = file_content_1 
# Concat stings
# Write the content to the file
with open(fpath, "w") as file:
    file.write(file_content)

root_path = ""
if on_Colab == False:
    # Run the shell script locally.
    print("Calculating linearized model using Dynare")
    result = subprocess.run(['./solve_neogrowth.sh'], capture_output=True, text=True)
    # Print the output of the script
    print(result.stdout)
    print(result.stderr)
# Desgined to run on Google Colab
else:
    print("Calculating linearized model using Octave Dynare")
    root_path = g_drive_path

    # !octave solve_neogrowth_octave.m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1143286/1173379088.py in <module>
#      52 % SIMULATED SERIES
#      53 stoch_simul(periods=50000);
# ---> 54 """.format(beta = params.beta, alpha = params.alpha,  gamma = params.gamma,
#      55            delta = params.delta, std_tfp = params.std_tfp, rho_tfp = params.rho_tfp)
#      56
#
# NameError: name 'params' is not defined

# %%
#Load simulated data and fit linear model
SS_values = pd.read_csv(root_path + "output/Linearization/SS_values.csv")
print(SS_values)

Sim_series = pd.read_csv(root_path + "output/Linearization/Sim_series.csv")
print(Sim_series)

# Load the data
Sim_series = pd.read_csv(root_path + "output/Linearization/Sim_series.csv")

## Simulate realization conditional expectation
Sim_series['c_plus_1'] = Sim_series['c'].shift(-1)
Sim_series['z_plus_1'] = Sim_series['z'].shift(-1)
Sim_series['k_plus_1'] = Sim_series['k'].shift(-1)
Sim_series['cond_exp'] = params.beta  * (Sim_series['c_plus_1']**(-params.gamma)) * ( params.alpha * Sim_series['z_plus_1'] * Sim_series['k_plus_1']**(params.alpha - 1) + 1 - params.delta )

df_Dynare = pd.DataFrame({'k': Sim_series['k'], 'z': Sim_series['z'], 'cond_exp': Sim_series['cond_exp']})

df_Dynare['a'] = np.log(df_Dynare['z'])
print(df_Dynare.head())

## Log-log model
model = smf.ols(formula='np.log(cond_exp) ~ np.log(k) + np.log(z) + I(np.log(k)**2) + I(np.log(z)**2) + np.log(k)*np.log(z)', data=df_Dynare).fit()
print(model.summary())

coeff_vector = model.params
print(coeff_vector)

coeff_array_0 = model.params.values
print(coeff_array_0)
# Out:
#   Variable  MeanValue
# 0        k   1.945545
# 1        c   1.050234
# 2        z   0.999339
#               k         c         z
# 0      1.954863  1.057708  1.010753
# 1      1.983764  1.080959  1.046356
# 2      1.974788  1.059974  0.996543
# 3      1.978957  1.067751  1.014132
# 4      1.985579  1.071944  1.019094
# ...         ...       ...       ...
# 49995  1.958806  1.052112  0.990920
# 49996  1.965954  1.062971  1.014112
# 49997  1.984367  1.076597  1.033450
# 49998  2.006744  1.088847  1.044820
# 49999  2.032689  1.102597  1.056723
#
# [50000 rows x 3 columns]
#           k         z  cond_exp         a
# 0  1.954863  1.010753  0.931015  0.010696
# 1  1.983764  1.046356  0.941163  0.045313
# 2  1.974788  0.996543  0.937158 -0.003463
# 3  1.978957  1.014132  0.933963  0.014033
# 4  1.985579  1.019094  0.942743  0.018914
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       np.log(cond_exp)   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                 4.886e+05
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):               0.00
# Time:                        15:08:33   Log-Likelihood:             1.6811e+05
# No. Observations:               49999   AIC:                        -3.362e+05
# Df Residuals:                   49993   BIC:                        -3.361e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.3392      0.009     35.998      0.000       0.321       0.358
# np.log(k)              -0.5128      0.028    -18.047      0.000      -0.569      -0.457
# np.log(z)              -0.5388      0.039    -13.898      0.000      -0.615      -0.463
# I(np.log(k) ** 2)      -0.1063      0.021     -4.967      0.000      -0.148      -0.064
# I(np.log(z) ** 2)      -0.0739      0.046     -1.617      0.106      -0.163       0.016
# np.log(k):np.log(z)     0.2417      0.058      4.156      0.000       0.128       0.356
# ==============================================================================
# Omnibus:                       13.679   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.272
# Skew:                           0.021   Prob(JB):                     0.000796
# Kurtosis:                       3.071   Cond. No.                     3.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept              0.339167
# np.log(k)             -0.512826
# np.log(z)             -0.538811
# I(np.log(k) ** 2)     -0.106288
# I(np.log(z) ** 2)     -0.073867
# np.log(k):np.log(z)    0.241667
# dtype: float64
# [ 0.33916745 -0.51282579 -0.53881051 -0.10628776 -0.07386731  0.2416666 ]

# %% [markdown]
# ### II.C. Basline PEA

# %%
# Usual PEA
tol = 1e-6
gam = 1.0
init = 500
long = 20000
slong = init + long

# SS value
k_ss = SS_values[SS_values["Variable"] == "k"]["MeanValue"].item()
a_ss = 0

# Also, define the index arrays T and T1, for example:
T = np.arange(init, slong-1)      # Corresponds roughly to Matlab: init+1:slong-1 (adjusted for 0-indexing)
T1 = np.arange(init+1, slong)       # Corresponds roughly to Matlab: init+2:slong

# Compute initial conditions:
#b0 = np.array([0.5386, -0.7367, -0.2428, 0.1091, 0.2152, -0.2934]) #coeff_array_0  # b0 should be a 1D numpy array
b0 = coeff_array_0

# generate shocks
#np.random.seed(1)

# Generate shocks: e is a vector of size slong with normally distributed shocks scaled by se
e = params.std_tfp * np.random.randn(slong)

# Initialize a as a vector of zeros
a = np.zeros(slong)

# Set the first element of a
a[0] = a_ss

# Generate the AR(1) process for a
for i in range(1, slong):
    a[i] = params.rho_tfp * a[i-1] + e[i]

# Initialize iteration counter and convergence criterion
iteration = 1
crit = np.inf  # set to a large number initially

while crit > tol:
    k = np.zeros(slong + 1)
    lb = np.zeros(slong)
    X = np.zeros((slong, len(b0)))
    
    # Set initial capital:
    k[0] = k_ss

    # Simulate the path:
    for i in range(slong):
        # Construct the regressors at time i.
        # Note: ensure k[i] > 0 (otherwise, np.log(k[i]) will be undefined)
        X[i, :] = np.array([1, np.log(k[i]), a[i], np.log(k[i])**2, a[i]**2, np.log(k[i]) * a[i]])
        # Compute the policy variable lb from the current coefficients
        lb[i] = np.exp(np.dot(X[i, :], b0))
        # Update capital for the next period using the model's law of motion
        k[i+1] = np.exp(a[i]) * k[i]**params.alpha + (1 - params.delta) * k[i] - lb[i]**(-1/params.gamma)
    
    # Construct the vector y using the simulated paths (vectorized operation)
    y = params.beta * lb[T1] * (params.alpha * np.exp(a[T1]) * k[T1]**(params.alpha - 1) + 1 - params.delta)
    
    # Solve the regression: log(y) = X(T,:) * bt in a least-squares sense.
    # np.linalg.lstsq returns a tuple; the first element is the solution.
    bt, _, _, _ = np.linalg.lstsq(X[T, :], np.log(y), rcond=None)
    
    # Update b using a smoothing parameter gam:
    b = gam * bt + (1 - gam) * b0
    
    # Compute convergence criterion (maximum absolute change in b)
    crit = np.max(np.abs(b - b0))
    
    # Update b0 for the next iteration
    b0 = b.copy()
    
    # Display current iteration and convergence criterion
    print(f"Iteration: {iteration}\tConv. crit.: {crit}\t b: {b}")
    
    iteration += 1

Res = y - np.exp(np.dot(X[T, :], b0))
MSE = np.mean(Res ** 2)

# =============================================================================
# Plotting results
# =============================================================================
# 1. Plot histogram of residuals
plt.figure()
plt.hist(Res, bins=100)
plt.title('Residuals', fontname='Times', fontsize=12)

# 2. Compute investment deviations: it = k[T1] - (1-delta)*k[T]
it = k[T1] - (1 - params.delta) * k[T]

# Create a 2x2 figure for several plots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Investment scatter plot
axs[0, 0].plot(k[T], it, '.', markersize=0.5, color='k')
axs[0, 0].set_xlabel('k_t', fontname='Times', fontsize=12)
axs[0, 0].set_title('Investment', fontname='Times', fontsize=12)

# Histogram of investment
axs[0, 1].hist(it, bins=100)
axs[0, 1].set_title('Distribution of Investment', fontname='Times', fontsize=12)

# Capital stock: plot k[T] vs. k[T1] and add 45° reference line (scaled by (1-delta))
axs[1, 0].plot(k[T], k[T1], '.', markersize=0.5, color='k')
x_line = np.linspace(np.min(k[T]), np.max(k[T]), 100)
axs[1, 0].plot(x_line, (1 - params.delta) * x_line, '-', linewidth=1.2, color='g')
axs[1, 0].set_xlabel('k_t', fontname='Times', fontsize=12)
axs[1, 0].set_title('Capital Stock', fontname='Times', fontsize=12)

plt.tight_layout()


# 3. Time series plots for a subset (T0 = 500:1000)
T0 = np.arange(500, 1000)
fig, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(it[T0], 'k')
ax.set_xlabel('Time', fontname='Times', fontsize=12)
ax.set_title('Investment', fontname='Times', fontsize=12)

plt.tight_layout()
plt.show()

plt.scatter(k[:-1], k[1:])
plt.ylabel("kt+1")
plt.xlabel("kt")
plt.show()
# Out:
# Iteration: 1	Conv. crit.: 0.1371742576338844	 b: [ 0.3246626  -0.53018121 -0.5776599  -0.04770696 -0.04422724  0.10449234]
# Iteration: 2	Conv. crit.: 0.033658419564519024	 b: [ 0.32064303 -0.53972702 -0.59435059 -0.02440125 -0.05220735  0.07083392]
# Iteration: 3	Conv. crit.: 0.011129897309016645	 b: [ 0.31979475 -0.54591025 -0.59966773 -0.01327135 -0.05549046  0.06031186]
# Iteration: 4	Conv. crit.: 0.004942669053523474	 b: [ 0.31953308 -0.54883976 -0.60198935 -0.00832868 -0.0563734   0.05861134]
# Iteration: 5	Conv. crit.: 0.0020149374723007485	 b: [ 0.31935557 -0.54993505 -0.60320224 -0.00631374 -0.05609374  0.05956232]
# Iteration: 6	Conv. crit.: 0.0012820799233575	 b: [ 0.31920705 -0.55021818 -0.60383029 -0.00557219 -0.05541565  0.0608444 ]
# Iteration: 7	Conv. crit.: 0.0009746006325829781	 b: [ 0.31909282 -0.55020769 -0.60412685 -0.00534119 -0.05474874  0.06181901]
# Iteration: 8	Conv. crit.: 0.0006188933357019338	 b: [ 0.31901283 -0.55012179 -0.60424864 -0.00529583 -0.05424276  0.0624379 ]
# Iteration: 9	Conv. crit.: 0.00036022161289538807	 b: [ 0.31896045 -0.55003736 -0.60428784 -0.00530776 -0.05390871  0.06279812]
# Iteration: 10	Conv. crit.: 0.00020146384891871205	 b: [ 0.31892769 -0.54997396 -0.60429296 -0.00533076 -0.05370724  0.06299781]
# Iteration: 11	Conv. crit.: 0.00011381118817389152	 b: [ 0.31890784 -0.54993141 -0.60428675 -0.00535072 -0.05359343  0.06310535]
# Iteration: 12	Conv. crit.: 6.110087351175048e-05	 b: [ 0.31889608 -0.54990453 -0.60427862 -0.00536493 -0.05353233  0.06316228]
# Iteration: 13	Conv. crit.: 3.1434460963229716e-05	 b: [ 0.31888921 -0.54988818 -0.60427175 -0.00537419 -0.0535009   0.0631921 ]
# Iteration: 14	Conv. crit.: 1.5561996883427243e-05	 b: [ 0.31888526 -0.54987846 -0.60426678 -0.00537993 -0.05348534  0.06320765]
# Iteration: 15	Conv. crit.: 8.085082018299827e-06	 b: [ 0.318883   -0.54987279 -0.60426346 -0.00538337 -0.05347792  0.06321573]
# Iteration: 16	Conv. crit.: 4.205352637925985e-06	 b: [ 0.31888171 -0.54986952 -0.60426135 -0.0053854  -0.05347453  0.06321994]
# Iteration: 17	Conv. crit.: 2.1909862833041638e-06	 b: [ 0.31888099 -0.54986765 -0.60426005 -0.00538658 -0.05347305  0.06322213]
# Iteration: 18	Conv. crit.: 1.1446295339195833e-06	 b: [ 0.31888058 -0.54986658 -0.60425926 -0.00538725 -0.05347245  0.06322327]
# Iteration: 19	Conv. crit.: 6.011462991839522e-07	 b: [ 0.31888035 -0.54986598 -0.6042588  -0.00538763 -0.05347224  0.06322387]

# %%
mean_k = np.mean(k)
median_k = np.median(k)
std_k = np.std(k)
min_k = np.min(k)
max_k = np.max(k)

mean_a = np.mean(a)
median_a = np.median(a)
std_a = np.std(a)
min_a = np.min(a)
max_a = np.max(a)

stats_dict = {
    'Variable': ['k', 'a'],
    'Mean': [mean_k, mean_a],
    'Median': [median_k, median_a],
    'Std': [std_k, std_a],
    'Min': [min_k, min_a],
    'Max': [max_k, max_a]
}

# Convert the dictionary to a pandas DataFrame
summary_df = pd.DataFrame(stats_dict)

print(summary_df)
# Out:
#   Variable      Mean    Median       Std       Min       Max
# 0        k  1.953301  1.950434  0.130922  1.570658  2.435353
# 1        a -0.000035  0.000115  0.045874 -0.162756  0.177640

# %%
# Define parameters
nb_stdev = 2
nb_points = 200

# Slice along k (keeping a fixed at a_ss)
k_grid_k = np.linspace(mean_k - nb_stdev * std_k, mean_k + nb_stdev * std_k, nb_points)
a_grid_k = a_ss * np.ones_like(k_grid_k)
X_grid_k = np.column_stack([
    np.ones_like(k_grid_k), 
    np.log(k_grid_k), 
    a_grid_k,
    np.log(k_grid_k)**2, 
    a_grid_k**2, 
    np.log(k_grid_k) * a_grid_k
])
lb_grid_k = np.exp(np.dot(X_grid_k, b0))
consumption_grid_k = lb_grid_k ** (-1 / params.gamma)


# Slice along a (keeping k fixed at mean_k)
a_grid_a = np.linspace(a_ss - nb_stdev * std_a, a_ss + nb_stdev * std_a, nb_points)
k_grid_a = mean_k * np.ones_like(a_grid_a)
X_grid_a = np.column_stack([
    np.ones_like(k_grid_a), 
    np.log(k_grid_a), 
    a_grid_a,
    np.log(k_grid_a)**2, 
    a_grid_a**2, 
    np.log(k_grid_a) * a_grid_a
])

lb_grid_a = np.exp(np.dot(X_grid_a, b0))
consumption_grid_a = lb_grid_a ** (-1 / params.gamma)

# Create subplots side by side
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Plot slice along k
axs[0].plot(k_grid_k, consumption_grid_k, label="Python")
#axs[0].plot(k_grid_k, consumption_grid_k_2, linestyle="--", label="Matlab")
axs[0].set_xlabel('Capital, k')
axs[0].set_ylabel('Consumption, c')
axs[0].set_title('Optimal Consumption (slice along k)')
axs[0].grid(True)

# Plot slice along a
axs[1].plot(a_grid_a, consumption_grid_a, label="Python")
#axs[1].plot(a_grid_a, consumption_grid_a_2, linestyle="--", label="Matlab")
axs[1].set_xlabel('Productivity shock, a')
axs[1].set_ylabel('Consumption, c')
axs[1].set_title('Optimal Consumption (slice along a)')
axs[1].grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### II.D. bc-MC-PEA
#
# Define a few jit-compiled functions:

# %%
@njit
def generate_random_innovations(slong, N, std):
    """
    Generate 1d innovatio N(0, std^2)
    """
    e = np.empty(slong)
    for i in range(slong):
        e[i] = std * np.random.randn()
    return e

@njit
def generate_random_arrays(slong, N, std):
    """
    Generate 1d innovation N(0, std^2) and random array, where each row is N(0, std^2).
    """
    e = np.empty(slong)
    E = np.empty((slong, N))
    for i in range(slong):
        e[i] = std * np.random.randn()
        for j in range(N):
            E[i, j] = std * np.random.randn()
    return e, E

def dhm_accuracy_test(params, b0, long = 100000, init = 1000):
    """
    Compute the DHM accuracy test for a given set of parameters and an initial coefficient vector b0.
    
    Parameters:
    params: Instance containing model parameters (beta, delta, alpha, gamma, rho_tfp, std_tfp)
    b0: Coefficient vector used for the approximation.
    
    Returns:
    dict: Dictionary containing DHM test results.
    """
    # Simulation setup
    slong = init + long
    
    T = np.arange(init, slong - 1)  # Select current period    
    T1 = np.arange(init + 1, slong) # Select period t+1
    
    # Steady state calculations
    kss = ((1 - params.beta * (1 - params.delta)) / (params.alpha * params.beta)) ** (1 / (params.alpha - 1))
    
    # Generate shocks and AR(1) process for a
    #np.random.seed(1)
    e = params.std_tfp * np.random.randn(slong)
    a = np.zeros(slong)
    for i in range(1, slong):
        a[i] = params.rho_tfp * a[i - 1] + e[i]
    
    # Initialize variables
    k = np.zeros(slong + 1)
    lb = np.zeros(slong)
    X = np.zeros((slong, len(b0)))
    k[0] = kss  # Initial capital at steady state
    
    # Simulate the economy
    for i in range(slong):
        X[i, :] = np.array([1, np.log(k[i]), a[i],
                            np.log(k[i]) ** 2, a[i] ** 2,
                            np.log(k[i]) * a[i]])
        
        lb[i] = np.exp(np.dot(X[i, :], b0))
        iv = np.exp(a[i]) * k[i] ** params.alpha - lb[i] ** (-1 / params.gamma)        
        k[i + 1] = (1 - params.delta) * k[i] + iv

    # Compute the error term
    ut = lb[T] - params.beta * (lb[T1] * (params.alpha * np.exp(a[T1]) * k[T1] ** (params.alpha - 1) + 1 - params.delta) )
    
    # Compute DHM statistics
    mean_ut = np.mean(ut)
    mean_abs_ut = np.mean(np.abs(ut))
    mean_square_ut = np.mean(ut**2)
    var_ut = np.var(ut, ddof=1)
    std_ut = np.sqrt(var_ut)
    T_sample = len(ut)
    dhm_stat = T_sample * (mean_ut ** 2) / var_ut
    
    # Chi-square critical values
    lower5 = chi2.ppf(0.05, df=1)
    upper5 = chi2.ppf(0.95, df=1)
    
    # Compute consumption equivalent
    mean_k = np.mean(k)
    a_ss = 0
    X_ss = np.array([1, np.log(mean_k), a_ss, np.log(mean_k) ** 2, a_ss, np.log(mean_k) * a_ss])
    c_ss = np.exp(np.dot(X_ss, b0)) ** (-1 / params.gamma)
    c_diff = (mean_ut + c_ss ** (-params.gamma)) ** (-1 / params.gamma)
    #c_diff = (mean_abs_ut + c_ss ** (-params.gamma)) ** (-1 / params.gamma)
    c_equivalent = 100 * (c_diff - c_ss) / c_ss
    
    return mean_abs_ut,  mean_square_ut, std_ut, dhm_stat, c_equivalent

def create_plots(list_N, MSE_N, Time_N, mean_square_ut_N, dhm_stat_N, c_equivalent_N, label = "N", ref_index_plot=0):
    """
    Creates two sets of plots:
    
    1. A figure with two subplots:
       - Left: MSE vs. N, along with 1/N and 1/sqrt(N) decay lines.
       - Right: Elapsed Time vs. N, along with 1*N and 1*sqrt(N) increase lines.
       
    2. A second figure with four subplots (2x2 grid):
       - Top-left: Mean (ut)^2 vs. N with a 1/sqrt(N) decay line.
       - Top-right: DHM Stats vs. N with a 1/sqrt(N) decay line.
       - Bottom-left: % C equivalent vs. N with a 1/sqrt(N) decay line.
       - Bottom-right: In sample MSE vs. N with a 1/N decay line.
       
    Parameters:
        list_N         : array-like, values of N (Number of Innovation Draws)
        MSE_N          : array-like, Mean Squared Error for each N
        Time_N         : array-like, elapsed time (seconds) for each N
        mean_square_ut_N: array-like, mean (ut)^2 for each N
        dhm_stat_N     : array-like, DHM statistic for each N
        c_equivalent_N : array-like, % C equivalent for each N
        ref_index_plot : int, reference index for plotting the decay/increase lines (default 0)
    """
    list_N = np.array(list_N)  # ensure numpy array for elementwise operations
    
    # -----------------------
    # Figure 1: Two subplots side-by-side.
    fig1, axs = plt.subplots(1, 2, figsize=(12, 5))
    
    # Left panel: MSE vs. N.
    axs[0].plot(list_N, MSE_N, marker='o', linestyle='-', label='MSE')
    axs[0].plot(list_N, MSE_N[ref_index_plot] * (list_N[ref_index_plot] / list_N),
                marker='o', linestyle='--', label='1/N decay')
    axs[0].plot(list_N, MSE_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
                marker='o', linestyle='--', label='1/sqrt(N) decay')
    axs[0].set_xlabel(label)
    axs[0].set_ylabel('Mean Squared Error')
    axs[0].set_title(f'MSE vs. {label}')
    axs[0].grid(True)
    axs[0].legend()
    
    # Right panel: Elapsed Time vs. N.
    axs[1].plot(list_N, Time_N, marker='o', linestyle='-', color='orange', label='Elapsed Time (s)')
    #axs[1].plot(list_N, Time_N[ref_index_plot] * (list_N / list_N[ref_index_plot]),
    #            marker='o', linestyle='--', label='1*N increase')
    #axs[1].plot(list_N, Time_N[ref_index_plot] * np.sqrt(list_N / list_N[ref_index_plot]),
    #            marker='o', linestyle='--', label='1*sqrt(N) increase')
    axs[1].set_xlabel('label')
    axs[1].set_ylabel('Elapsed Time (seconds)')
    axs[1].set_title(f'Elapsed Time vs. {label}')
    axs[1].grid(True)
    axs[1].legend()
    
    plt.tight_layout()
    plt.show()
    
    # -----------------------
    # Figure 2: Four subplots in a 2x2 grid.
    fig2, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 5))
    
    # Top-left: Mean (ut)^2 vs. N.
    ax1.plot(list_N, mean_square_ut_N, marker='o', linestyle='-')
    ax1.plot(list_N, mean_square_ut_N[ref_index_plot] * np.power(list_N[ref_index_plot] / list_N, 0.5),
             marker='o', linestyle='--', label='1/sqrt(N) decay')
    ax1.set_xlabel(label)
    ax1.set_ylabel('Mean (ut)^2')
    ax1.set_title('Mean (ut)^2')
    ax1.grid(True)
    ax1.legend()
    
    # Top-right: DHM Stats vs. N.
    ax2.plot(list_N, dhm_stat_N, marker='o', linestyle='-', color='orange')
    ax2.plot(list_N, dhm_stat_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
             marker='o', linestyle='--', label='1/sqrt(N) decay')
    ax2.set_xlabel(label)
    ax2.set_ylabel('DHM Stats')
    ax2.set_title('DHM Stats')
    ax2.grid(True)
    ax2.legend()
    
    # Bottom-left: % C equivalent vs. N.
    ax3.plot(list_N, c_equivalent_N, marker='o', linestyle='-', color='orange')
    ax3.plot(list_N, c_equivalent_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
             marker='o', linestyle='--', label='1/sqrt(N) decay')
    ax3.set_xlabel(label)
    ax3.set_ylabel('% C equivalent')
    ax3.set_title('% C equivalent')
    ax3.grid(True)
    ax3.legend()
    
    # Bottom-right: In sample MSE vs. N.
    ax4.plot(list_N, MSE_N, marker='o', linestyle='-', label='In sample MSE')
    ax4.plot(list_N, MSE_N[ref_index_plot] * (list_N[ref_index_plot] / list_N),
             marker='o', linestyle='--', label='1/N decay')
    ax4.set_xlabel(label)
    ax4.set_ylabel('% In sample MSE')
    ax4.set_title('% In sample MSE')
    ax4.grid(True)
    ax4.legend()
    
    plt.tight_layout()
    plt.show()

@njit
def simulate_path_N(slong, kss, e, E, b0, beta, gamma, alpha, delta, rho_tfp, N, log_y = False):
    """
    Simulates the model path period by period.
    
    Parameters:
        slong   : total number of simulation periods (integer)
        kss     : steady state capital (float)
        e       : array of nnovations of shape (slong)
        E       : array of extra innovations of shape (slong, N)
        b0      : coefficient vector (array of length 6)
        beta    : discount factor (float)
        gamma   : CRRA coefficient (float)
        alpha   : production elasticity (float)
        delta   : depreciation rate (float)
        rho_tfp : AR(1) coefficient for TFP (float)
        N       : number of innovations per period (integer)
    """
    # Preallocate arrays
    a = np.zeros(slong)
    k      = np.zeros(slong + 1)    # capital path (slong+1 because we update k[i+1])
    y      = np.zeros(slong)        # simulated y
    X      = np.zeros((slong, 6))     # regressor matrix (6 variables)
    y_temp = np.zeros(N)             # temporary array for innovations

    # Initialize state.
    k[0] = kss
    a[0] = 0.0
    for i in range(1, slong):
        a[i] = rho_tfp * a[i-1] + e[i]

    for i in range(slong):
        # Build regressor vector for current period i: [1, log(k[i]), a[i], log(k[i])^2, a[i]^2, log(k[i])*a[i]]
        X[i, 0] = 1.0
        X[i, 1] = np.log(k[i])
        X[i, 2] = a[i]
        X[i, 3] = X[i, 1]**2 #(np.log(k[i]))**2
        X[i, 4] = a[i]**2
        X[i, 5] = X[i, 1]*a[i] #np.log(k[i]) * a[i]
        
        # Compute lb[i] = exp( dot(X[i], b0) )
        dot_val = 0.0
        for p in range(6):
            dot_val += X[i, p] * b0[p]
        lb = np.exp(dot_val)
        
        # Compute investment
        iv = np.exp(a[i]) * (k[i]**alpha) - lb**(-1.0 / gamma)
        k[i + 1] = (1.0 - delta) * k[i] + iv
        
        # For each of the N innovations compute a simulated realization for y
        for j in range(N):
            # Next period's TFP shock
            a_next = rho_tfp * a[i] + E[i, j]
            # Build regressor for next period using k[i+1] and a_next
            X_next0 = 1.0
            X_next1 = np.log(k[i+1])
            X_next2 = a_next
            X_next3 = X_next1**2
            X_next4 = a_next**2
            X_next5 = X_next1 * a_next
            dot_val_next = (X_next0 * b0[0] + X_next1 * b0[1] + X_next2 * b0[2] +
                            X_next3 * b0[3] + X_next4 * b0[4] + X_next5 * b0[5])
            lb_next = np.exp(dot_val_next)

            y_temp[j] = beta * (lb_next * (alpha * np.exp(a_next) * (k[i+1]**(alpha-1)) + 1.0 - delta) )
        # Average the N innovations to form the simulated y for period i
        s = 0.0
        for j in range(N):
            if log_y == False:
                s += y_temp[j]
            else:
                s += np.log(y_temp[j])
        y[i] = s / N

    return X, y

# %%
@njit
def evaluate_Et_Gauss_path(slong, kss, e, b0, beta, gamma, alpha, delta, rho_tfp, number_nodes, quadrature_nodes, quadrature_weights, nb_expl_vars):
    """
    Simulates the model path period by period. Calculate the error = (E_t - Xb).
    
    Parameters:
        slong   : total number of simulation periods (integer)
        kss     : steady state capital (float)
        e       : array of nnovations of shape (slong)
        b0      : coefficient vector (array of length nb_expl_vars)
        beta    : discount factor (float)
        gamma   : CRRA coefficient (float)
        alpha   : production elasticity (float)
        delta   : depreciation rate (float)
        rho_tfp : AR(1) coefficient for TFP (float)
        number_nodes: number of quadrature nodes
        quadrature_nodes: quadrature nodes
        quadrature_weights: quadrature weights
        nb_expl_vars: number of explanatory variables in regression
    """
    # Preallocate arrays
    a = np.zeros(slong)
    k      = np.zeros(slong + 1)    # capital path (slong+1 because we update k[i+1])
    y      = np.zeros(slong)        # error
    X      = np.zeros((slong, nb_expl_vars))     # regressor matrix (6 variables)
    y_temp = np.zeros(number_nodes)             # temporary array for innovations

    # Initialize state.
    k[0] = kss
    a[0] = 0.0
    for i in range(1, slong):
        a[i] = rho_tfp * a[i-1] + e[i]

    for i in range(slong):
        # Build regressor vector for current period i: [1, log(k[i]), a[i], log(k[i])^2, a[i]^2, log(k[i])*a[i]]
        X[i, 0] = 1.0
        X[i, 1] = np.log(k[i])
        X[i, 2] = a[i]
        X[i, 3] = (np.log(k[i]))**2
        X[i, 4] = a[i]**2
        X[i, 5] = np.log(k[i]) * a[i]
        
        # Compute lb[i] = exp( dot(X[i], b0) )
        dot_val = 0.0
        for p in range(nb_expl_vars):
            dot_val += X[i, p] * b0[p]
        lb = np.exp(dot_val)
        # Compute investment
        iv = np.exp(a[i]) * (k[i]**alpha) - lb**(-1.0 / gamma)
        # Implied savings
        k[i + 1] = (1.0 - delta) * k[i] + iv
        
        # For each of the N innovations compute a simulated realization for y
        for j in range(number_nodes):
            # Next period's TFP shock
            a_next = rho_tfp * a[i] + quadrature_nodes[j] #+ E[i, j]
            # Build regressor for next period using k[i+1] and a_next
            X_next0 = 1.0
            X_next1 = np.log(k[i+1])
            X_next2 = a_next
            X_next3 = (np.log(k[i+1]))**2
            X_next4 = a_next**2
            X_next5 = np.log(k[i+1]) * a_next
            dot_val_next = (X_next0 * b0[0] + X_next1 * b0[1] + X_next2 * b0[2] +
                            X_next3 * b0[3] + X_next4 * b0[4] + X_next5 * b0[5])
            lb_next = np.exp(dot_val_next)

            y_temp[j] = beta * (lb_next * (alpha * np.exp(a_next) * (k[i+1]**(alpha-1)) + 1.0 - delta) )

        # Average the N innovations to form the simulated y for period i
        s = 0.0
        for j in range(number_nodes):
            s += quadrature_weights[j]*y_temp[j]
        # Calculate error: Gaussian - implied by current linear model (E_t - lb)
        ## Constraint not binding
        y[i] = s - lb

    return y

# %% [markdown]
# Run for several choices of $N$.

# %%
# --------------------------------------------------------------------------
# Main code (outside numba) to run the PEA iterations.
# --------------------------------------------------------------------------
list_N = [1, 2, 5, 10, 50, 100, 200, 500, 1000]
MSE_N = np.zeros(len(list_N)) #In-sample 
MSIE_N = np.zeros(len(list_N)) #Mean square integration error, out-sample
Time_N = np.zeros(len(list_N))
# To store stats on accuracy:
mean_abs_ut_N, mean_square_ut_N, std_ut_N, dhm_stat_N, c_equivalent_N = np.zeros(len(list_N)), np.zeros(len(list_N)), np.zeros(len(list_N)), np.zeros(len(list_N)), np.zeros(len(list_N))

nb_expl_vars = 6  # number of explanatory variables
long = 20000
init = 500
slong = init + long
T = np.arange(init, slong - 1)  # Select current period    
T1 = np.arange(init + 1, slong) # Select period t+1

tol = 1e-8
gam = 1.0  # smoothing parameter
max_iter = 50 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

# Steady state calculations (using your model's parameters)
kss = ((1 - params.beta * (1 - params.delta)) / (params.alpha * params.beta)) ** (1 / (params.alpha - 1))
# Innovations for the out-sample test
e_test = params.std_tfp * np.random.randn(slong) #New shocks

#for N in range(1, max_N+1):
for (index_N, N) in enumerate(list_N):
    print("Running simulation with N =", N)
    b0_current = coeff_array_0.copy()  # initial guess (shape (6,))
    
    np.random.seed(1)
    # innovation for state vector (not used directly in simulation here
    # for M large, no need to redraw many times.
    e = params.std_tfp * np.random.randn(slong)
    # extra draws for each state: shape (slong, N)
    E = params.std_tfp * np.random.randn(slong, N)

    # Warmup (compilation) first go
    X_data, y_out = simulate_path_N(slong, kss, e, E, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N)
    
    start_time = time.time()
    iter_num = 1
    crit = 1.0
    # Run a fixed number of iterations (or use while crit > tol)
    while iter_num < max_iter:
        if iter_num % redraw_shocks_every == 0:
            e[:], E[:,:] = generate_random_arrays(slong, N, params.std_tfp)
    
        # Call the numba-compiled simulation to get regression data.
        X_data, y_out = simulate_path_N(slong, kss, e, E, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N, log_y = False)
        bt, _, _, _ = np.linalg.lstsq(X_data[T, :], np.log(y_out[T]), rcond=None)
        # regression y_m = log(average)
        #X_data, y_out = simulate_path_N(slong, kss, e, E, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N, log_y = True)
        #bt, _, _, _ = np.linalg.lstsq(X_data[T, :], y_out[T], rcond=None)
        
        b_new = gam * bt + (1 - gam) * b0_current
        crit = np.max(np.abs(b_new - b0_current))
        b0_current = b_new.copy()
        print("Iteration:", iter_num, "Conv. crit.:", crit)
        iter_num += 1
    end_time = time.time()
    elapsed = end_time - start_time
    print("Elapsed time for N =", N, ":", elapsed, "seconds")
    # Compute residuals and In-sample MSE.
    Res = y_out - np.exp(np.dot(X_data, b0_current))
    MSE = np.mean(Res ** 2)
    MSE_N[index_N] = MSE
    # Alternative measure of accuracy
    mean_abs_ut_N[index_N], mean_square_ut_N[index_N], std_ut_N[index_N], dhm_stat_N[index_N], c_equivalent_N[index_N] = dhm_accuracy_test(params, b0_current)
    # Mean square integration error
    err = evaluate_Et_Gauss_path(slong, kss, e_test, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, len(params.nodes_flat), params.nodes_flat, params.weights, nb_expl_vars)
    MSIE_N[index_N] = np.mean(err[init:]**2)
    Time_N[index_N] = elapsed
    print("Final iteration N:", N, "Iterations:", iter_num, "OLS MSE:", MSE, "MISE:", MSIE_N[index_N])
    print("Final b0:", b0_current)
# Out:
# Running simulation with N = 1
# Iteration: 1 Conv. crit.: 0.0874345111250352
# Iteration: 2 Conv. crit.: 0.05734066978738961
# Iteration: 3 Conv. crit.: 0.022364420841337718
# Iteration: 4 Conv. crit.: 0.010051646591367022
# Iteration: 5 Conv. crit.: 0.007282227023373174
# Iteration: 6 Conv. crit.: 0.004350863371960015
# Iteration: 7 Conv. crit.: 0.002337445610631657
# Iteration: 8 Conv. crit.: 0.001167996722755707
# Iteration: 9 Conv. crit.: 0.000551144658407797
# Iteration: 10 Conv. crit.: 0.0002468973515399875
# Iteration: 11 Conv. crit.: 0.00011493245771210248
# Iteration: 12 Conv. crit.: 6.670371333827863e-05
# Iteration: 13 Conv. crit.: 3.780891635796202e-05
# Iteration: 14 Conv. crit.: 2.109077056444697e-05
# Iteration: 15 Conv. crit.: 1.1634524663461931e-05
# Iteration: 16 Conv. crit.: 6.367357344383429e-06
# Iteration: 17 Conv. crit.: 3.4648171098883296e-06
# Iteration: 18 Conv. crit.: 1.8775031744855397e-06
# Iteration: 19 Conv. crit.: 1.014225954998338e-06
# Iteration: 20 Conv. crit.: 5.466155204025824e-07
# Iteration: 21 Conv. crit.: 2.9408068524805486e-07
# Iteration: 22 Conv. crit.: 1.580025321690215e-07
# Iteration: 23 Conv. crit.: 8.480094737528532e-08
# Iteration: 24 Conv. crit.: 4.547434107049497e-08
# Iteration: 25 Conv. crit.: 2.4368252526940637e-08
# Iteration: 26 Conv. crit.: 1.3050212355203428e-08
# Iteration: 27 Conv. crit.: 6.9851218142957805e-09
# Iteration: 28 Conv. crit.: 3.736874587545458e-09
# Iteration: 29 Conv. crit.: 1.998166743177876e-09
# Iteration: 30 Conv. crit.: 1.0679123141343894e-09
# Iteration: 31 Conv. crit.: 5.704351435653621e-10
# Iteration: 32 Conv. crit.: 3.04542946416575e-10
# Iteration: 33 Conv. crit.: 1.6248380418915076e-10
# Iteration: 34 Conv. crit.: 8.663014749998865e-11
# Iteration: 35 Conv. crit.: 4.614908455380373e-11
# Iteration: 36 Conv. crit.: 2.4568347356535014e-11
# Iteration: 37 Conv. crit.: 1.3058221171036166e-11
# Iteration: 38 Conv. crit.: 6.9331207441791776e-12
# Iteration: 39 Conv. crit.: 3.680389326632394e-12
# Iteration: 40 Conv. crit.: 1.9430013153964865e-12
# Iteration: 41 Conv. crit.: 1.0303979891546078e-12
# Iteration: 42 Conv. crit.: 5.39124300757976e-13
# Iteration: 43 Conv. crit.: 2.857714065385153e-13
# Iteration: 44 Conv. crit.: 1.511013536514838e-13
# Iteration: 45 Conv. crit.: 7.760458942129844e-14
# Iteration: 46 Conv. crit.: 4.4374226515486725e-14
# Iteration: 47 Conv. crit.: 2.8206603719382883e-14
# Iteration: 48 Conv. crit.: 1.4432899320127035e-14
# Iteration: 49 Conv. crit.: 6.5503158452884236e-15
# Elapsed time for N = 1 : 0.8490478992462158 seconds
# Final iteration N: 1 Iterations: 50 OLS MSE: 5.174654484331825e-05 MISE: 4.124247989672008e-08
# Final b0: [ 0.29264557 -0.47668793 -0.71353382 -0.05670685 -0.05045437  0.2178952 ]
# Running simulation with N = 2
# Iteration: 1 Conv. crit.: 0.126468165453936
# Iteration: 2 Conv. crit.: 0.0301085471145998
# Iteration: 3 Conv. crit.: 0.010488378102520124
# Iteration: 4 Conv. crit.: 0.004647025508595581
# Iteration: 5 Conv. crit.: 0.0018705233278075162
# Iteration: 6 Conv. crit.: 0.0010131255058260513
# Iteration: 7 Conv. crit.: 0.0008350729398366313
# Iteration: 8 Conv. crit.: 0.0005508032195563339
# Iteration: 9 Conv. crit.: 0.00032715347354482505
# Iteration: 10 Conv. crit.: 0.00018608275426081067
# Iteration: 11 Conv. crit.: 0.00010599212579660844
# Iteration: 12 Conv. crit.: 5.716584910832323e-05
# Iteration: 13 Conv. crit.: 2.944017439146518e-05
# Iteration: 14 Conv. crit.: 1.4535752604696861e-05
# Iteration: 15 Conv. crit.: 7.018884818021931e-06
# Iteration: 16 Conv. crit.: 3.5620332788921516e-06
# Iteration: 17 Conv. crit.: 1.8382262352290013e-06
# Iteration: 18 Conv. crit.: 1.0111028425630053e-06
# Iteration: 19 Conv. crit.: 5.653275523265222e-07
# Iteration: 20 Conv. crit.: 3.19202418386233e-07
# Iteration: 21 Conv. crit.: 1.7877605740235225e-07
# Iteration: 22 Conv. crit.: 9.946703172225568e-08
# Iteration: 23 Conv. crit.: 5.504119571231314e-08
# Iteration: 24 Conv. crit.: 3.03210058172354e-08
# Iteration: 25 Conv. crit.: 1.6640766986597555e-08
# Iteration: 26 Conv. crit.: 9.104156650785455e-09
# Iteration: 27 Conv. crit.: 4.967688149726257e-09
# Iteration: 28 Conv. crit.: 2.704494850291894e-09
# Iteration: 29 Conv. crit.: 1.4695049621593625e-09
# Iteration: 30 Conv. crit.: 7.970971660498094e-10
# Iteration: 31 Conv. crit.: 4.317100010808872e-10
# Iteration: 32 Conv. crit.: 2.3347856981104087e-10
# Iteration: 33 Conv. crit.: 1.26120669463603e-10
# Iteration: 34 Conv. crit.: 6.803002605693109e-11
# Iteration: 35 Conv. crit.: 3.6651015555833055e-11
# Iteration: 36 Conv. crit.: 1.9717893984250168e-11
# Iteration: 37 Conv. crit.: 1.0738909761442983e-11
# Iteration: 38 Conv. crit.: 5.8826971072178935e-12
# Iteration: 39 Conv. crit.: 3.226016676016741e-12
# Iteration: 40 Conv. crit.: 1.7740114932607298e-12
# Iteration: 41 Conv. crit.: 9.56415502351149e-13
# Iteration: 42 Conv. crit.: 5.29479238231545e-13
# Iteration: 43 Conv. crit.: 2.915168106909505e-13
# Iteration: 44 Conv. crit.: 1.5787371410169726e-13
# Iteration: 45 Conv. crit.: 7.889522368742519e-14
# Iteration: 46 Conv. crit.: 4.7406523151494184e-14
# Iteration: 47 Conv. crit.: 2.696454171058349e-14
# Iteration: 48 Conv. crit.: 2.0289325775024736e-14
# Iteration: 49 Conv. crit.: 7.66053886991358e-15
# Elapsed time for N = 2 : 0.23021841049194336 seconds
# Final iteration N: 2 Iterations: 50 OLS MSE: 2.4793510866101925e-05 MISE: 9.515275763023327e-09
# Final b0: [ 0.3152596  -0.54163259 -0.6121342  -0.0096496  -0.0720545   0.07630529]
# Running simulation with N = 5
# Iteration: 1 Conv. crit.: 0.10167251850725226
# Iteration: 2 Conv. crit.: 0.029476006277133426
# Iteration: 3 Conv. crit.: 0.009125827521757224
# Iteration: 4 Conv. crit.: 0.004200835425530319
# Iteration: 5 Conv. crit.: 0.0016476601192456641
# Iteration: 6 Conv. crit.: 0.0007956884228397243
# Iteration: 7 Conv. crit.: 0.00040199961896780767
# Iteration: 8 Conv. crit.: 0.0002513932089459603
# Iteration: 9 Conv. crit.: 0.00017936868821749608
# Iteration: 10 Conv. crit.: 0.00012421687279814964
# Iteration: 11 Conv. crit.: 7.832749046693399e-05
# Iteration: 12 Conv. crit.: 4.756753244063161e-05
# Iteration: 13 Conv. crit.: 2.938974888654078e-05
# Iteration: 14 Conv. crit.: 1.757641577598834e-05
# Iteration: 15 Conv. crit.: 1.0237137485255565e-05
# Iteration: 16 Conv. crit.: 5.835622870903334e-06
# Iteration: 17 Conv. crit.: 3.2686750699728595e-06
# Iteration: 18 Conv. crit.: 1.8047012026317644e-06
# Iteration: 19 Conv. crit.: 9.84676843521215e-07
# Iteration: 20 Conv. crit.: 5.320279284209972e-07
# Iteration: 21 Conv. crit.: 2.851424342892317e-07
# Iteration: 22 Conv. crit.: 1.5180366379208277e-07
# Iteration: 23 Conv. crit.: 8.037124810122975e-08
# Iteration: 24 Conv. crit.: 4.235865565249686e-08
# Iteration: 25 Conv. crit.: 2.2241719535576188e-08
# Iteration: 26 Conv. crit.: 1.164371003781195e-08
# Iteration: 27 Conv. crit.: 6.081141534775014e-09
# Iteration: 28 Conv. crit.: 3.1702712954828627e-09
# Iteration: 29 Conv. crit.: 1.650625344740142e-09
# Iteration: 30 Conv. crit.: 8.587336813858926e-10
# Iteration: 31 Conv. crit.: 4.4661122022837674e-10
# Iteration: 32 Conv. crit.: 2.323113368341012e-10
# Iteration: 33 Conv. crit.: 1.2092678247643818e-10
# Iteration: 34 Conv. crit.: 6.302151855930305e-11
# Iteration: 35 Conv. crit.: 3.289976624465396e-11
# Iteration: 36 Conv. crit.: 1.7221876702500083e-11
# Iteration: 37 Conv. crit.: 9.038589321441748e-12
# Iteration: 38 Conv. crit.: 4.764175165483664e-12
# Iteration: 39 Conv. crit.: 2.52328713479244e-12
# Iteration: 40 Conv. crit.: 1.3423984146498924e-12
# Iteration: 41 Conv. crit.: 7.190359418984826e-13
# Iteration: 42 Conv. crit.: 3.8884173658715326e-13
# Iteration: 43 Conv. crit.: 2.1346813205980197e-13
# Iteration: 44 Conv. crit.: 1.1560197243909442e-13
# Iteration: 45 Conv. crit.: 6.404599073306372e-14
# Iteration: 46 Conv. crit.: 3.549938121238938e-14
# Iteration: 47 Conv. crit.: 2.0317081350640365e-14
# Iteration: 48 Conv. crit.: 1.301736496372996e-14
# Iteration: 49 Conv. crit.: 6.994405055138486e-15
# Elapsed time for N = 5 : 0.3537557125091553 seconds
# Final iteration N: 5 Iterations: 50 OLS MSE: 1.0309626644150564e-05 MISE: 4.492385044813572e-09
# Final b0: [ 0.30105666 -0.5029747  -0.63950079 -0.03549341 -0.0763217   0.10781223]
# Running simulation with N = 10
# Iteration: 1 Conv. crit.: 0.08267724116958175
# Iteration: 2 Conv. crit.: 0.04095463204357741
# Iteration: 3 Conv. crit.: 0.012863785519192206
# Iteration: 4 Conv. crit.: 0.0031768397245464097
# Iteration: 5 Conv. crit.: 0.0010583992288294708
# Iteration: 6 Conv. crit.: 0.0007603373409190428
# Iteration: 7 Conv. crit.: 0.0004775384397078669
# Iteration: 8 Conv. crit.: 0.00030922738263494676
# Iteration: 9 Conv. crit.: 0.00019760690508252576
# Iteration: 10 Conv. crit.: 0.00011866825001982662
# Iteration: 11 Conv. crit.: 7.133837633210849e-05
# Iteration: 12 Conv. crit.: 4.416330589834816e-05
# Iteration: 13 Conv. crit.: 2.6994020079704195e-05
# Iteration: 14 Conv. crit.: 1.6268904733537926e-05
# Iteration: 15 Conv. crit.: 9.670056172431107e-06
# Iteration: 16 Conv. crit.: 5.674303059685637e-06
# Iteration: 17 Conv. crit.: 3.2913606490547753e-06
# Iteration: 18 Conv. crit.: 1.8897707147746967e-06
# Iteration: 19 Conv. crit.: 1.0754170369636773e-06
# Iteration: 20 Conv. crit.: 6.072852101191017e-07
# Iteration: 21 Conv. crit.: 3.4065497835078506e-07
# Iteration: 22 Conv. crit.: 1.8999725584500915e-07
# Iteration: 23 Conv. crit.: 1.0544982188831487e-07
# Iteration: 24 Conv. crit.: 5.828045530897885e-08
# Iteration: 25 Conv. crit.: 3.2096274860116125e-08
# Iteration: 26 Conv. crit.: 1.7623268927513536e-08
# Iteration: 27 Conv. crit.: 9.65247301532024e-09
# Iteration: 28 Conv. crit.: 5.2760741747759354e-09
# Iteration: 29 Conv. crit.: 2.8793008671756937e-09
# Iteration: 30 Conv. crit.: 1.5694164301471858e-09
# Iteration: 31 Conv. crit.: 8.54729440002977e-10
# Iteration: 32 Conv. crit.: 4.652752488842893e-10
# Iteration: 33 Conv. crit.: 2.53250045934017e-10
# Iteration: 34 Conv. crit.: 1.3787619657090744e-10
# Iteration: 35 Conv. crit.: 7.51105982965683e-11
# Iteration: 36 Conv. crit.: 4.095693229011488e-11
# Iteration: 37 Conv. crit.: 2.2364554652654078e-11
# Iteration: 38 Conv. crit.: 1.2232451163107783e-11
# Iteration: 39 Conv. crit.: 6.708925082143935e-12
# Iteration: 40 Conv. crit.: 3.686467797692217e-12
# Iteration: 41 Conv. crit.: 2.03384531438644e-12
# Iteration: 42 Conv. crit.: 1.1252387910332118e-12
# Iteration: 43 Conv. crit.: 6.24167384444263e-13
# Iteration: 44 Conv. crit.: 3.4958147487884617e-13
# Iteration: 45 Conv. crit.: 1.9491352976075405e-13
# Iteration: 46 Conv. crit.: 1.1014800183062334e-13
# Iteration: 47 Conv. crit.: 6.264433416447446e-14
# Iteration: 48 Conv. crit.: 3.4708347307343956e-14
# Iteration: 49 Conv. crit.: 2.085831507514513e-14
# Elapsed time for N = 10 : 0.5393686294555664 seconds
# Final iteration N: 10 Iterations: 50 OLS MSE: 5.102987988677734e-06 MISE: 2.0909594851951547e-09
# Final b0: [ 0.29584437 -0.48452198 -0.6711791  -0.05143474 -0.10007281  0.15950088]
# Running simulation with N = 50
# Iteration: 1 Conv. crit.: 0.0969527406547131
# Iteration: 2 Conv. crit.: 0.033413162033176014
# Iteration: 3 Conv. crit.: 0.009981306630262976
# Iteration: 4 Conv. crit.: 0.003046033467581366
# Iteration: 5 Conv. crit.: 0.0014921232803391526
# Iteration: 6 Conv. crit.: 0.0007092697067144771
# Iteration: 7 Conv. crit.: 0.00041905176055258286
# Iteration: 8 Conv. crit.: 0.00032432168377788395
# Iteration: 9 Conv. crit.: 0.00022680054646068148
# Iteration: 10 Conv. crit.: 0.00014835547943850558
# Iteration: 11 Conv. crit.: 9.240943733303253e-05
# Iteration: 12 Conv. crit.: 5.545051441514792e-05
# Iteration: 13 Conv. crit.: 3.232089981818065e-05
# Iteration: 14 Conv. crit.: 1.8415166844795716e-05
# Iteration: 15 Conv. crit.: 1.0306021476058635e-05
# Iteration: 16 Conv. crit.: 5.687042578833568e-06
# Iteration: 17 Conv. crit.: 3.103689510702834e-06
# Iteration: 18 Conv. crit.: 1.6792727225156678e-06
# Iteration: 19 Conv. crit.: 9.025403526485842e-07
# Iteration: 20 Conv. crit.: 4.826201435298438e-07
# Iteration: 21 Conv. crit.: 2.5709959365627366e-07
# Iteration: 22 Conv. crit.: 1.3658925539228317e-07
# Iteration: 23 Conv. crit.: 7.243216455787849e-08
# Iteration: 24 Conv. crit.: 3.836734455142654e-08
# Iteration: 25 Conv. crit.: 2.0312862392124487e-08
# Iteration: 26 Conv. crit.: 1.0754320170502929e-08
# Iteration: 27 Conv. crit.: 5.6962581873598594e-09
# Iteration: 28 Conv. crit.: 3.0196731365395024e-09
# Iteration: 29 Conv. crit.: 1.6026878157937574e-09
# Iteration: 30 Conv. crit.: 8.519212696400658e-10
# Iteration: 31 Conv. crit.: 4.5368665768652505e-10
# Iteration: 32 Conv. crit.: 2.4213168969833276e-10
# Iteration: 33 Conv. crit.: 1.2955320149998784e-10
# Iteration: 34 Conv. crit.: 6.951543507494051e-11
# Iteration: 35 Conv. crit.: 3.742210707979865e-11
# Iteration: 36 Conv. crit.: 2.0221269103615214e-11
# Iteration: 37 Conv. crit.: 1.0968503882935465e-11
# Iteration: 38 Conv. crit.: 5.9800775442653276e-12
# Iteration: 39 Conv. crit.: 3.275449356188176e-12
# Iteration: 40 Conv. crit.: 1.8044177263476513e-12
# Iteration: 41 Conv. crit.: 9.984096882575955e-13
# Iteration: 42 Conv. crit.: 5.593303598061539e-13
# Iteration: 43 Conv. crit.: 3.1048774662423284e-13
# Iteration: 44 Conv. crit.: 1.7530421558831222e-13
# Iteration: 45 Conv. crit.: 1.0502709812953981e-13
# Iteration: 46 Conv. crit.: 5.906386491005833e-14
# Iteration: 47 Conv. crit.: 3.530509218307998e-14
# Iteration: 48 Conv. crit.: 2.2315482794965646e-14
# Iteration: 49 Conv. crit.: 1.2656542480726785e-14
# Elapsed time for N = 50 : 2.1224374771118164 seconds
# Final iteration N: 50 Iterations: 50 OLS MSE: 1.021155685934731e-06 MISE: 2.3198302906819227e-10
# Final b0: [ 0.30246897 -0.5048435  -0.65103044 -0.03571964 -0.10221037  0.12875422]
# Running simulation with N = 100
# Iteration: 1 Conv. crit.: 0.10156826888067089
# Iteration: 2 Conv. crit.: 0.03014909994950188
# Iteration: 3 Conv. crit.: 0.008292098719966279
# Iteration: 4 Conv. crit.: 0.0031533581099405517
# Iteration: 5 Conv. crit.: 0.0015334831516464753
# Iteration: 6 Conv. crit.: 0.0007217101984552388
# Iteration: 7 Conv. crit.: 0.0003302691437642724
# Iteration: 8 Conv. crit.: 0.0002544598124466779
# Iteration: 9 Conv. crit.: 0.0001899795750257144
# Iteration: 10 Conv. crit.: 0.00013063667977922244
# Iteration: 11 Conv. crit.: 8.461909731538597e-05
# Iteration: 12 Conv. crit.: 5.240780120224775e-05
# Iteration: 13 Conv. crit.: 3.13656954441105e-05
# Iteration: 14 Conv. crit.: 1.8282547493336798e-05
# Iteration: 15 Conv. crit.: 1.0439839858350508e-05
# Iteration: 16 Conv. crit.: 5.8665161691145995e-06
# Iteration: 17 Conv. crit.: 3.2554628001946195e-06
# Iteration: 18 Conv. crit.: 1.7888850536856848e-06
# Iteration: 19 Conv. crit.: 9.75515713874664e-07
# Iteration: 20 Conv. crit.: 5.288399129443899e-07
# Iteration: 21 Conv. crit.: 2.8540510345342884e-07
# Iteration: 22 Conv. crit.: 1.5351177756750545e-07
# Iteration: 23 Conv. crit.: 8.236999157751335e-08
# Iteration: 24 Conv. crit.: 4.412430860967209e-08
# Iteration: 25 Conv. crit.: 2.3612794386451696e-08
# Iteration: 26 Conv. crit.: 1.2630312837269564e-08
# Iteration: 27 Conv. crit.: 6.755874790154159e-09
# Iteration: 28 Conv. crit.: 3.615189939076835e-09
# Iteration: 29 Conv. crit.: 1.936105178956815e-09
# Iteration: 30 Conv. crit.: 1.0380753340255566e-09
# Iteration: 31 Conv. crit.: 5.574107148076379e-10
# Iteration: 32 Conv. crit.: 2.9987635985495587e-10
# Iteration: 33 Conv. crit.: 1.6167929495214395e-10
# Iteration: 34 Conv. crit.: 8.739989287853689e-11
# Iteration: 35 Conv. crit.: 4.73800859657203e-11
# Iteration: 36 Conv. crit.: 2.5781113355272112e-11
# Iteration: 37 Conv. crit.: 1.4076795284978516e-11
# Iteration: 38 Conv. crit.: 7.72328034859271e-12
# Iteration: 39 Conv. crit.: 4.2533615518536294e-12
# Iteration: 40 Conv. crit.: 2.36384523066846e-12
# Iteration: 41 Conv. crit.: 1.3120338149263944e-12
# Iteration: 42 Conv. crit.: 7.403383461834778e-13
# Iteration: 43 Conv. crit.: 4.134748099460239e-13
# Iteration: 44 Conv. crit.: 2.385452946285227e-13
# Iteration: 45 Conv. crit.: 1.3954115640757436e-13
# Iteration: 46 Conv. crit.: 7.385758671318854e-14
# Iteration: 47 Conv. crit.: 4.606037773413618e-14
# Iteration: 48 Conv. crit.: 2.6825763832505345e-14
# Iteration: 49 Conv. crit.: 1.532107773982716e-14
# Elapsed time for N = 100 : 4.056137323379517 seconds
# Final iteration N: 100 Iterations: 50 OLS MSE: 5.119613416333049e-07 MISE: 1.564400416280234e-10
# Final b0: [ 0.30300778 -0.50612179 -0.6420557  -0.03495608 -0.08945051  0.11579534]
# Running simulation with N = 200
# Iteration: 1 Conv. crit.: 0.09577304952854826
# Iteration: 2 Conv. crit.: 0.034497992895995644
# Iteration: 3 Conv. crit.: 0.01030132449550436
# Iteration: 4 Conv. crit.: 0.0024888511725926765
# Iteration: 5 Conv. crit.: 0.001267016531301457
# Iteration: 6 Conv. crit.: 0.0006372010915182136
# Iteration: 7 Conv. crit.: 0.00035354813665000595
# Iteration: 8 Conv. crit.: 0.0002551646605873925
# Iteration: 9 Conv. crit.: 0.000167404641176927
# Iteration: 10 Conv. crit.: 0.00011535742663189297
# Iteration: 11 Conv. crit.: 7.577497326471949e-05
# Iteration: 12 Conv. crit.: 4.7908788915557166e-05
# Iteration: 13 Conv. crit.: 2.9374769695264535e-05
# Iteration: 14 Conv. crit.: 1.757071187162562e-05
# Iteration: 15 Conv. crit.: 1.030187747146083e-05
# Iteration: 16 Conv. crit.: 5.942827940114137e-06
# Iteration: 17 Conv. crit.: 3.383199891057731e-06
# Iteration: 18 Conv. crit.: 1.9053278962621878e-06
# Iteration: 19 Conv. crit.: 1.0635732746316906e-06
# Iteration: 20 Conv. crit.: 5.894011163437574e-07
# Iteration: 21 Conv. crit.: 3.2468848294719965e-07
# Iteration: 22 Conv. crit.: 1.7799374497917686e-07
# Iteration: 23 Conv. crit.: 9.718914870116002e-08
# Iteration: 24 Conv. crit.: 5.2898029567760574e-08
# Iteration: 25 Conv. crit.: 2.8718177225162123e-08
# Iteration: 26 Conv. crit.: 1.556038771444168e-08
# Iteration: 27 Conv. crit.: 8.418868643889077e-09
# Iteration: 28 Conv. crit.: 4.550520280033332e-09
# Iteration: 29 Conv. crit.: 2.4582731544819936e-09
# Iteration: 30 Conv. crit.: 1.3278270288852312e-09
# Iteration: 31 Conv. crit.: 7.174277560917375e-10
# Iteration: 32 Conv. crit.: 3.87890816688774e-10
# Iteration: 33 Conv. crit.: 2.0994411764618803e-10
# Iteration: 34 Conv. crit.: 1.1380606179667296e-10
# Iteration: 35 Conv. crit.: 6.181710698882625e-11
# Iteration: 36 Conv. crit.: 3.3655619957606575e-11
# Iteration: 37 Conv. crit.: 1.838625085515133e-11
# Iteration: 38 Conv. crit.: 1.0063380684321999e-11
# Iteration: 39 Conv. crit.: 5.543759895587641e-12
# Iteration: 40 Conv. crit.: 3.065783737987715e-12
# Iteration: 41 Conv. crit.: 1.6995987950352287e-12
# Iteration: 42 Conv. crit.: 9.504758091694043e-13
# Iteration: 43 Conv. crit.: 5.336703301495049e-13
# Iteration: 44 Conv. crit.: 3.007594173709549e-13
# Iteration: 45 Conv. crit.: 1.6832368832098155e-13
# Iteration: 46 Conv. crit.: 1.0261236305098009e-13
# Iteration: 47 Conv. crit.: 5.0154325137441447e-14
# Iteration: 48 Conv. crit.: 3.2987501619174964e-14
# Iteration: 49 Conv. crit.: 2.288447209508604e-14
# Elapsed time for N = 200 : 7.880913019180298 seconds
# Final iteration N: 200 Iterations: 50 OLS MSE: 2.5305026772511645e-07 MISE: 8.197313883194772e-11
# Final b0: [ 0.3002155  -0.49789674 -0.65290219 -0.04100346 -0.09965086  0.13149536]
# Running simulation with N = 500
# Iteration: 1 Conv. crit.: 0.1003983489037886
# Iteration: 2 Conv. crit.: 0.03217151030447518
# Iteration: 3 Conv. crit.: 0.009487377191496171
# Iteration: 4 Conv. crit.: 0.0027554727465415874
# Iteration: 5 Conv. crit.: 0.0013435145852983554
# Iteration: 6 Conv. crit.: 0.0006421765066528806
# Iteration: 7 Conv. crit.: 0.000311343240023812
# Iteration: 8 Conv. crit.: 0.00024633894914068144
# Iteration: 9 Conv. crit.: 0.00017767442186000793
# Iteration: 10 Conv. crit.: 0.00012015570804640996
# Iteration: 11 Conv. crit.: 7.737332945983999e-05
# Iteration: 12 Conv. crit.: 4.795512493505072e-05
# Iteration: 13 Conv. crit.: 2.8840331384921702e-05
# Iteration: 14 Conv. crit.: 1.693604687741379e-05
# Iteration: 15 Conv. crit.: 9.758823856773069e-06
# Iteration: 16 Conv. crit.: 5.538953070816088e-06
# Iteration: 17 Conv. crit.: 3.106160580010342e-06
# Iteration: 18 Conv. crit.: 1.7251922406341658e-06
# Iteration: 19 Conv. crit.: 9.508469623886739e-07
# Iteration: 20 Conv. crit.: 5.208617399055093e-07
# Iteration: 21 Conv. crit.: 2.839387412967298e-07
# Iteration: 22 Conv. crit.: 1.5419446261488723e-07
# Iteration: 23 Conv. crit.: 8.348871320673634e-08
# Iteration: 24 Conv. crit.: 4.510379177091739e-08
# Iteration: 25 Conv. crit.: 2.4326979597422138e-08
# Iteration: 26 Conv. crit.: 1.3106287860553678e-08
# Iteration: 27 Conv. crit.: 7.056448564357609e-09
# Iteration: 28 Conv. crit.: 3.79828846153174e-09
# Iteration: 29 Conv. crit.: 2.0447811499568758e-09
# Iteration: 30 Conv. crit.: 1.1013521900027357e-09
# Iteration: 31 Conv. crit.: 5.937042246717539e-10
# Iteration: 32 Conv. crit.: 3.204361359587793e-10
# Iteration: 33 Conv. crit.: 1.7322401846264768e-10
# Iteration: 34 Conv. crit.: 9.382419841053036e-11
# Iteration: 35 Conv. crit.: 5.093699073643876e-11
# Iteration: 36 Conv. crit.: 2.7730082119425958e-11
# Iteration: 37 Conv. crit.: 1.5146509046992662e-11
# Iteration: 38 Conv. crit.: 8.309977705955873e-12
# Iteration: 39 Conv. crit.: 4.5714543261965446e-12
# Iteration: 40 Conv. crit.: 2.5261598368686577e-12
# Iteration: 41 Conv. crit.: 1.4026696470992306e-12
# Iteration: 42 Conv. crit.: 7.935457846386385e-13
# Iteration: 43 Conv. crit.: 4.3443026953582375e-13
# Iteration: 44 Conv. crit.: 2.546990396368187e-13
# Iteration: 45 Conv. crit.: 1.375705105388647e-13
# Iteration: 46 Conv. crit.: 8.477940571793852e-14
# Iteration: 47 Conv. crit.: 5.2208237732997986e-14
# Iteration: 48 Conv. crit.: 2.55351295663786e-14
# Iteration: 49 Conv. crit.: 2.1316282072803006e-14
# Elapsed time for N = 500 : 19.48548173904419 seconds
# Final iteration N: 500 Iterations: 50 OLS MSE: 1.0149252380563864e-07 MISE: 1.2809433056319288e-11
# Final b0: [ 0.30199824 -0.50312046 -0.64674843 -0.03718938 -0.09212723  0.12216971]
# Running simulation with N = 1000
# Iteration: 1 Conv. crit.: 0.09913524997656409
# Iteration: 2 Conv. crit.: 0.03260002502678705
# Iteration: 3 Conv. crit.: 0.009648056507834735
# Iteration: 4 Conv. crit.: 0.0027594152572475994
# Iteration: 5 Conv. crit.: 0.0013540555758247974
# Iteration: 6 Conv. crit.: 0.0006514675325661745
# Iteration: 7 Conv. crit.: 0.00032275447058544016
# Iteration: 8 Conv. crit.: 0.00025315705949466305
# Iteration: 9 Conv. crit.: 0.0001815744302636757
# Iteration: 10 Conv. crit.: 0.00012233777940905133
# Iteration: 11 Conv. crit.: 7.857827600085687e-05
# Iteration: 12 Conv. crit.: 4.861404292647031e-05
# Iteration: 13 Conv. crit.: 2.9197515549736486e-05
# Iteration: 14 Conv. crit.: 1.7127999410476713e-05
# Iteration: 15 Conv. crit.: 9.861074546729798e-06
# Iteration: 16 Conv. crit.: 5.592931334882922e-06
# Iteration: 17 Conv. crit.: 3.1343933065974827e-06
# Iteration: 18 Conv. crit.: 1.739818633911261e-06
# Iteration: 19 Conv. crit.: 9.583489250369892e-07
# Iteration: 20 Conv. crit.: 5.246685596121958e-07
# Iteration: 21 Conv. crit.: 2.858477889805533e-07
# Iteration: 22 Conv. crit.: 1.5513901319152978e-07
# Iteration: 23 Conv. crit.: 8.394865171068577e-08
# Iteration: 24 Conv. crit.: 4.532332657791738e-08
# Iteration: 25 Conv. crit.: 2.442907733046784e-08
# Iteration: 26 Conv. crit.: 1.3152049033182678e-08
# Iteration: 27 Conv. crit.: 7.075846436555011e-09
# Iteration: 28 Conv. crit.: 3.80574606551054e-09
# Iteration: 29 Conv. crit.: 2.0470959372076436e-09
# Iteration: 30 Conv. crit.: 1.1016367817973105e-09
# Iteration: 31 Conv. crit.: 5.93294927075938e-10
# Iteration: 32 Conv. crit.: 3.1989583204605765e-10
# Iteration: 33 Conv. crit.: 1.7273955876806468e-10
# Iteration: 34 Conv. crit.: 9.345149654116369e-11
# Iteration: 35 Conv. crit.: 5.0671536411250884e-11
# Iteration: 36 Conv. crit.: 2.7565186244693507e-11
# Iteration: 37 Conv. crit.: 1.502480084791813e-11
# Iteration: 38 Conv. crit.: 8.222506009403219e-12
# Iteration: 39 Conv. crit.: 4.524075558620666e-12
# Iteration: 40 Conv. crit.: 2.4904939222025746e-12
# Iteration: 41 Conv. crit.: 1.3891943151378428e-12
# Iteration: 42 Conv. crit.: 7.71063768389979e-13
# Iteration: 43 Conv. crit.: 4.3251513481834536e-13
# Iteration: 44 Conv. crit.: 2.5990321006474915e-13
# Iteration: 45 Conv. crit.: 1.3139489496438728e-13
# Iteration: 46 Conv. crit.: 6.349087922075114e-14
# Iteration: 47 Conv. crit.: 6.69048150214735e-14
# Iteration: 48 Conv. crit.: 2.930988785010413e-14
# Iteration: 49 Conv. crit.: 1.712519015484304e-14
# Elapsed time for N = 1000 : 39.045673847198486 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 5.198080519232868e-08 MISE: 1.93900629064801e-11
# Final b0: [ 0.30174709 -0.50246965 -0.64829364 -0.03762014 -0.09359587  0.12414447]

# %%
create_plots(list_N, MSE_N, Time_N, mean_square_ut_N, dhm_stat_N, np.abs(c_equivalent_N), ref_index_plot=0)

# %%
index_ref=0
plt.plot(list_N, np.sqrt(MSIE_N), label="Square root MSIE")
plt.plot(list_N, np.sqrt(MSIE_N[index_ref]*(np.array(list_N[index_ref])/np.array(list_N))), label="1/sqrt(N) decay")
plt.xlabel("sqrt(MSIE)")
plt.xlabel("N")
plt.legend()

# %% [markdown]
# #### Gaussian quadrature
#
# Use quadrature node to calculate the expectation wrt to next period's innovation.

# %%
@njit
def simulate_paths_Gauss(slong, kss, e, b0, beta, gamma, alpha, delta, rho_tfp, number_nodes, quadrature_nodes, quadrature_weights, nb_expl_vars):
    """
    Simulates the model path period by period.
    
    Parameters:
        slong   : total number of simulation periods (integer)
        kss     : steady state capital (float)
        e       : array of nnovations of shape (slong)
        b0      : coefficient vector (array of length nb_expl_vars)
        beta    : discount factor (float)
        gamma   : CRRA coefficient (float)
        alpha   : production elasticity (float)
        delta   : depreciation rate (float)
        rho_tfp : AR(1) coefficient for TFP (float)
        number_nodes: number of quadrature nodes
        quadrature_nodes: quadrature nodes
        quadrature_weights: quadrature weights
        nb_expl_vars: number of explanatory variables in regression
    """
    # Preallocate arrays
    a = np.zeros(slong)
    k      = np.zeros(slong + 1)    # capital path (slong+1 because we update k[i+1])
    y      = np.zeros(slong)        # simulated y
    X      = np.zeros((slong, nb_expl_vars))     # regressor matrix (6 variables)
    y_temp = np.zeros(number_nodes)             # temporary array for innovations

    # Initialize state.
    k[0] = kss
    a[0] = 0.0
    for i in range(1, slong):
        a[i] = rho_tfp * a[i-1] + e[i]

    for i in range(slong):
        # Build regressor vector for current period i: [1, log(k[i]), a[i], log(k[i])^2, a[i]^2, log(k[i])*a[i]]
        X[i, 0] = 1.0
        X[i, 1] = np.log(k[i])
        X[i, 2] = a[i]
        X[i, 3] = (np.log(k[i]))**2
        X[i, 4] = a[i]**2
        X[i, 5] = np.log(k[i]) * a[i]
        
        # Compute lb[i] = exp( dot(X[i], b0) )
        dot_val = 0.0
        for p in range(nb_expl_vars):
            dot_val += X[i, p] * b0[p]
        lb = np.exp(dot_val)
        # Compute investment
        iv = np.exp(a[i]) * (k[i]**alpha) - lb**(-1.0 / gamma)
        k[i + 1] = (1.0 - delta) * k[i] + iv
        
        # For each of the N innovations compute a simulated realization for y
        for j in range(number_nodes):
            # Next period's TFP shock
            a_next = rho_tfp * a[i] + quadrature_nodes[j] #+ E[i, j]
            # Build regressor for next period using k[i+1] and a_next
            X_next0 = 1.0
            X_next1 = np.log(k[i+1])
            X_next2 = a_next
            X_next3 = (np.log(k[i+1]))**2
            X_next4 = a_next**2
            X_next5 = np.log(k[i+1]) * a_next
            dot_val_next = (X_next0 * b0[0] + X_next1 * b0[1] + X_next2 * b0[2] +
                            X_next3 * b0[3] + X_next4 * b0[4] + X_next5 * b0[5])
            lb_next = np.exp(dot_val_next)

            y_temp[j] = beta * (lb_next * (alpha * np.exp(a_next) * (k[i+1]**(alpha-1)) + 1.0 - delta))
            # Average the N innovations:
            # Take into account quadratue weights
            #y[i] += quadrature_weights[j]*y_temp[j]
        # Average the N innovations to form the simulated y for period i
        s = 0.0
        for j in range(number_nodes):
            s += quadrature_weights[j]*y_temp[j]
        y[i] = s 
    return X, y

# %%
# --------------------------------------------------------------------------
# PEA with quadrature nodes
# --------------------------------------------------------------------------
list_N_Gauss = [0, 1, 2, 3, 4, 5]
MSE_N_Gauss = np.zeros(len(list_N_Gauss))
MSIE_N_Gauss = np.zeros(len(list_N_Gauss))
Time_N_Gauss = np.zeros(len(list_N_Gauss))
mean_abs_ut_N_Gauss =  np.zeros(len(list_N_Gauss ))
mean_square_ut_N_Gauss =  np.zeros(len(list_N_Gauss ))
std_ut_N_Gauss =  np.zeros(len(list_N_Gauss ))
dhm_stat_N_Gauss =  np.zeros(len(list_N_Gauss ))
c_equivalent_N_Gauss = np.zeros(len(list_N_Gauss))

nb_expl_vars = 6  # number of explanatory variables
long = 20000
init = 500
slong = init + long
T = np.arange(init, slong - 1)  # Select current period    
T1 = np.arange(init + 1, slong) # Select period t+1

tol = 1e-8
gam = 1.0  # smoothing parameter
max_iter = 50 # max number of iterations
redraw_shocks_every = 1000 #redraw new realizations of innovations (new state and innovation vectors)

# Steady state calculations (using your model's parameters)
kss = ((1 - params.beta * (1 - params.delta)) / (params.alpha * params.beta)) ** (1 / (params.alpha - 1))

b0_current = coeff_array_0.copy()  # initial guess (shape (6,))

np.random.seed(1)
# innovation for state vector 
e = params.std_tfp * np.random.randn(slong)

#for N in range(1, max_N+1):
for (index_N, N_Gauss) in enumerate(list_N_Gauss):
    # create nodes:
    params_local = MyParams(N_chosen, M_chosen, lr_chosen, optimizer_chosen,
                  nb_epochs_chosen, N_Gauss,
                  params.beta, params.alpha, params.gamma, params.delta,
                  params.std_tfp, rho_chosen)
    
    # Warmup (compilation) first go
    X_data, y_out = simulate_paths_Gauss(slong, kss, e , b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, len(params_local.nodes_flat), params_local.nodes_flat, params_local.weights, nb_expl_vars)
    
    start_time = time.time()
    iter_num = 1
    crit = 1.0
    # Run a fixed number of iterations (or use while crit > tol)
    while iter_num < max_iter:
        #np.random.seed(1)
        if iter_num % redraw_shocks_every == 0:
            e[:], E[:,:] = generate_random_arrays(slong, N, params.std_tfp)
    
        # If drawing new shocks
        #e[:], E[:,:] = generate_random_arrays(slong, N, params.std_tfp)
        # Call the numba-compiled simulation to get regression data.
        #X_data, y_out = simulate_paths_Gauss_old(b0_current, params, nb_expl_vars, slong, kss, params_local.nodes_flat, params_local.weights)
        X_data, y_out = simulate_paths_Gauss(slong, kss, e, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, len(params_local.nodes_flat), params_local.nodes_flat, params_local.weights, nb_expl_vars)
    
        # Remove
        X_data = X_data[T,:]
        y_out = y_out[T]
        bt, _, _, _ = np.linalg.lstsq(X_data, np.log(y_out), rcond=None)
        b_new = gam * bt + (1 - gam) * b0_current
        crit = np.max(np.abs(b_new - b0_current))
        b0_current = b_new.copy()
        print("Iteration:", iter_num, "Conv. crit.:", crit)
        iter_num += 1
    end_time = time.time()
    elapsed = end_time - start_time
    print(f"Elapsed time for:  {elapsed} seconds")
    # Compute residuals and MSE.
    Res = y_out - np.exp(np.dot(X_data, b0_current))
    MSE = np.mean(Res ** 2)
    MSE_N_Gauss[index_N] = MSE
    # Alternative measure of accuracy
    mean_abs_ut_N_Gauss[index_N],  mean_square_ut_N_Gauss[index_N], std_ut_N_Gauss[index_N], dhm_stat_N_Gauss[index_N], c_equivalent_N_Gauss[index_N] = dhm_accuracy_test(params, b0_current)
     # Mean square integration error
    err = evaluate_Et_Gauss_path(slong, kss, e_test, b0_current, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, len(params.nodes_flat), params.nodes_flat, params.weights, nb_expl_vars)
    MSIE_N_Gauss[index_N] = np.mean(err[init:]**2)
    print("Final iteration N:", N, "Iterations:", iter_num, "OLS MSE:", MSE, "MISE:", MSIE_N_Gauss[index_N])
    print("Final b0:", b0_current)
    Time_N_Gauss[index_N] = elapsed
# Out:
# Iteration: 1 Conv. crit.: 0.1508862825314798
# Iteration: 2 Conv. crit.: 0.026836691801724655
# Iteration: 3 Conv. crit.: 0.010736541167866626
# Iteration: 4 Conv. crit.: 0.004781446635156811
# Iteration: 5 Conv. crit.: 0.0020176048519164602
# Iteration: 6 Conv. crit.: 0.000762345411918483
# Iteration: 7 Conv. crit.: 0.00032310613131797394
# Iteration: 8 Conv. crit.: 0.00021566809001061227
# Iteration: 9 Conv. crit.: 0.00014602918101080942
# Iteration: 10 Conv. crit.: 9.38732678414933e-05
# Iteration: 11 Conv. crit.: 5.8453809986591665e-05
# Iteration: 12 Conv. crit.: 3.743244709449034e-05
# Iteration: 13 Conv. crit.: 2.440954609239654e-05
# Iteration: 14 Conv. crit.: 1.5213975673125657e-05
# Iteration: 15 Conv. crit.: 9.198339633892383e-06
# Iteration: 16 Conv. crit.: 5.444808671359325e-06
# Iteration: 17 Conv. crit.: 3.1752567905135587e-06
# Iteration: 18 Conv. crit.: 1.832416877234344e-06
# Iteration: 19 Conv. crit.: 1.049855593487914e-06
# Iteration: 20 Conv. crit.: 5.986185312584213e-07
# Iteration: 21 Conv. crit.: 3.403196426055022e-07
# Iteration: 22 Conv. crit.: 1.9317637872662274e-07
# Iteration: 23 Conv. crit.: 1.0960377062885218e-07
# Iteration: 24 Conv. crit.: 6.221155457453165e-08
# Iteration: 25 Conv. crit.: 3.5349382282445774e-08
# Iteration: 26 Conv. crit.: 2.0118258989287874e-08
# Iteration: 27 Conv. crit.: 1.147323609729245e-08
# Iteration: 28 Conv. crit.: 6.558819209967481e-09
# Iteration: 29 Conv. crit.: 3.759611080789149e-09
# Iteration: 30 Conv. crit.: 2.161489459640009e-09
# Iteration: 31 Conv. crit.: 1.2466879056871605e-09
# Iteration: 32 Conv. crit.: 7.215156805351342e-10
# Iteration: 33 Conv. crit.: 4.1907874392954625e-10
# Iteration: 34 Conv. crit.: 2.4432832146370487e-10
# Iteration: 35 Conv. crit.: 1.4300043094106485e-10
# Iteration: 36 Conv. crit.: 8.47548697890943e-11
# Iteration: 37 Conv. crit.: 5.081390863637125e-11
# Iteration: 38 Conv. crit.: 3.058198139171964e-11
# Iteration: 39 Conv. crit.: 1.8475332375089693e-11
# Iteration: 40 Conv. crit.: 1.120215031846783e-11
# Iteration: 41 Conv. crit.: 6.816880393500924e-12
# Iteration: 42 Conv. crit.: 4.161337940900012e-12
# Iteration: 43 Conv. crit.: 2.5495161537492095e-12
# Iteration: 44 Conv. crit.: 1.5655254870239332e-12
# Iteration: 45 Conv. crit.: 9.64117674584486e-13
# Iteration: 46 Conv. crit.: 5.953015858040089e-13
# Iteration: 47 Conv. crit.: 3.6970426720017713e-13
# Iteration: 48 Conv. crit.: 2.282618538629322e-13
# Iteration: 49 Conv. crit.: 1.4277468096679513e-13
# Elapsed time for:  0.21230387687683105 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.2025726013834663e-10 MISE: 3.1033046301247207e-07
# Final b0: [ 0.30198932 -0.50340274 -0.64818346 -0.03691631 -0.09334529  0.12417055]
# Iteration: 1 Conv. crit.: 0.0007274556061743209
# Iteration: 2 Conv. crit.: 0.0003706050832548713
# Iteration: 3 Conv. crit.: 0.0002045957902720441
# Iteration: 4 Conv. crit.: 0.00011918886076323076
# Iteration: 5 Conv. crit.: 7.174579747909471e-05
# Iteration: 6 Conv. crit.: 4.401331213543802e-05
# Iteration: 7 Conv. crit.: 2.7293076136691852e-05
# Iteration: 8 Conv. crit.: 1.703035081807025e-05
# Iteration: 9 Conv. crit.: 1.0666692843885883e-05
# Iteration: 10 Conv. crit.: 6.697375592168431e-06
# Iteration: 11 Conv. crit.: 4.212577371043302e-06
# Iteration: 12 Conv. crit.: 2.6533600723244177e-06
# Iteration: 13 Conv. crit.: 1.673225457687888e-06
# Iteration: 14 Conv. crit.: 1.0562343985554001e-06
# Iteration: 15 Conv. crit.: 6.673695054915108e-07
# Iteration: 16 Conv. crit.: 4.2201905126049155e-07
# Iteration: 17 Conv. crit.: 2.670669687065974e-07
# Iteration: 18 Conv. crit.: 1.6912026368220978e-07
# Iteration: 19 Conv. crit.: 1.0715819559470319e-07
# Iteration: 20 Conv. crit.: 6.793264467619409e-08
# Iteration: 21 Conv. crit.: 4.30850449761877e-08
# Iteration: 22 Conv. crit.: 2.733654097530902e-08
# Iteration: 23 Conv. crit.: 1.73502724964969e-08
# Iteration: 24 Conv. crit.: 1.1015243939205277e-08
# Iteration: 25 Conv. crit.: 6.995018231314987e-09
# Iteration: 26 Conv. crit.: 4.4429819823221806e-09
# Iteration: 27 Conv. crit.: 2.822523437195912e-09
# Iteration: 28 Conv. crit.: 1.7933542983961104e-09
# Iteration: 29 Conv. crit.: 1.1447369718808886e-09
# Iteration: 30 Conv. crit.: 7.315601457946741e-10
# Iteration: 31 Conv. crit.: 4.671291131685962e-10
# Iteration: 32 Conv. crit.: 2.9807345480747927e-10
# Iteration: 33 Conv. crit.: 1.9009083196408483e-10
# Iteration: 34 Conv. crit.: 1.211685196622625e-10
# Iteration: 35 Conv. crit.: 7.720613037776047e-11
# Iteration: 36 Conv. crit.: 4.9176329675049146e-11
# Iteration: 37 Conv. crit.: 3.1314506543367315e-11
# Iteration: 38 Conv. crit.: 1.9935275652471773e-11
# Iteration: 39 Conv. crit.: 1.2688738948440914e-11
# Iteration: 40 Conv. crit.: 8.074652058098764e-12
# Iteration: 41 Conv. crit.: 5.1383342025701495e-12
# Iteration: 42 Conv. crit.: 3.269162718311236e-12
# Iteration: 43 Conv. crit.: 2.080668970450006e-12
# Iteration: 44 Conv. crit.: 1.322830733840874e-12
# Iteration: 45 Conv. crit.: 8.424372310855688e-13
# Iteration: 46 Conv. crit.: 5.35460564776713e-13
# Iteration: 47 Conv. crit.: 3.405054016525355e-13
# Iteration: 48 Conv. crit.: 2.1616042289451798e-13
# Iteration: 49 Conv. crit.: 1.376676550535194e-13
# Elapsed time for:  0.27149391174316406 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.1918891266090125e-10 MISE: 4.1173936648277463e-10
# Final b0: [ 0.30360003 -0.50350418 -0.64800538 -0.03709926 -0.0935347   0.12449571]
# Iteration: 1 Conv. crit.: 1.2045937109461669e-06
# Iteration: 2 Conv. crit.: 6.696625196034312e-07
# Iteration: 3 Conv. crit.: 3.921006887508405e-07
# Iteration: 4 Conv. crit.: 2.368908087468924e-07
# Iteration: 5 Conv. crit.: 1.4571886047809457e-07
# Iteration: 6 Conv. crit.: 9.055257338408396e-08
# Iteration: 7 Conv. crit.: 5.6600278242058266e-08
# Iteration: 8 Conv. crit.: 3.550234817240039e-08
# Iteration: 9 Conv. crit.: 2.2319353809585607e-08
# Iteration: 10 Conv. crit.: 1.4054311270328412e-08
# Iteration: 11 Conv. crit.: 8.861103240054291e-09
# Iteration: 12 Conv. crit.: 5.5927754649687245e-09
# Iteration: 13 Conv. crit.: 3.5332182179992344e-09
# Iteration: 14 Conv. crit.: 2.2339500249657362e-09
# Iteration: 15 Conv. crit.: 1.413510197778578e-09
# Iteration: 16 Conv. crit.: 8.94981810883877e-10
# Iteration: 17 Conv. crit.: 5.670039437966068e-10
# Iteration: 18 Conv. crit.: 3.5940633802411526e-10
# Iteration: 19 Conv. crit.: 2.279214594835821e-10
# Iteration: 20 Conv. crit.: 1.44595835305239e-10
# Iteration: 21 Conv. crit.: 9.176620574535832e-11
# Iteration: 22 Conv. crit.: 5.825534499237506e-11
# Iteration: 23 Conv. crit.: 3.69911878905782e-11
# Iteration: 24 Conv. crit.: 2.34944286248151e-11
# Iteration: 25 Conv. crit.: 1.4924672608884748e-11
# Iteration: 26 Conv. crit.: 9.482303831021e-12
# Iteration: 27 Conv. crit.: 6.0389471201460765e-12
# Iteration: 28 Conv. crit.: 3.860134434319207e-12
# Iteration: 29 Conv. crit.: 2.4653612484826226e-12
# Iteration: 30 Conv. crit.: 1.5741852266160095e-12
# Iteration: 31 Conv. crit.: 1.0031975250512914e-12
# Iteration: 32 Conv. crit.: 6.398215290914777e-13
# Iteration: 33 Conv. crit.: 4.0811798385220754e-13
# Iteration: 34 Conv. crit.: 2.5979218776228663e-13
# Iteration: 35 Conv. crit.: 1.6620038678638593e-13
# Iteration: 36 Conv. crit.: 1.0502709812953981e-13
# Iteration: 37 Conv. crit.: 6.639133687258436e-14
# Iteration: 38 Conv. crit.: 4.2743586448068527e-14
# Iteration: 39 Conv. crit.: 2.853273173286652e-14
# Iteration: 40 Conv. crit.: 1.6930901125533637e-14
# Iteration: 41 Conv. crit.: 1.0436096431476471e-14
# Iteration: 42 Conv. crit.: 7.216449660063518e-15
# Iteration: 43 Conv. crit.: 4.9960036108132044e-15
# Iteration: 44 Conv. crit.: 2.7755575615628914e-15
# Iteration: 45 Conv. crit.: 2.7755575615628914e-15
# Iteration: 46 Conv. crit.: 9.71445146547012e-16
# Iteration: 47 Conv. crit.: 8.881784197001252e-16
# Iteration: 48 Conv. crit.: 7.771561172376096e-16
# Iteration: 49 Conv. crit.: 8.049116928532385e-16
# Elapsed time for:  0.275587797164917 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.191900879865872e-10 MISE: 4.0963808211856715e-10
# Final b0: [ 0.30359714 -0.50350464 -0.64800524 -0.037099   -0.09353445  0.12449523]
# Iteration: 1 Conv. crit.: 1.0569119468506472e-09
# Iteration: 2 Conv. crit.: 6.325128198980678e-10
# Iteration: 3 Conv. crit.: 3.867352549313807e-10
# Iteration: 4 Conv. crit.: 2.3942020588307855e-10
# Iteration: 5 Conv. crit.: 1.4928791536306107e-10
# Iteration: 6 Conv. crit.: 9.348316565294112e-11
# Iteration: 7 Conv. crit.: 5.869665864466356e-11
# Iteration: 8 Conv. crit.: 3.692141037348051e-11
# Iteration: 9 Conv. crit.: 2.3257673564813786e-11
# Iteration: 10 Conv. crit.: 1.46665457556594e-11
# Iteration: 11 Conv. crit.: 9.259149003071343e-12
# Iteration: 12 Conv. crit.: 5.849543072145025e-12
# Iteration: 13 Conv. crit.: 3.69876351768994e-12
# Iteration: 14 Conv. crit.: 2.34123831432953e-12
# Iteration: 15 Conv. crit.: 1.482147737874584e-12
# Iteration: 16 Conv. crit.: 9.389156119254949e-13
# Iteration: 17 Conv. crit.: 5.950240300478526e-13
# Iteration: 18 Conv. crit.: 3.7769787297747826e-13
# Iteration: 19 Conv. crit.: 2.3975266216780255e-13
# Iteration: 20 Conv. crit.: 1.5198953207118393e-13
# Iteration: 21 Conv. crit.: 9.670042544485113e-14
# Iteration: 22 Conv. crit.: 6.106226635438361e-14
# Iteration: 23 Conv. crit.: 3.902433931557425e-14
# Iteration: 24 Conv. crit.: 2.503552920529728e-14
# Iteration: 25 Conv. crit.: 1.5765166949677223e-14
# Iteration: 26 Conv. crit.: 1.0325074129013956e-14
# Iteration: 27 Conv. crit.: 6.661338147750939e-15
# Iteration: 28 Conv. crit.: 3.885780586188048e-15
# Iteration: 29 Conv. crit.: 3.219646771412954e-15
# Iteration: 30 Conv. crit.: 1.6653345369377348e-15
# Iteration: 31 Conv. crit.: 1.4016565685892601e-15
# Iteration: 32 Conv. crit.: 7.355227538141662e-16
# Iteration: 33 Conv. crit.: 7.771561172376096e-16
# Iteration: 34 Conv. crit.: 5.551115123125783e-16
# Iteration: 35 Conv. crit.: 4.440892098500626e-16
# Iteration: 36 Conv. crit.: 8.881784197001252e-16
# Iteration: 37 Conv. crit.: 9.992007221626409e-16
# Iteration: 38 Conv. crit.: 5.551115123125783e-16
# Iteration: 39 Conv. crit.: 2.3592239273284576e-16
# Iteration: 40 Conv. crit.: 4.440892098500626e-16
# Iteration: 41 Conv. crit.: 6.661338147750939e-16
# Iteration: 42 Conv. crit.: 4.996003610813204e-16
# Iteration: 43 Conv. crit.: 3.3306690738754696e-16
# Iteration: 44 Conv. crit.: 2.498001805406602e-16
# Iteration: 45 Conv. crit.: 7.91033905045424e-16
# Iteration: 46 Conv. crit.: 6.661338147750939e-16
# Iteration: 47 Conv. crit.: 6.661338147750939e-16
# Iteration: 48 Conv. crit.: 5.551115123125783e-16
# Iteration: 49 Conv. crit.: 7.632783294297951e-16
# Elapsed time for:  0.3442087173461914 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.191900832261743e-10 MISE: 4.0963892687041094e-10
# Final b0: [ 0.30359714 -0.50350464 -0.64800524 -0.037099   -0.09353445  0.12449523]
# Iteration: 1 Conv. crit.: 7.354117315117037e-13
# Iteration: 2 Conv. crit.: 4.4481085481606897e-13
# Iteration: 3 Conv. crit.: 2.893241202173158e-13
# Iteration: 4 Conv. crit.: 1.8451906669270102e-13
# Iteration: 5 Conv. crit.: 1.1679546219056647e-13
# Iteration: 6 Conv. crit.: 7.432943149865423e-14
# Iteration: 7 Conv. crit.: 4.701794509287538e-14
# Iteration: 8 Conv. crit.: 3.0031532816110484e-14
# Iteration: 9 Conv. crit.: 1.887379141862766e-14
# Iteration: 10 Conv. crit.: 1.1823875212257917e-14
# Iteration: 11 Conv. crit.: 7.716050021144838e-15
# Iteration: 12 Conv. crit.: 3.941291737419306e-15
# Iteration: 13 Conv. crit.: 2.9976021664879227e-15
# Iteration: 14 Conv. crit.: 1.7763568394002505e-15
# Iteration: 15 Conv. crit.: 2.1094237467877974e-15
# Iteration: 16 Conv. crit.: 9.43689570931383e-16
# Iteration: 17 Conv. crit.: 8.881784197001252e-16
# Iteration: 18 Conv. crit.: 1.6653345369377348e-16
# Iteration: 19 Conv. crit.: 8.881784197001252e-16
# Iteration: 20 Conv. crit.: 5.273559366969494e-16
# Iteration: 21 Conv. crit.: 4.440892098500626e-16
# Iteration: 22 Conv. crit.: 6.661338147750939e-16
# Iteration: 23 Conv. crit.: 3.885780586188048e-16
# Iteration: 24 Conv. crit.: 4.440892098500626e-16
# Iteration: 25 Conv. crit.: 6.106226635438361e-16
# Iteration: 26 Conv. crit.: 8.881784197001252e-16
# Iteration: 27 Conv. crit.: 8.326672684688674e-16
# Iteration: 28 Conv. crit.: 5.551115123125783e-16
# Iteration: 29 Conv. crit.: 5.551115123125783e-16
# Iteration: 30 Conv. crit.: 6.661338147750939e-16
# Iteration: 31 Conv. crit.: 5.551115123125783e-16
# Iteration: 32 Conv. crit.: 2.498001805406602e-16
# Iteration: 33 Conv. crit.: 6.106226635438361e-16
# Iteration: 34 Conv. crit.: 6.661338147750939e-16
# Iteration: 35 Conv. crit.: 6.661338147750939e-16
# Iteration: 36 Conv. crit.: 9.992007221626409e-16
# Iteration: 37 Conv. crit.: 6.106226635438361e-16
# Iteration: 38 Conv. crit.: 6.661338147750939e-16
# Iteration: 39 Conv. crit.: 4.440892098500626e-16
# Iteration: 40 Conv. crit.: 6.106226635438361e-16
# Iteration: 41 Conv. crit.: 6.661338147750939e-16
# Iteration: 42 Conv. crit.: 2.220446049250313e-16
# Iteration: 43 Conv. crit.: 7.216449660063518e-16
# Iteration: 44 Conv. crit.: 5.551115123125783e-16
# Iteration: 45 Conv. crit.: 4.85722573273506e-16
# Iteration: 46 Conv. crit.: 9.159339953157541e-16
# Iteration: 47 Conv. crit.: 1.6653345369377348e-16
# Iteration: 48 Conv. crit.: 5.551115123125783e-16
# Iteration: 49 Conv. crit.: 4.440892098500626e-16
# Elapsed time for:  0.3816530704498291 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.1919008323457726e-10 MISE: 4.0963892616228007e-10
# Final b0: [ 0.30359714 -0.50350464 -0.64800524 -0.037099   -0.09353445  0.12449523]
# Iteration: 1 Conv. crit.: 1.1102230246251565e-15
# Iteration: 2 Conv. crit.: 5.551115123125783e-16
# Iteration: 3 Conv. crit.: 6.661338147750939e-16
# Iteration: 4 Conv. crit.: 4.996003610813204e-16
# Iteration: 5 Conv. crit.: 2.220446049250313e-16
# Iteration: 6 Conv. crit.: 7.494005416219807e-16
# Iteration: 7 Conv. crit.: 9.992007221626409e-16
# Iteration: 8 Conv. crit.: 6.661338147750939e-16
# Iteration: 9 Conv. crit.: 8.049116928532385e-16
# Iteration: 10 Conv. crit.: 6.661338147750939e-16
# Iteration: 11 Conv. crit.: 4.3021142204224816e-16
# Iteration: 12 Conv. crit.: 2.7755575615628914e-16
# Iteration: 13 Conv. crit.: 3.3306690738754696e-16
# Iteration: 14 Conv. crit.: 3.3306690738754696e-16
# Iteration: 15 Conv. crit.: 1.1102230246251565e-15
# Iteration: 16 Conv. crit.: 1.1379786002407855e-15
# Iteration: 17 Conv. crit.: 7.771561172376096e-16
# Iteration: 18 Conv. crit.: 5.551115123125783e-16
# Iteration: 19 Conv. crit.: 8.604228440844963e-16
# Iteration: 20 Conv. crit.: 6.38378239159465e-16
# Iteration: 21 Conv. crit.: 4.996003610813204e-16
# Iteration: 22 Conv. crit.: 2.636779683484747e-16
# Iteration: 23 Conv. crit.: 6.661338147750939e-16
# Iteration: 24 Conv. crit.: 6.661338147750939e-16
# Iteration: 25 Conv. crit.: 7.771561172376096e-16
# Iteration: 26 Conv. crit.: 4.440892098500626e-16
# Iteration: 27 Conv. crit.: 3.885780586188048e-16
# Iteration: 28 Conv. crit.: 8.881784197001252e-16
# Iteration: 29 Conv. crit.: 3.7470027081099033e-16
# Iteration: 30 Conv. crit.: 6.661338147750939e-16
# Iteration: 31 Conv. crit.: 4.440892098500626e-16
# Iteration: 32 Conv. crit.: 3.885780586188048e-16
# Iteration: 33 Conv. crit.: 4.85722573273506e-16
# Iteration: 34 Conv. crit.: 4.440892098500626e-16
# Iteration: 35 Conv. crit.: 6.661338147750939e-16
# Iteration: 36 Conv. crit.: 8.187894806610529e-16
# Iteration: 37 Conv. crit.: 7.771561172376096e-16
# Iteration: 38 Conv. crit.: 7.771561172376096e-16
# Iteration: 39 Conv. crit.: 3.885780586188048e-16
# Iteration: 40 Conv. crit.: 4.440892098500626e-16
# Iteration: 41 Conv. crit.: 7.771561172376096e-16
# Iteration: 42 Conv. crit.: 4.718447854656915e-16
# Iteration: 43 Conv. crit.: 6.661338147750939e-16
# Iteration: 44 Conv. crit.: 6.661338147750939e-16
# Iteration: 45 Conv. crit.: 7.216449660063518e-16
# Iteration: 46 Conv. crit.: 5.551115123125783e-16
# Iteration: 47 Conv. crit.: 5.273559366969494e-16
# Iteration: 48 Conv. crit.: 4.440892098500626e-16
# Iteration: 49 Conv. crit.: 6.661338147750939e-16
# Elapsed time for:  0.4029982089996338 seconds
# Final iteration N: 1000 Iterations: 50 OLS MSE: 4.191900832346498e-10 MISE: 4.0963892616217223e-10
# Final b0: [ 0.30359714 -0.50350464 -0.64800524 -0.037099   -0.09353445  0.12449523]

# %%
create_plots(list_N_Gauss, MSE_N_Gauss, Time_N_Gauss, mean_square_ut_N_Gauss, dhm_stat_N_Gauss, np.abs(c_equivalent_N_Gauss), label="N", ref_index_plot=1)
# Out:
# /tmp/ipykernel_20519/3339673783.py:125: RuntimeWarning: divide by zero encountered in divide
#   axs[0].plot(list_N, MSE_N[ref_index_plot] * (list_N[ref_index_plot] / list_N),
# /tmp/ipykernel_20519/3339673783.py:127: RuntimeWarning: divide by zero encountered in divide
#   axs[0].plot(list_N, MSE_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
# /tmp/ipykernel_20519/3339673783.py:156: RuntimeWarning: divide by zero encountered in divide
#   ax1.plot(list_N, mean_square_ut_N[ref_index_plot] * np.power(list_N[ref_index_plot] / list_N, 0.5),
# /tmp/ipykernel_20519/3339673783.py:166: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot(list_N, dhm_stat_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
# /tmp/ipykernel_20519/3339673783.py:176: RuntimeWarning: divide by zero encountered in divide
#   ax3.plot(list_N, c_equivalent_N[ref_index_plot] * np.sqrt(list_N[ref_index_plot] / list_N),
# /tmp/ipykernel_20519/3339673783.py:186: RuntimeWarning: divide by zero encountered in divide
#   ax4.plot(list_N, MSE_N[ref_index_plot] * (list_N[ref_index_plot] / list_N),

# %%
index_ref=1
plt.plot(list_N_Gauss, np.sqrt(MSIE_N_Gauss), label="Square root MSIE")
plt.xlabel("sqrt(MSIE)")
plt.xlabel("N")
plt.legend()

# %% [markdown]
# ### Evaluate running time
#
# #### Evaluate simulation time

# %%
# -------------------------------
# Assume simulate_path_N is defined and compiled via @njit

# Define grid of slong (M, number of state draws) and N (number of innovation draws)
slong_list = [10, 50, 100, 1000, 5000, 10000, 20000]
N_list = [1, 5, 10, 25, 50, 100, 200, 300, 400, 1000]

# Data list to collect results
results = []

# Loop over combinations of slong and N
for slong in slong_list:
    for N in N_list:
        # Generate random shocks for the simulation
        # e: state shock vector of length slong
        # E: extra innovations of shape (slong, N)
        e = params.std_tfp * np.random.randn(slong)
        E = params.std_tfp * np.random.randn(slong, N)
        
        # Warmup call (compilation cost; ignore elapsed time on this call)
        X, y = simulate_path_N(slong, kss, e, E, b0, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N)
        
        # Measure elapsed time for one call
        start = time.time()
        X, y = simulate_path_N(slong, kss, e, E, b0, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N)
        end = time.time()
        elapsed = end - start

        
        # Store the result
        results.append({
            "slong": slong,
            "N": N,
            "elapsed_time": elapsed
        })
        print(f"slong={slong}, N={N} -> elapsed_time: {elapsed:.6f} seconds")

# Convert results to a pandas DataFrame
df = pd.DataFrame(results)
print("\nTiming results:")
print(df)
# Out:
# slong=10, N=1 -> elapsed_time: 0.000006 seconds
# slong=10, N=5 -> elapsed_time: 0.000007 seconds
# slong=10, N=10 -> elapsed_time: 0.000008 seconds
# slong=10, N=25 -> elapsed_time: 0.000014 seconds
# slong=10, N=50 -> elapsed_time: 0.000024 seconds
# slong=10, N=100 -> elapsed_time: 0.000044 seconds
# slong=10, N=200 -> elapsed_time: 0.000146 seconds
# slong=10, N=300 -> elapsed_time: 0.000120 seconds
# slong=10, N=400 -> elapsed_time: 0.000159 seconds
# slong=10, N=1000 -> elapsed_time: 0.000413 seconds
# slong=50, N=1 -> elapsed_time: 0.000009 seconds
# slong=50, N=5 -> elapsed_time: 0.000017 seconds
# slong=50, N=10 -> elapsed_time: 0.000026 seconds
# slong=50, N=25 -> elapsed_time: 0.000056 seconds
# slong=50, N=50 -> elapsed_time: 0.000105 seconds
# slong=50, N=100 -> elapsed_time: 0.000204 seconds
# slong=50, N=200 -> elapsed_time: 0.000577 seconds
# slong=50, N=300 -> elapsed_time: 0.000632 seconds
# slong=50, N=400 -> elapsed_time: 0.000886 seconds
# slong=50, N=1000 -> elapsed_time: 0.002097 seconds
# slong=100, N=1 -> elapsed_time: 0.000016 seconds
# slong=100, N=5 -> elapsed_time: 0.000031 seconds
# slong=100, N=10 -> elapsed_time: 0.000051 seconds
# slong=100, N=25 -> elapsed_time: 0.000111 seconds
# slong=100, N=50 -> elapsed_time: 0.000213 seconds
# slong=100, N=100 -> elapsed_time: 0.000483 seconds
# slong=100, N=200 -> elapsed_time: 0.000844 seconds
# slong=100, N=300 -> elapsed_time: 0.001316 seconds
# slong=100, N=400 -> elapsed_time: 0.001711 seconds
# slong=100, N=1000 -> elapsed_time: 0.004237 seconds
# slong=1000, N=1 -> elapsed_time: 0.000119 seconds
# slong=1000, N=5 -> elapsed_time: 0.000304 seconds
# slong=1000, N=10 -> elapsed_time: 0.000502 seconds
# slong=1000, N=25 -> elapsed_time: 0.001130 seconds
# slong=1000, N=50 -> elapsed_time: 0.002218 seconds
# slong=1000, N=100 -> elapsed_time: 0.004265 seconds
# slong=1000, N=200 -> elapsed_time: 0.008782 seconds
# slong=1000, N=300 -> elapsed_time: 0.013334 seconds
# slong=1000, N=400 -> elapsed_time: 0.016923 seconds
# slong=1000, N=1000 -> elapsed_time: 0.042399 seconds
# slong=5000, N=1 -> elapsed_time: 0.000593 seconds
# slong=5000, N=5 -> elapsed_time: 0.001500 seconds
# slong=5000, N=10 -> elapsed_time: 0.002428 seconds
# slong=5000, N=25 -> elapsed_time: 0.005553 seconds
# slong=5000, N=50 -> elapsed_time: 0.012914 seconds
# slong=5000, N=100 -> elapsed_time: 0.022549 seconds
# slong=5000, N=200 -> elapsed_time: 0.042305 seconds
# slong=5000, N=300 -> elapsed_time: 0.062783 seconds
# slong=5000, N=400 -> elapsed_time: 0.085591 seconds
# slong=5000, N=1000 -> elapsed_time: 0.198921 seconds
# slong=10000, N=1 -> elapsed_time: 0.001103 seconds
# slong=10000, N=5 -> elapsed_time: 0.002563 seconds
# slong=10000, N=10 -> elapsed_time: 0.004503 seconds
# slong=10000, N=25 -> elapsed_time: 0.010611 seconds
# slong=10000, N=50 -> elapsed_time: 0.020301 seconds
# slong=10000, N=100 -> elapsed_time: 0.045148 seconds
# slong=10000, N=200 -> elapsed_time: 0.078441 seconds
# slong=10000, N=300 -> elapsed_time: 0.120810 seconds
# slong=10000, N=400 -> elapsed_time: 0.158320 seconds
# slong=10000, N=1000 -> elapsed_time: 0.425637 seconds
# slong=20000, N=1 -> elapsed_time: 0.002498 seconds
# slong=20000, N=5 -> elapsed_time: 0.005309 seconds
# slong=20000, N=10 -> elapsed_time: 0.011225 seconds
# slong=20000, N=25 -> elapsed_time: 0.020905 seconds
# slong=20000, N=50 -> elapsed_time: 0.040707 seconds
# slong=20000, N=100 -> elapsed_time: 0.095007 seconds
# slong=20000, N=200 -> elapsed_time: 0.161319 seconds
# slong=20000, N=300 -> elapsed_time: 0.264943 seconds
# slong=20000, N=400 -> elapsed_time: 0.333138 seconds
# slong=20000, N=1000 -> elapsed_time: 0.850227 seconds
#
# Timing results:
#     slong     N  elapsed_time
# 0      10     1      0.000006
# 1      10     5      0.000007
# 2      10    10      0.000008
# 3      10    25      0.000014
# 4      10    50      0.000024
# ..    ...   ...           ...
# 65  20000   100      0.095007
# 66  20000   200      0.161319
# 67  20000   300      0.264943
# 68  20000   400      0.333138
# 69  20000  1000      0.850227
#
# [70 rows x 3 columns]

# %%
# Create an interaction term (slong * N)
df["slong_N"] = df["slong"] * df["N"]

# Fit the regression model:
# elapsed_time = constant + a*slong + b*N + c*(slong*N)
X_reg = sm.add_constant(df[["slong", "N"]])
y = df["elapsed_time"]
y_log = np.log(y)
model = sm.OLS(df["elapsed_time"], X_reg).fit()

print("\nRegression summary:")
print(model.summary())

# Fit the regression model:
# elapsed_time = constant + a*slong + b*N + c*(slong*N)
X_reg = sm.add_constant(df[["slong", "N", "slong_N"]])
model = sm.OLS(df["elapsed_time"], X_reg).fit()

print("\nRegression summary:")
print(model.summary())

# Fit the regression model:
# elapsed_time = constant + a*slong + b*N + c*(slong*N)
X_reg = sm.add_constant(df[["slong", "slong_N"]])
model = sm.OLS(df["elapsed_time"], X_reg).fit()

print("\nRegression summary:")
print(model.summary())

# Fit the regression model:
# elapsed_time = alpha_0 + alpha_1 * MN
X_reg = sm.add_constant(df[["slong_N"]])
model = sm.OLS(y, X_reg).fit()

print("\nRegression summary:")
print(model.summary())


plt.scatter(df["slong_N"], df["elapsed_time"], label="values")
plt.plot(df["slong_N"], model.predict(), label="predicted values")
plt.ylabel("Simulation time (seconds)")
plt.xlabel("MN")
plt.legend()
# Out:
# Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           elapsed_time   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     35.10
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):           3.74e-11
# Time:                        11:26:56   Log-Likelihood:                 71.728
# No. Observations:                  70   AIC:                            -137.5
# Df Residuals:                      67   BIC:                            -130.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0457      0.015     -3.002      0.004      -0.076      -0.015
# slong        8.89e-06   1.52e-06      5.833      0.000    5.85e-06    1.19e-05
# N              0.0002   3.61e-05      6.015      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       62.815   Durbin-Watson:                   0.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              642.660
# Skew:                           2.330   Prob(JB):                    2.81e-140
# Kurtosis:                      17.093   Cond. No.                     1.24e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           elapsed_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.361e+04
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):          5.39e-105
# Time:                        11:26:56   Log-Likelihood:                 303.27
# No. Observations:                  70   AIC:                            -598.5
# Df Residuals:                      66   BIC:                            -589.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.169      0.866      -0.001       0.001
# slong       3.135e-08   6.89e-08      0.455      0.651   -1.06e-07    1.69e-07
# N          -1.996e-06   1.66e-06     -1.206      0.232    -5.3e-06    1.31e-06
# slong_N     4.236e-08   1.91e-10    221.840      0.000     4.2e-08    4.27e-08
# ==============================================================================
# Omnibus:                       22.536   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.214
# Skew:                          -0.712   Prob(JB):                     5.74e-21
# Kurtosis:                       8.471   Cond. No.                     4.78e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           elapsed_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 5.008e+04
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):          4.37e-107
# Time:                        11:26:56   Log-Likelihood:                 302.51
# No. Observations:                  70   AIC:                            -599.0
# Df Residuals:                      67   BIC:                            -592.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -0.647      0.520      -0.001       0.001
# slong       6.005e-08   6.49e-08      0.925      0.358   -6.95e-08     1.9e-07
# slong_N     4.223e-08   1.54e-10    274.423      0.000    4.19e-08    4.25e-08
# ==============================================================================
# Omnibus:                       26.628   Durbin-Watson:                   2.619
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.448
# Skew:                          -0.890   Prob(JB):                     3.14e-26
# Kurtosis:                       9.091   Cond. No.                     3.90e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.9e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           elapsed_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.004e+05
# Date:                Mon, 14 Apr 2025   Prob (F-statistic):          1.68e-109
# Time:                        11:26:56   Log-Likelihood:                 302.07
# No. Observations:                  70   AIC:                            -600.1
# Df Residuals:                      68   BIC:                            -595.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -8.22e-05      0.000     -0.197      0.845      -0.001       0.001
# slong_N      4.23e-08   1.34e-10    316.819      0.000     4.2e-08    4.26e-08
# ==============================================================================
# Omnibus:                       23.902   Durbin-Watson:                   2.579
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              132.387
# Skew:                          -0.634   Prob(JB):                     1.79e-29
# Kurtosis:                       9.617   Cond. No.                     3.33e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Evaluate simulation time + OLS time

# %%
def run_OLS(X_data, y_out):
    bt, _, _, _ = np.linalg.lstsq(X_data, np.log(y_out), rcond=None)
    return bt

# %%
# -------------------------------
# Assume simulate_path_N is defined and compiled via @njit

# Define grid of slong (M, number of state draws) and N (number of innovation draws)
slong_list = [10, 50, 100, 1000, 5000, 10000, 20000, int(1e6), int(1e7)]
N_list = [1]

# Data list to collect results
results = []

# Loop over combinations of slong and N
for slong in slong_list:
    for N in N_list:
        # Generate random shocks for the simulation
        # e: state shock vector of length slong
        # E: extra innovations of shape (slong, N)
        e = params.std_tfp * np.random.randn(slong)
        E = params.std_tfp * np.random.randn(slong, N)
        
        # Warmup call (compilation cost; ignore elapsed time on this call)
        X, y = simulate_path_N(slong, kss, e, E, b0, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N)
        
        # Measure elapsed time for one call
        start = time.time()
        X, y = simulate_path_N(slong, kss, e, E, b0, params.beta, params.gamma, params.alpha, params.delta, params.rho_tfp, N)
        end = time.time()
        elapsed = end - start

        # Measure OLS time
        # Warmup call (compilation cost; ignore elapsed time on this call)
        bt, _, _, _ = np.linalg.lstsq(X, np.log(y), rcond=None)
        
        start = time.time()
        bt, _, _, _ = np.linalg.lstsq(X, np.log(y), rcond=None)
        end = time.time()
        elapsed_simulation = end - start
        
        # Store the result
        results.append({
            "slong": slong,
            "N": N,
            "elapsed_time": elapsed,
            "elapsed_simulation_time": elapsed_simulation,
        })
        print(f"slong={slong}, N={N} -> elapsed_time: {elapsed:.6f} seconds. Simulation time {elapsed_simulation:.6f}")

# Convert results to a pandas DataFrame
df = pd.DataFrame(results)
print("\nTiming results:")
print(df)
# Out:
# slong=10, N=1 -> elapsed_time: 0.000009 seconds. Simulation time 0.000064
# slong=50, N=1 -> elapsed_time: 0.000016 seconds. Simulation time 0.000068
# slong=100, N=1 -> elapsed_time: 0.000024 seconds. Simulation time 0.000065
# slong=1000, N=1 -> elapsed_time: 0.000164 seconds. Simulation time 0.000120
# slong=5000, N=1 -> elapsed_time: 0.000658 seconds. Simulation time 0.000273
# slong=10000, N=1 -> elapsed_time: 0.001185 seconds. Simulation time 0.000527
# slong=20000, N=1 -> elapsed_time: 0.002295 seconds. Simulation time 0.001099
# slong=1000000, N=1 -> elapsed_time: 0.131956 seconds. Simulation time 0.123223
# slong=10000000, N=1 -> elapsed_time: 1.411482 seconds. Simulation time 1.205371
#
# Timing results:
#       slong  N  elapsed_time  elapsed_simulation_time
# 0        10  1      0.000009                 0.000064
# 1        50  1      0.000016                 0.000068
# 2       100  1      0.000024                 0.000065
# 3      1000  1      0.000164                 0.000120
# 4      5000  1      0.000658                 0.000273
# 5     10000  1      0.001185                 0.000527
# 6     20000  1      0.002295                 0.001099
# 7   1000000  1      0.131956                 0.123223
# 8  10000000  1      1.411482                 1.205371

# %%
# Create an interaction term (slong * N)
df["slong_N"] = df["slong"] * df["N"]

plt.scatter(df["slong_N"], df["elapsed_time"], label="simulation")
plt.ylabel("Simulation time (seconds)")
plt.xlabel("MN")
plt.legend()
plt.show()

plt.scatter(df["slong"], df["elapsed_simulation_time"], label="OLS")
plt.show()

# %% [markdown]
# ---
#
# ## Hardware details

# %%
# !python3 --version
# Out:
# Python 3.8.10

# %%
cpuinfo.get_cpu_info()
# Out:
# {'python_version': '3.8.10.final.0 (64 bit)',
#  'cpuinfo_version': [9, 0, 0],
#  'cpuinfo_version_string': '9.0.0',
#  'arch': 'X86_64',
#  'bits': 64,
#  'count': 12,
#  'arch_string_raw': 'x86_64',
#  'vendor_id_raw': 'GenuineIntel',
#  'brand_raw': 'Intel(R) Core(TM) i7-8850H CPU @ 2.60GHz',
#  'hz_advertised_friendly': '2.6000 GHz',
#  'hz_actual_friendly': '4.0058 GHz',
#  'hz_advertised': [2600000000, 0],
#  'hz_actual': [4005795000, 0],
#  'stepping': 10,
#  'model': 158,
#  'family': 6,
#  'flags': ['3dnowprefetch',
#   'abm',
#   'acpi',
#   'adx',
#   'aes',
#   'aperfmperf',
#   'apic',
#   'arat',
#   'arch_capabilities',
#   'arch_perfmon',
#   'art',
#   'avx',
#   'avx2',
#   'bmi1',
#   'bmi2',
#   'bts',
#   'clflush',
#   'clflushopt',
#   'cmov',
#   'constant_tsc',
#   'cpuid',
#   'cpuid_fault',
#   'cx16',
#   'cx8',
#   'de',
#   'ds_cpl',
#   'dtes64',
#   'dtherm',
#   'dts',
#   'epb',
#   'ept',
#   'ept_ad',
#   'erms',
#   'est',
#   'f16c',
#   'flexpriority',
#   'flush_l1d',
#   'fma',
#   'fpu',
#   'fsgsbase',
#   'fxsr',
#   'hle',
#   'ht',
#   'hwp',
#   'hwp_act_window',
#   'hwp_epp',
#   'hwp_notify',
#   'ibpb',
#   'ibrs',
#   'ida',
#   'intel_pt',
#   'invpcid',
#   'invpcid_single',
#   'lahf_lm',
#   'lm',
#   'mca',
#   'mce',
#   'md_clear',
#   'mmx',
#   'monitor',
#   'movbe',
#   'mpx',
#   'msr',
#   'mtrr',
#   'nonstop_tsc',
#   'nopl',
#   'nx',
#   'osxsave',
#   'pae',
#   'pat',
#   'pbe',
#   'pcid',
#   'pclmulqdq',
#   'pdcm',
#   'pdpe1gb',
#   'pebs',
#   'pge',
#   'pln',
#   'pni',
#   'popcnt',
#   'pse',
#   'pse36',
#   'pti',
#   'pts',
#   'rdrand',
#   'rdrnd',
#   'rdseed',
#   'rdtscp',
#   'rep_good',
#   'rtm',
#   'sdbg',
#   'sep',
#   'sgx',
#   'sgx_lc',
#   'smap',
#   'smep',
#   'smx',
#   'ss',
#   'ssbd',
#   'sse',
#   'sse2',
#   'sse4_1',
#   'sse4_2',
#   'ssse3',
#   'stibp',
#   'syscall',
#   'tm',
#   'tm2',
#   'tpr_shadow',
#   'tsc',
#   'tsc_adjust',
#   'tsc_deadline_timer',
#   'tscdeadline',
#   'vme',
#   'vmx',
#   'vnmi',
#   'vpid',
#   'x2apic',
#   'xgetbv1',
#   'xsave',
#   'xsavec',
#   'xsaveopt',
#   'xsaves',
#   'xtopology',
#   'xtpr'],
#  'l3_cache_size': 9437184,
#  'l2_cache_size': '1,5 MiB',
#  'l1_data_cache_size': 196608,
#  'l1_instruction_cache_size': 196608,
#  'l2_cache_line_size': 256,
#  'l2_cache_associativity': 6}

# %% [markdown]
# ### Saving and closing on Colab

# %%
# Copy to drive
if on_Colab==True:
    drive.mount('/gdrive')

    path = f"/gdrive/My Drive/gradient_free_bc_MC/8.OLG_model_nonsmooth_5/{output_extension}"
    # Create folder if does not exist:
    if not os.path.exists(path):
      # If it doesn't exist, create it
      os.mkdir(path)

    ## A. Save to Grdive
    # Compress to zip
    folder_to_zip = current_wd  + "/output/" + output_extension
    output_zip_file = folder_to_zip
    shutil.make_archive(f"{path}/{output_extension}", 'zip', folder_to_zip)

    #shutil.copy(f"{output_zip_file}.zip", f"{path}/{output_extension}.zip")
    # Remove local
    drive.flush_and_unmount()
    print('All changes made in this colab session should now be visible in Drive.')

# %%
disconnect_when_done = False

if on_Colab==True:
    # Wait 2 minutes
    time.sleep(120)

    ## Close session
    from google.colab import runtime
    if disconnect_when_done==True:
      print("Closing runtime")
      runtime.unassign()

# %% [markdown]
# ---
#
# ## References
#
#
# *  Pascal, Julien, Artificial Neural Networks to Solve Dynamic Programming Problems: A Bias-Corrected Monte Carlo Operator (January 16, 2024). BCL Working Papers n°172, Available at SSRN: https://ssrn.com/abstract=4476122 or http://dx.doi.org/10.2139/ssrn.4476122
